# %%
from google.colab import drive

# 1 Monte Google Drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os
import glob
import torch
import numpy as np
import nibabel as nib
import matplotlib.pyplot as plt

# 2 Chemin du dossier extrait sur Google Drive
dossier_path = '/content/drive/MyDrive/Nouveau/Lung250M_4B/Lung250M_4B'

# 3 Lister les fichiers dans le dossier
fichiers = os.listdir(dossier_path)
print("Fichiers dans le dossier :", fichiers)

# %matplotlib inline

# 3. Lister les fichiers images et masques
images_train = sorted(glob.glob(os.path.join(dossier_path, "imagesTr", "*.nii.gz")))
labels_train = sorted(glob.glob(os.path.join(dossier_path, "masksTr", "*.nii.gz")))

# Lister les fichiers de test (imagesTs et masksTs)
images_test = sorted(glob.glob(os.path.join(dossier_path, "imagesTs", "*.nii.gz")))
labels_test = sorted(glob.glob(os.path.join(dossier_path, "masksTs", "*.nii.gz")))

# 4. Afficher le nombre d'images et de masques
print('Nombre d\'images :', len(images_train), 'Nombre de masques :', len(labels_train))
# Out:
# Fichiers dans le dossier : ['imagesTs', 'imagesTr', 'masksTs', 'masksTr']
# Nombre d'images : 22 Nombre de masques : 22

# %%
# 5 Chargement d'une image et du masque
img = nib.load(images_train[0]).get_fdata()
lbl = nib.load(labels_train[0]).get_fdata()
# Affichage des dimensions du volume
print('img shape:', img.shape, ' lbl shape:', lbl.shape)

print('img intensity min.:', np.min(img), ' max.:', np.max(img), ' unique labels:', np.unique(lbl)) # pour vérifier le nombre de classe du masque

# Visualisation de la coupe 100
slice_idx = 100

plt.figure(figsize=(8,5))
plt.subplot(1,2,1)
plt.imshow(img[slice_idx], cmap='gray', vmin=-1000, vmax=1000) # affiche le slice en niveau de gris
plt.contour(lbl[slice_idx], colors='red') # Pour le contour en rouge
plt.axis('off')
# Pour afficher uniquement le masque
plt.subplot(1,2,2)
plt.imshow(lbl[slice_idx], cmap='gray')
plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# img shape: (332, 218, 267)  lbl shape: (332, 218, 267)
# img intensity min.: -1024.0  max.: 1599.203125  unique labels: [0. 1.]

# %%
# !pip install --force-reinstall numpy monai
# Out:
# Collecting numpy
#   Downloading numpy-2.2.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 2.0 MB/s eta 0:00:00
# Collecting monai
#   Downloading monai-1.4.0-py3-none-any.whl.metadata (11 kB)
# Collecting numpy
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.7 MB/s eta 0:00:00
# Collecting torch>=1.9 (from monai)
#   Downloading torch-2.7.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Collecting filelock (from torch>=1.9->monai)
#   Downloading filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting typing-extensions>=4.10.0 (from torch>=1.9->monai)
#   Downloading typing_extensions-4.13.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting sympy>=1.13.3 (from torch>=1.9->monai)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch>=1.9->monai)
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch>=1.9->monai)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec (from torch>=1.9->monai)
#   Downloading fsspec-2025.3.2-py3-none-any.whl.metadata (11 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.6.77 (from torch>=1.9->monai)
#   Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.6.77 (from torch>=1.9->monai)
#   Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.6.80 (from torch>=1.9->monai)
#   Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.5.1.17 (from torch>=1.9->monai)
#   Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.6.4.1 (from torch>=1.9->monai)
#   Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.3.0.4 (from torch>=1.9->monai)
#   Downloading nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.7.77 (from torch>=1.9->monai)
#   Downloading nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.7.1.2 (from torch>=1.9->monai)
#   Downloading nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.5.4.2 (from torch>=1.9->monai)
#   Downloading nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.3 (from torch>=1.9->monai)
#   Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.26.2 (from torch>=1.9->monai)
#   Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvtx-cu12==12.6.77 (from torch>=1.9->monai)
#   Downloading nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nvjitlink-cu12==12.6.85 (from torch>=1.9->monai)
#   Downloading nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufile-cu12==1.11.1.6 (from torch>=1.9->monai)
#   Downloading nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.3.0 (from torch>=1.9->monai)
#   Downloading triton-3.3.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Collecting setuptools>=40.8.0 (from triton==3.3.0->torch>=1.9->monai)
#   Downloading setuptools-80.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch>=1.9->monai)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch>=1.9->monai)
#   Downloading MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Downloading monai-1.4.0-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 40.8 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 26.7 MB/s eta 0:00:00
# Downloading torch-2.7.0-cp311-cp311-manylinux_2_28_x86_64.whl (865.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 865.2/865.2 MB 1.7 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (393.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 MB 3.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 121.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 97.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.7/897.7 kB 64.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl (571.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.0/571.0 MB 2.3 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (200.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.2/200.2 MB 5.5 MB/s eta 0:00:00
# Downloading nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 70.5 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 17.0 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (158.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/158.2 MB 6.1 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 MB 6.7 MB/s eta 0:00:00
# Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl (156.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 MB 6.6 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 MB 6.6 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 104.0 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.3/89.3 kB 9.7 MB/s eta 0:00:00
# Downloading triton-3.3.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (156.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.5/156.5 MB 7.0 MB/s eta 0:00:00
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 117.0 MB/s eta 0:00:00
# Downloading typing_extensions-4.13.2-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 4.5 MB/s eta 0:00:00
# Downloading filelock-3.18.0-py3-none-any.whl (16 kB)
# Downloading fsspec-2025.3.2-py3-none-any.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.4/194.4 kB 20.2 MB/s eta 0:00:00
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.9/134.9 kB 14.5 MB/s eta 0:00:00
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 71.0 MB/s eta 0:00:00
# Downloading MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23 kB)
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 45.1 MB/s eta 0:00:00
# Downloading setuptools-80.3.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 73.7 MB/s eta 0:00:00
# Installing collected packages: nvidia-cusparselt-cu12, mpmath, typing-extensions, sympy, setuptools, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, MarkupSafe, fsspec, filelock, triton, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, jinja2, nvidia-cusolver-cu12, torch, monai
#   Attempting uninstall: nvidia-cusparselt-cu12
#     Found existing installation: nvidia-cusparselt-cu12 0.6.2
#     Uninstalling nvidia-cusparselt-cu12-0.6.2:
#       Successfully uninstalled nvidia-cusparselt-cu12-0.6.2
#   Attempting uninstall: mpmath
#     Found existing installation: mpmath 1.3.0
#     Uninstalling mpmath-1.3.0:
#       Successfully uninstalled mpmath-1.3.0
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.13.2
#     Uninstalling typing_extensions-4.13.2:
#       Successfully uninstalled typing_extensions-4.13.2
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.1
#     Uninstalling sympy-1.13.1:
#       Successfully uninstalled sympy-1.13.1
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.2.0
#     Uninstalling setuptools-75.2.0:
#       Successfully uninstalled setuptools-75.2.0
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.4.127
#     Uninstalling nvidia-nvtx-cu12-12.4.127:
#       Successfully uninstalled nvidia-nvtx-cu12-12.4.127
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.21.5
#     Uninstalling nvidia-nccl-cu12-2.21.5:
#       Successfully uninstalled nvidia-nccl-cu12-2.21.5
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.4.2
#     Uninstalling networkx-3.4.2:
#       Successfully uninstalled networkx-3.4.2
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
#       Successfully uninstalled MarkupSafe-3.0.2
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.18.0
#     Uninstalling filelock-3.18.0:
#       Successfully uninstalled filelock-3.18.0
#   Attempting uninstall: triton
#     Found existing installation: triton 3.2.0
#     Uninstalling triton-3.2.0:
#       Successfully uninstalled triton-3.2.0
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 3.1.6
#     Uninstalling Jinja2-3.1.6:
#       Successfully uninstalled Jinja2-3.1.6
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
#   Attempting uninstall: torch
#     Found existing installation: torch 2.6.0+cu124
#     Uninstalling torch-2.6.0+cu124:
#       Successfully uninstalled torch-2.6.0+cu124
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# torchaudio 2.6.0+cu124 requires torch==2.6.0, but you have torch 2.7.0 which is incompatible.
# torchvision 0.21.0+cu124 requires torch==2.6.0, but you have torch 2.7.0 which is incompatible.
# fastai 2.7.19 requires torch<2.7,>=1.10, but you have torch 2.7.0 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed MarkupSafe-3.0.2 filelock-3.18.0 fsspec-2025.3.2 jinja2-3.1.6 monai-1.4.0 mpmath-1.3.0 networkx-3.4.2 numpy-1.26.4 nvidia-cublas-cu12-12.6.4.1 nvidia-cuda-cupti-cu12-12.6.80 nvidia-cuda-nvrtc-cu12-12.6.77 nvidia-cuda-runtime-cu12-12.6.77 nvidia-cudnn-cu12-9.5.1.17 nvidia-cufft-cu12-11.3.0.4 nvidia-cufile-cu12-1.11.1.6 nvidia-curand-cu12-10.3.7.77 nvidia-cusolver-cu12-11.7.1.2 nvidia-cusparse-cu12-12.5.4.2 nvidia-cusparselt-cu12-0.6.3 nvidia-nccl-cu12-2.26.2 nvidia-nvjitlink-cu12-12.6.85 nvidia-nvtx-cu12-12.6.77 setuptools-80.3.0 sympy-1.14.0 torch-2.7.0 triton-3.3.0 typing-extensions-4.13.2

# %%
from monai.utils import first, set_determinism

set_determinism(seed=0) # Pour fixer la seed dés le départ

# %%
# 1. Créer une liste de dictionnaires pour les paires image-masque d'entraînement
train_data_dicts = [
    {"image": image_name, "label": label_name}
    for image_name, label_name in zip(images_train, labels_train)
]

# 2. Diviser les données d'entraînement en train/val (par exemple 85%/15%)
train_split = int(0.84 * len(train_data_dicts))
train_files = train_data_dicts[:train_split]
val_files = train_data_dicts[train_split:]

# 3. Créer une liste de dictionnaires pour les données de test
test_files = [
    {"image": image_name, "label": label_name}
    for image_name, label_name in zip(images_test, labels_test)
]

# 4. Afficher le nombre de fichiers dans chaque ensemble
print(f"Entraînement : {len(train_files)} fichiers")
print(f"Validation : {len(val_files)} fichiers")
print(f"Test : {len(test_files)} fichiers")
# Out:
# Entraînement : 18 fichiers
# Validation : 4 fichiers
# Test : 30 fichiers

# %%
from monai.transforms import (
    AsDiscrete,
    AsDiscreted,
    EnsureChannelFirstd,
    Compose,
    CropForegroundd,
    LoadImaged,
    Orientationd,
    RandAffined,
    RandFlipd,
    RandScaleIntensityd,
    RandShiftIntensityd,
    RandSpatialCropd,
    SaveImaged,
    ScaleIntensityRanged,
    Spacingd,
    Invertd,
)
from monai.data import CacheDataset, DataLoader, Dataset, decollate_batch

# Transformations
train_transforms = Compose([
    LoadImaged(keys=["image", "label"]),
    EnsureChannelFirstd(keys=["image", "label"]),
    ScaleIntensityRanged(keys=["image"], a_min=-1000, a_max=1000, b_min=0.0, b_max=1.0, clip=True),
    #ScaleIntensityRanged(keys=["label"], a_min=0, a_max=255, b_min=0.0, b_max=1.0, clip=True),
    CropForegroundd(keys=["image", "label"], source_key="image"),
    Orientationd(keys=["image", "label"], axcodes="PLS"),
    Spacingd(keys=["image", "label"], pixdim=(1.5, 1.5, 2.0), mode=("bilinear", "nearest")),
    RandSpatialCropd(keys=["image", "label"], roi_size=[96, 96, 96], random_size=False),
    RandAffined(keys=["image", "label"], mode=('bilinear', 'nearest'), prob=1.0, spatial_size=(96, 96, 96), rotate_range=(0, 0, np.pi/15), scale_range=(0.1, 0.1, 0.1)),
    RandFlipd(keys=["image", "label"], prob=0.25, spatial_axis=0),
    RandFlipd(keys=["image", "label"], prob=0.25, spatial_axis=1),
    RandFlipd(keys=["image", "label"], prob=0.25, spatial_axis=2),
    RandScaleIntensityd(keys="image", factors=0.1, prob=1.0),
    RandShiftIntensityd(keys="image", offsets=0.1, prob=1.0),
])

val_transforms = Compose([
    LoadImaged(keys=["image", "label"]),
    EnsureChannelFirstd(keys=["image", "label"]),
    ScaleIntensityRanged(keys=["image"], a_min=-1000, a_max=1000, b_min=0.0, b_max=1.0, clip=True),
    #ScaleIntensityRanged(keys=["label"], a_min=0, a_max=255, b_min=0.0, b_max=1.0, clip=True),
    CropForegroundd(keys=["image", "label"], source_key="image"),
    Orientationd(keys=["image", "label"], axcodes="PLS"),
    Spacingd(keys=["image", "label"], pixdim=(1.5, 1.5, 2.0), mode=("bilinear", "nearest")),
])

test_transforms = Compose([
    LoadImaged(keys=["image", "label"]),
    EnsureChannelFirstd(keys=["image", "label"]),
    ScaleIntensityRanged(keys=["image"], a_min=-1000, a_max=1000, b_min=0.0, b_max=1.0, clip=True),
    #ScaleIntensityRanged(keys=["label"], a_min=0, a_max=255, b_min=0.0, b_max=1.0, clip=True),
    CropForegroundd(keys=["image", "label"], source_key="image"),
    Orientationd(keys=["image", "label"], axcodes="PLS"),
    Spacingd(keys=["image", "label"], pixdim=(1.5, 1.5, 2.0), mode=("bilinear", "nearest")),
])
# Out:
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:321: FutureWarning: monai.transforms.croppad.dictionary CropForegroundd.__init__:allow_smaller: Current default value of argument `allow_smaller=True` has been deprecated since version 1.2. It will be changed to `allow_smaller=False` in version 1.5.
#   warn_deprecated(argname, msg, warning_category)

# %%
# Visualisation de l'image après les transformation
sample_ds = Dataset(data=train_files, transform=train_transforms)
sample_dataloader = DataLoader(sample_ds, batch_size=1)
sample_batch = first(sample_dataloader)

img, lbl = sample_batch["image"][0][0], sample_batch["label"][0][0]
print(f"img shape: {img.shape}, lbl shape: {lbl.shape}")

slice_idx = 64
plt.figure(figsize=(8,5))
plt.subplot(1,2,1)
plt.imshow(img[:,:,slice_idx], cmap='gray')
plt.contour(lbl[:,:,slice_idx], colors='red')
plt.axis('off')
plt.subplot(1,2,2)
plt.imshow(lbl[:,:,slice_idx], cmap='gray')
plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# img shape: torch.Size([96, 96, 96]), lbl shape: torch.Size([96, 96, 96])

# %% [markdown]
# Maintenant, nous créons des dataloaders pour les jeux de données d'entraînement et de validation en utilisant la bibliothèque MONAI. La classe `CacheDataset` est utilisée pour créer les jeux de données d'entraînement et de validation en spécifiant les chemins des fichiers, les transformations de prétraitement, le taux de cache et le nombre de travailleurs pour le traitement parallèle. C'est une classe de la bibliothèque MONAI qui permet de créer un jeu de données à partir d'une liste de fichiers de données et d'une fonction de transformation. Elle peut être utilisée pour mettre en cache les données prétraitées en mémoire afin d'y accéder plus rapidement pendant l'entraînement, ce qui peut être particulièrement utile pour de grands jeux de données.

# %%
# Créer les datasets avec CacheDataset
train_ds = CacheDataset(data=train_files, transform=train_transforms, cache_rate=1.0)
val_ds = CacheDataset(data=val_files, transform=val_transforms, cache_rate=1.0)
test_ds = CacheDataset(data=test_files, transform=test_transforms, cache_rate=1.0)

# Créer les DataLoaders
train_loader = DataLoader(train_ds, batch_size=2, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=1)
test_loader = DataLoader(test_ds, batch_size=1)
# Out:
# Loading dataset: 100%|██████████| 18/18 [02:07<00:00,  7.10s/it]
# Loading dataset: 100%|██████████| 4/4 [00:28<00:00,  7.04s/it]
# Loading dataset: 100%|██████████| 30/30 [03:19<00:00,  6.67s/it]

# %%
from monai.losses import DiceLoss
from monai.metrics import DiceMetric
from monai.networks.nets import UNet
from monai.networks.layers import Norm

device = torch.device("cuda:0")
model = UNet(
    spatial_dims=3,
    in_channels=1,
    out_channels=2,
    channels=(16, 32, 64, 128, 256),
    strides=(2, 2, 2, 2),
    num_res_units=2,
    norm=Norm.BATCH,
).to(device)
loss_function = DiceLoss(to_onehot_y=True, softmax=True)
optimizer = torch.optim.Adam(model.parameters(), 1e-4)
dice_metric = DiceMetric(include_background=False, reduction="mean")

# %%
from monai.inferers import sliding_window_inference

# Define hyperparameters
max_epochs = 500
val_interval = 2
best_metric = -1
best_metric_epoch = -1
epoch_loss_values = []
metric_values = []

# Define post-processing transforms
post_pred = Compose([AsDiscrete(argmax=True, to_onehot=2)])
post_label = Compose([AsDiscrete(to_onehot=2)])

# Training loop
for epoch in range(max_epochs):
    print("-" * 10)
    print(f"epoch {epoch + 1}/{max_epochs}")
    model.train()
    epoch_loss = 0
    step = 0
    for batch_data in train_loader:
        step += 1
        inputs, labels = batch_data["image"].to(device), batch_data["label"].to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = loss_function(outputs, labels)
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
        print(f"{step}/{len(train_ds) // train_loader.batch_size}, train_loss: {loss.item():.4f}")
    epoch_loss /= step
    epoch_loss_values.append(epoch_loss)

    print(f"epoch {epoch + 1} average loss: {epoch_loss:.4f}")

    if (epoch + 1) % val_interval == 0:
        model.eval()
        with torch.no_grad():
            val_sample = next(iter(val_loader))
            print("Label shape :", val_sample["label"].shape)
            print("Label unique values :", torch.unique(val_sample["label"]))
            print("Image shape :", val_sample["image"].shape)
            for val_data in val_loader:
                val_inputs, val_labels = val_data["image"].to(device), val_data["label"].to(device),
                val_outputs = sliding_window_inference(val_inputs, (96, 96, 96), 1, model)

                val_outputs = [post_pred(i) for i in decollate_batch(val_outputs)]
                val_labels = [post_label(i) for i in decollate_batch(val_labels)]

                # compute metric for current iteration
                dice_metric(y_pred=val_outputs, y=val_labels)

            # aggregate the final mean dice result
            metric = dice_metric.aggregate().item()

            # reset the status for next validation round
            dice_metric.reset()

            metric_values.append(metric)
            if metric > best_metric:
                best_metric = metric
                best_metric_epoch = epoch + 1
                torch.save(model.state_dict(), "best_metric_model.pth")
                print("saved new best metric model")
            print(
                f"current epoch: {epoch + 1} current mean dice: {metric:.4f}"
                f"\nbest mean dice: {best_metric:.4f} "
                f"at epoch: {best_metric_epoch}"
            )
from google.colab import files
files.download('best_metric_model.pth')
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# 9/9, train_loss: 0.0353
# epoch 156 average loss: 0.0256
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 156 current mean dice: 0.8860
# best mean dice: 0.9712 at epoch: 128
# ----------
# epoch 157/500
# 1/9, train_loss: 0.0205
# 2/9, train_loss: 0.0263
# 3/9, train_loss: 0.0234
# 4/9, train_loss: 0.0301
# 5/9, train_loss: 0.0197
# 6/9, train_loss: 0.0228
# 7/9, train_loss: 0.0239
# 8/9, train_loss: 0.0281
# 9/9, train_loss: 0.0345
# epoch 157 average loss: 0.0255
# ----------
# epoch 158/500
# 1/9, train_loss: 0.0514
# 2/9, train_loss: 0.0194
# 3/9, train_loss: 0.0317
# 4/9, train_loss: 0.0217
# 5/9, train_loss: 0.0225
# 6/9, train_loss: 0.0199
# 7/9, train_loss: 0.0213
# 8/9, train_loss: 0.0205
# 9/9, train_loss: 0.0228
# epoch 158 average loss: 0.0257
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 158 current mean dice: 0.9534
# best mean dice: 0.9712 at epoch: 128
# ----------
# epoch 159/500
# 1/9, train_loss: 0.0243
# 2/9, train_loss: 0.0202
# 3/9, train_loss: 0.0222
# 4/9, train_loss: 0.0217
# 5/9, train_loss: 0.0247
# 6/9, train_loss: 0.0251
# 7/9, train_loss: 0.0241
# 8/9, train_loss: 0.0218
# 9/9, train_loss: 0.0234
# epoch 159 average loss: 0.0231
# ----------
# epoch 160/500
# 1/9, train_loss: 0.0212
# 2/9, train_loss: 0.0266
# 3/9, train_loss: 0.0191
# 4/9, train_loss: 0.0230
# 5/9, train_loss: 0.0255
# 6/9, train_loss: 0.0158
# 7/9, train_loss: 0.0248
# 8/9, train_loss: 0.0188
# 9/9, train_loss: 0.0200
# epoch 160 average loss: 0.0217
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 160 current mean dice: 0.9667
# best mean dice: 0.9712 at epoch: 128
# ----------
# epoch 161/500
# 1/9, train_loss: 0.0218
# 2/9, train_loss: 0.0223
# 3/9, train_loss: 0.0259
# 4/9, train_loss: 0.0209
# 5/9, train_loss: 0.0225
# 6/9, train_loss: 0.0212
# 7/9, train_loss: 0.0283
# 8/9, train_loss: 0.0210
# 9/9, train_loss: 0.0213
# epoch 161 average loss: 0.0228
# ----------
# epoch 162/500
# 1/9, train_loss: 0.0214
# 2/9, train_loss: 0.0275
# 3/9, train_loss: 0.0210
# 4/9, train_loss: 0.0196
# 5/9, train_loss: 0.0233
# 6/9, train_loss: 0.0207
# 7/9, train_loss: 0.0184
# 8/9, train_loss: 0.0286
# 9/9, train_loss: 0.0167
# epoch 162 average loss: 0.0219
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 162 current mean dice: 0.9573
# best mean dice: 0.9712 at epoch: 128
# ----------
# epoch 163/500
# 1/9, train_loss: 0.0259
# 2/9, train_loss: 0.0173
# 3/9, train_loss: 0.0200
# 4/9, train_loss: 0.0200
# 5/9, train_loss: 0.0269
# 6/9, train_loss: 0.0192
# 7/9, train_loss: 0.0281
# 8/9, train_loss: 0.0192
# 9/9, train_loss: 0.0237
# epoch 163 average loss: 0.0223
# ----------
# epoch 164/500
# 1/9, train_loss: 0.0187
# 2/9, train_loss: 0.0213
# 3/9, train_loss: 0.0186
# 4/9, train_loss: 0.0265
# 5/9, train_loss: 0.0231
# 6/9, train_loss: 0.0209
# 7/9, train_loss: 0.0218
# 8/9, train_loss: 0.0219
# 9/9, train_loss: 0.0174
# epoch 164 average loss: 0.0211
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 164 current mean dice: 0.9541
# best mean dice: 0.9712 at epoch: 128
# ----------
# epoch 165/500
# 1/9, train_loss: 0.0188
# 2/9, train_loss: 0.0245
# 3/9, train_loss: 0.0239
# 4/9, train_loss: 0.0206
# 5/9, train_loss: 0.0198
# 6/9, train_loss: 0.0221
# 7/9, train_loss: 0.0240
# 8/9, train_loss: 0.0265
# 9/9, train_loss: 0.0233
# epoch 165 average loss: 0.0226
# ----------
# epoch 166/500
# 1/9, train_loss: 0.0165
# 2/9, train_loss: 0.0205
# 3/9, train_loss: 0.0213
# 4/9, train_loss: 0.0185
# 5/9, train_loss: 0.0200
# 6/9, train_loss: 0.0203
# 7/9, train_loss: 0.0168
# 8/9, train_loss: 0.0196
# 9/9, train_loss: 0.0167
# epoch 166 average loss: 0.0189
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 166 current mean dice: 0.9606
# best mean dice: 0.9712 at epoch: 128
# ----------
# epoch 167/500
# 1/9, train_loss: 0.0208
# 2/9, train_loss: 0.0183
# 3/9, train_loss: 0.0180
# 4/9, train_loss: 0.0178
# 5/9, train_loss: 0.0185
# 6/9, train_loss: 0.0189
# 7/9, train_loss: 0.0199
# 8/9, train_loss: 0.0167
# 9/9, train_loss: 0.0297
# epoch 167 average loss: 0.0198
# ----------
# epoch 168/500
# 1/9, train_loss: 0.0230
# 2/9, train_loss: 0.0189
# 3/9, train_loss: 0.0354
# 4/9, train_loss: 0.0238
# 5/9, train_loss: 0.0220
# 6/9, train_loss: 0.0224
# 7/9, train_loss: 0.0212
# 8/9, train_loss: 0.0201
# 9/9, train_loss: 0.0255
# epoch 168 average loss: 0.0236
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 168 current mean dice: 0.9588
# best mean dice: 0.9712 at epoch: 128
# ----------
# epoch 169/500
# 1/9, train_loss: 0.0216
# 2/9, train_loss: 0.0202
# 3/9, train_loss: 0.0228
# 4/9, train_loss: 0.0179
# 5/9, train_loss: 0.0317
# 6/9, train_loss: 0.0204
# 7/9, train_loss: 0.0230
# 8/9, train_loss: 0.0222
# 9/9, train_loss: 0.0230
# epoch 169 average loss: 0.0225
# ----------
# epoch 170/500
# 1/9, train_loss: 0.0265
# 2/9, train_loss: 0.0209
# 3/9, train_loss: 0.0240
# 4/9, train_loss: 0.0171
# 5/9, train_loss: 0.0204
# 6/9, train_loss: 0.0213
# 7/9, train_loss: 0.0188
# 8/9, train_loss: 0.0236
# 9/9, train_loss: 0.0183
# epoch 170 average loss: 0.0212
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# saved new best metric model
# current epoch: 170 current mean dice: 0.9717
# best mean dice: 0.9717 at epoch: 170
# ----------
# epoch 171/500
# 1/9, train_loss: 0.0220
# 2/9, train_loss: 0.0197
# 3/9, train_loss: 0.0275
# 4/9, train_loss: 0.0217
# 5/9, train_loss: 0.0215
# 6/9, train_loss: 0.0197
# 7/9, train_loss: 0.0241
# 8/9, train_loss: 0.0233
# 9/9, train_loss: 0.0214
# epoch 171 average loss: 0.0223
# ----------
# epoch 172/500
# 1/9, train_loss: 0.0183
# 2/9, train_loss: 0.0188
# 3/9, train_loss: 0.0220
# 4/9, train_loss: 0.0220
# 5/9, train_loss: 0.0358
# 6/9, train_loss: 0.0192
# 7/9, train_loss: 0.0272
# 8/9, train_loss: 0.0196
# 9/9, train_loss: 0.0210
# epoch 172 average loss: 0.0227
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 172 current mean dice: 0.9622
# best mean dice: 0.9717 at epoch: 170
# ----------
# epoch 173/500
# 1/9, train_loss: 0.0202
# 2/9, train_loss: 0.0170
# 3/9, train_loss: 0.0165
# 4/9, train_loss: 0.0227
# 5/9, train_loss: 0.0200
# 6/9, train_loss: 0.0183
# 7/9, train_loss: 0.0319
# 8/9, train_loss: 0.0303
# 9/9, train_loss: 0.0206
# epoch 173 average loss: 0.0220
# ----------
# epoch 174/500
# 1/9, train_loss: 0.0213
# 2/9, train_loss: 0.0181
# 3/9, train_loss: 0.0227
# 4/9, train_loss: 0.0204
# 5/9, train_loss: 0.0202
# 6/9, train_loss: 0.0221
# 7/9, train_loss: 0.0192
# 8/9, train_loss: 0.0189
# 9/9, train_loss: 0.0207
# epoch 174 average loss: 0.0204
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 174 current mean dice: 0.9492
# best mean dice: 0.9717 at epoch: 170
# ----------
# epoch 175/500
# 1/9, train_loss: 0.0203
# 2/9, train_loss: 0.0191
# 3/9, train_loss: 0.0245
# 4/9, train_loss: 0.0240
# 5/9, train_loss: 0.0206
# 6/9, train_loss: 0.0242
# 7/9, train_loss: 0.0203
# 8/9, train_loss: 0.0324
# 9/9, train_loss: 0.0198
# epoch 175 average loss: 0.0228
# ----------
# epoch 176/500
# 1/9, train_loss: 0.0236
# 2/9, train_loss: 0.0372
# 3/9, train_loss: 0.0196
# 4/9, train_loss: 0.0384
# 5/9, train_loss: 0.0211
# 6/9, train_loss: 0.0217
# 7/9, train_loss: 0.0258
# 8/9, train_loss: 0.0269
# 9/9, train_loss: 0.0244
# epoch 176 average loss: 0.0265
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# saved new best metric model
# current epoch: 176 current mean dice: 0.9753
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 177/500
# 1/9, train_loss: 0.0266
# 2/9, train_loss: 0.0241
# 3/9, train_loss: 0.0196
# 4/9, train_loss: 0.0256
# 5/9, train_loss: 0.0312
# 6/9, train_loss: 0.0244
# 7/9, train_loss: 0.0190
# 8/9, train_loss: 0.0230
# 9/9, train_loss: 0.0208
# epoch 177 average loss: 0.0238
# ----------
# epoch 178/500
# 1/9, train_loss: 0.0183
# 2/9, train_loss: 0.0246
# 3/9, train_loss: 0.0216
# 4/9, train_loss: 0.0196
# 5/9, train_loss: 0.0235
# 6/9, train_loss: 0.0211
# 7/9, train_loss: 0.0168
# 8/9, train_loss: 0.0208
# 9/9, train_loss: 0.0192
# epoch 178 average loss: 0.0206
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 178 current mean dice: 0.9353
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 179/500
# 1/9, train_loss: 0.0182
# 2/9, train_loss: 0.0215
# 3/9, train_loss: 0.0273
# 4/9, train_loss: 0.0220
# 5/9, train_loss: 0.0203
# 6/9, train_loss: 0.0192
# 7/9, train_loss: 0.0199
# 8/9, train_loss: 0.0183
# 9/9, train_loss: 0.0163
# epoch 179 average loss: 0.0203
# ----------
# epoch 180/500
# 1/9, train_loss: 0.0193
# 2/9, train_loss: 0.0461
# 3/9, train_loss: 0.0211
# 4/9, train_loss: 0.0222
# 5/9, train_loss: 0.0192
# 6/9, train_loss: 0.0216
# 7/9, train_loss: 0.0232
# 8/9, train_loss: 0.0223
# 9/9, train_loss: 0.0214
# epoch 180 average loss: 0.0241
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 180 current mean dice: 0.8686
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 181/500
# 1/9, train_loss: 0.0210
# 2/9, train_loss: 0.0195
# 3/9, train_loss: 0.0237
# 4/9, train_loss: 0.0199
# 5/9, train_loss: 0.0225
# 6/9, train_loss: 0.0207
# 7/9, train_loss: 0.0200
# 8/9, train_loss: 0.0174
# 9/9, train_loss: 0.0348
# epoch 181 average loss: 0.0221
# ----------
# epoch 182/500
# 1/9, train_loss: 0.0206
# 2/9, train_loss: 0.0208
# 3/9, train_loss: 0.0231
# 4/9, train_loss: 0.0178
# 5/9, train_loss: 0.0471
# 6/9, train_loss: 0.0255
# 7/9, train_loss: 0.0203
# 8/9, train_loss: 0.0240
# 9/9, train_loss: 0.0223
# epoch 182 average loss: 0.0246
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 182 current mean dice: 0.9574
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 183/500
# 1/9, train_loss: 0.0195
# 2/9, train_loss: 0.0267
# 3/9, train_loss: 0.0192
# 4/9, train_loss: 0.0195
# 5/9, train_loss: 0.0174
# 6/9, train_loss: 0.0183
# 7/9, train_loss: 0.0311
# 8/9, train_loss: 0.0303
# 9/9, train_loss: 0.0173
# epoch 183 average loss: 0.0221
# ----------
# epoch 184/500
# 1/9, train_loss: 0.0191
# 2/9, train_loss: 0.0206
# 3/9, train_loss: 0.0245
# 4/9, train_loss: 0.0193
# 5/9, train_loss: 0.0213
# 6/9, train_loss: 0.0171
# 7/9, train_loss: 0.0155
# 8/9, train_loss: 0.0244
# 9/9, train_loss: 0.0218
# epoch 184 average loss: 0.0204
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 184 current mean dice: 0.9612
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 185/500
# 1/9, train_loss: 0.0199
# 2/9, train_loss: 0.0189
# 3/9, train_loss: 0.0296
# 4/9, train_loss: 0.0200
# 5/9, train_loss: 0.0232
# 6/9, train_loss: 0.0288
# 7/9, train_loss: 0.0197
# 8/9, train_loss: 0.0219
# 9/9, train_loss: 0.0276
# epoch 185 average loss: 0.0233
# ----------
# epoch 186/500
# 1/9, train_loss: 0.0177
# 2/9, train_loss: 0.0265
# 3/9, train_loss: 0.0239
# 4/9, train_loss: 0.0203
# 5/9, train_loss: 0.0217
# 6/9, train_loss: 0.0230
# 7/9, train_loss: 0.0225
# 8/9, train_loss: 0.0183
# 9/9, train_loss: 0.0260
# epoch 186 average loss: 0.0222
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 186 current mean dice: 0.9348
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 187/500
# 1/9, train_loss: 0.0218
# 2/9, train_loss: 0.0177
# 3/9, train_loss: 0.0196
# 4/9, train_loss: 0.0188
# 5/9, train_loss: 0.0175
# 6/9, train_loss: 0.0229
# 7/9, train_loss: 0.0235
# 8/9, train_loss: 0.0160
# 9/9, train_loss: 0.0210
# epoch 187 average loss: 0.0199
# ----------
# epoch 188/500
# 1/9, train_loss: 0.0361
# 2/9, train_loss: 0.0203
# 3/9, train_loss: 0.0168
# 4/9, train_loss: 0.0199
# 5/9, train_loss: 0.0190
# 6/9, train_loss: 0.0186
# 7/9, train_loss: 0.0238
# 8/9, train_loss: 0.0182
# 9/9, train_loss: 0.0272
# epoch 188 average loss: 0.0222
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 188 current mean dice: 0.9648
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 189/500
# 1/9, train_loss: 0.0182
# 2/9, train_loss: 0.0216
# 3/9, train_loss: 0.0182
# 4/9, train_loss: 0.0304
# 5/9, train_loss: 0.0146
# 6/9, train_loss: 0.0149
# 7/9, train_loss: 0.0277
# 8/9, train_loss: 0.0212
# 9/9, train_loss: 0.0192
# epoch 189 average loss: 0.0207
# ----------
# epoch 190/500
# 1/9, train_loss: 0.0220
# 2/9, train_loss: 0.0167
# 3/9, train_loss: 0.0278
# 4/9, train_loss: 0.0162
# 5/9, train_loss: 0.0194
# 6/9, train_loss: 0.0173
# 7/9, train_loss: 0.0351
# 8/9, train_loss: 0.0202
# 9/9, train_loss: 0.0205
# epoch 190 average loss: 0.0217
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 190 current mean dice: 0.9678
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 191/500
# 1/9, train_loss: 0.0200
# 2/9, train_loss: 0.0214
# 3/9, train_loss: 0.0217
# 4/9, train_loss: 0.0185
# 5/9, train_loss: 0.0218
# 6/9, train_loss: 0.0206
# 7/9, train_loss: 0.0215
# 8/9, train_loss: 0.0206
# 9/9, train_loss: 0.0197
# epoch 191 average loss: 0.0206
# ----------
# epoch 192/500
# 1/9, train_loss: 0.0165
# 2/9, train_loss: 0.0184
# 3/9, train_loss: 0.0194
# 4/9, train_loss: 0.0236
# 5/9, train_loss: 0.0208
# 6/9, train_loss: 0.0180
# 7/9, train_loss: 0.0179
# 8/9, train_loss: 0.0203
# 9/9, train_loss: 0.0178
# epoch 192 average loss: 0.0192
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 192 current mean dice: 0.9458
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 193/500
# 1/9, train_loss: 0.0197
# 2/9, train_loss: 0.0183
# 3/9, train_loss: 0.0216
# 4/9, train_loss: 0.0199
# 5/9, train_loss: 0.0277
# 6/9, train_loss: 0.0170
# 7/9, train_loss: 0.0212
# 8/9, train_loss: 0.0219
# 9/9, train_loss: 0.0170
# epoch 193 average loss: 0.0205
# ----------
# epoch 194/500
# 1/9, train_loss: 0.0236
# 2/9, train_loss: 0.0199
# 3/9, train_loss: 0.0202
# 4/9, train_loss: 0.0239
# 5/9, train_loss: 0.0181
# 6/9, train_loss: 0.0182
# 7/9, train_loss: 0.0221
# 8/9, train_loss: 0.0225
# 9/9, train_loss: 0.0191
# epoch 194 average loss: 0.0209
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 194 current mean dice: 0.9407
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 195/500
# 1/9, train_loss: 0.0191
# 2/9, train_loss: 0.0204
# 3/9, train_loss: 0.0216
# 4/9, train_loss: 0.0194
# 5/9, train_loss: 0.0214
# 6/9, train_loss: 0.0199
# 7/9, train_loss: 0.0175
# 8/9, train_loss: 0.0189
# 9/9, train_loss: 0.0173
# epoch 195 average loss: 0.0195
# ----------
# epoch 196/500
# 1/9, train_loss: 0.0364
# 2/9, train_loss: 0.0232
# 3/9, train_loss: 0.0504
# 4/9, train_loss: 0.0288
# 5/9, train_loss: 0.0209
# 6/9, train_loss: 0.0158
# 7/9, train_loss: 0.0214
# 8/9, train_loss: 0.0226
# 9/9, train_loss: 0.0190
# epoch 196 average loss: 0.0265
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 196 current mean dice: 0.9627
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 197/500
# 1/9, train_loss: 0.0187
# 2/9, train_loss: 0.0226
# 3/9, train_loss: 0.0224
# 4/9, train_loss: 0.0245
# 5/9, train_loss: 0.0432
# 6/9, train_loss: 0.0239
# 7/9, train_loss: 0.0195
# 8/9, train_loss: 0.0211
# 9/9, train_loss: 0.0216
# epoch 197 average loss: 0.0242
# ----------
# epoch 198/500
# 1/9, train_loss: 0.0203
# 2/9, train_loss: 0.0331
# 3/9, train_loss: 0.0458
# 4/9, train_loss: 0.0205
# 5/9, train_loss: 0.0235
# 6/9, train_loss: 0.0198
# 7/9, train_loss: 0.0191
# 8/9, train_loss: 0.0223
# 9/9, train_loss: 0.0337
# epoch 198 average loss: 0.0265
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 198 current mean dice: 0.8603
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 199/500
# 1/9, train_loss: 0.0233
# 2/9, train_loss: 0.0171
# 3/9, train_loss: 0.0220
# 4/9, train_loss: 0.0200
# 5/9, train_loss: 0.0229
# 6/9, train_loss: 0.0206
# 7/9, train_loss: 0.0195
# 8/9, train_loss: 0.0250
# 9/9, train_loss: 0.0223
# epoch 199 average loss: 0.0214
# ----------
# epoch 200/500
# 1/9, train_loss: 0.0177
# 2/9, train_loss: 0.0192
# 3/9, train_loss: 0.0304
# 4/9, train_loss: 0.0193
# 5/9, train_loss: 0.0234
# 6/9, train_loss: 0.0268
# 7/9, train_loss: 0.0286
# 8/9, train_loss: 0.0223
# 9/9, train_loss: 0.0270
# epoch 200 average loss: 0.0239
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 200 current mean dice: 0.9404
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 201/500
# 1/9, train_loss: 0.0253
# 2/9, train_loss: 0.0287
# 3/9, train_loss: 0.0267
# 4/9, train_loss: 0.0205
# 5/9, train_loss: 0.0221
# 6/9, train_loss: 0.0202
# 7/9, train_loss: 0.0214
# 8/9, train_loss: 0.0210
# 9/9, train_loss: 0.0229
# epoch 201 average loss: 0.0232
# ----------
# epoch 202/500
# 1/9, train_loss: 0.0244
# 2/9, train_loss: 0.0206
# 3/9, train_loss: 0.0226
# 4/9, train_loss: 0.0267
# 5/9, train_loss: 0.0193
# 6/9, train_loss: 0.0220
# 7/9, train_loss: 0.0250
# 8/9, train_loss: 0.0182
# 9/9, train_loss: 0.0260
# epoch 202 average loss: 0.0227
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 202 current mean dice: 0.9414
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 203/500
# 1/9, train_loss: 0.0234
# 2/9, train_loss: 0.0489
# 3/9, train_loss: 0.0184
# 4/9, train_loss: 0.0194
# 5/9, train_loss: 0.0214
# 6/9, train_loss: 0.0198
# 7/9, train_loss: 0.0201
# 8/9, train_loss: 0.0185
# 9/9, train_loss: 0.0194
# epoch 203 average loss: 0.0232
# ----------
# epoch 204/500
# 1/9, train_loss: 0.0199
# 2/9, train_loss: 0.0214
# 3/9, train_loss: 0.0219
# 4/9, train_loss: 0.0191
# 5/9, train_loss: 0.0199
# 6/9, train_loss: 0.0218
# 7/9, train_loss: 0.0191
# 8/9, train_loss: 0.0178
# 9/9, train_loss: 0.0211
# epoch 204 average loss: 0.0202
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 204 current mean dice: 0.9692
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 205/500
# 1/9, train_loss: 0.0223
# 2/9, train_loss: 0.0194
# 3/9, train_loss: 0.0223
# 4/9, train_loss: 0.0184
# 5/9, train_loss: 0.0209
# 6/9, train_loss: 0.0209
# 7/9, train_loss: 0.0204
# 8/9, train_loss: 0.0212
# 9/9, train_loss: 0.0161
# epoch 205 average loss: 0.0202
# ----------
# epoch 206/500
# 1/9, train_loss: 0.0331
# 2/9, train_loss: 0.0178
# 3/9, train_loss: 0.0189
# 4/9, train_loss: 0.0211
# 5/9, train_loss: 0.0194
# 6/9, train_loss: 0.0447
# 7/9, train_loss: 0.0189
# 8/9, train_loss: 0.0182
# 9/9, train_loss: 0.0176
# epoch 206 average loss: 0.0233
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 206 current mean dice: 0.9469
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 207/500
# 1/9, train_loss: 0.0178
# 2/9, train_loss: 0.0140
# 3/9, train_loss: 0.0191
# 4/9, train_loss: 0.0188
# 5/9, train_loss: 0.0202
# 6/9, train_loss: 0.0489
# 7/9, train_loss: 0.0173
# 8/9, train_loss: 0.0193
# 9/9, train_loss: 0.0189
# epoch 207 average loss: 0.0216
# ----------
# epoch 208/500
# 1/9, train_loss: 0.0194
# 2/9, train_loss: 0.0181
# 3/9, train_loss: 0.0227
# 4/9, train_loss: 0.0155
# 5/9, train_loss: 0.0146
# 6/9, train_loss: 0.0198
# 7/9, train_loss: 0.0150
# 8/9, train_loss: 0.0227
# 9/9, train_loss: 0.0229
# epoch 208 average loss: 0.0190
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 208 current mean dice: 0.9707
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 209/500
# 1/9, train_loss: 0.0231
# 2/9, train_loss: 0.0184
# 3/9, train_loss: 0.0170
# 4/9, train_loss: 0.0196
# 5/9, train_loss: 0.0192
# 6/9, train_loss: 0.0158
# 7/9, train_loss: 0.0150
# 8/9, train_loss: 0.0176
# 9/9, train_loss: 0.0170
# epoch 209 average loss: 0.0181
# ----------
# epoch 210/500
# 1/9, train_loss: 0.0194
# 2/9, train_loss: 0.0172
# 3/9, train_loss: 0.0160
# 4/9, train_loss: 0.0303
# 5/9, train_loss: 0.0162
# 6/9, train_loss: 0.0191
# 7/9, train_loss: 0.0188
# 8/9, train_loss: 0.0204
# 9/9, train_loss: 0.0187
# epoch 210 average loss: 0.0196
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 210 current mean dice: 0.9542
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 211/500
# 1/9, train_loss: 0.0181
# 2/9, train_loss: 0.0179
# 3/9, train_loss: 0.0153
# 4/9, train_loss: 0.0275
# 5/9, train_loss: 0.0240
# 6/9, train_loss: 0.0377
# 7/9, train_loss: 0.0252
# 8/9, train_loss: 0.0190
# 9/9, train_loss: 0.0234
# epoch 211 average loss: 0.0231
# ----------
# epoch 212/500
# 1/9, train_loss: 0.0168
# 2/9, train_loss: 0.0213
# 3/9, train_loss: 0.0254
# 4/9, train_loss: 0.0200
# 5/9, train_loss: 0.0278
# 6/9, train_loss: 0.0183
# 7/9, train_loss: 0.0170
# 8/9, train_loss: 0.0173
# 9/9, train_loss: 0.0193
# epoch 212 average loss: 0.0204
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 212 current mean dice: 0.9552
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 213/500
# 1/9, train_loss: 0.0182
# 2/9, train_loss: 0.0174
# 3/9, train_loss: 0.0177
# 4/9, train_loss: 0.0185
# 5/9, train_loss: 0.0260
# 6/9, train_loss: 0.0181
# 7/9, train_loss: 0.0187
# 8/9, train_loss: 0.0157
# 9/9, train_loss: 0.0169
# epoch 213 average loss: 0.0186
# ----------
# epoch 214/500
# 1/9, train_loss: 0.0179
# 2/9, train_loss: 0.0174
# 3/9, train_loss: 0.0184
# 4/9, train_loss: 0.0289
# 5/9, train_loss: 0.0152
# 6/9, train_loss: 0.0221
# 7/9, train_loss: 0.0263
# 8/9, train_loss: 0.0170
# 9/9, train_loss: 0.0281
# epoch 214 average loss: 0.0213
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 214 current mean dice: 0.9574
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 215/500
# 1/9, train_loss: 0.0216
# 2/9, train_loss: 0.0204
# 3/9, train_loss: 0.0190
# 4/9, train_loss: 0.0164
# 5/9, train_loss: 0.0192
# 6/9, train_loss: 0.0218
# 7/9, train_loss: 0.0312
# 8/9, train_loss: 0.0190
# 9/9, train_loss: 0.0216
# epoch 215 average loss: 0.0211
# ----------
# epoch 216/500
# 1/9, train_loss: 0.0195
# 2/9, train_loss: 0.0267
# 3/9, train_loss: 0.0187
# 4/9, train_loss: 0.0342
# 5/9, train_loss: 0.0158
# 6/9, train_loss: 0.0249
# 7/9, train_loss: 0.0182
# 8/9, train_loss: 0.0206
# 9/9, train_loss: 0.0233
# epoch 216 average loss: 0.0224
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 216 current mean dice: 0.9430
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 217/500
# 1/9, train_loss: 0.0182
# 2/9, train_loss: 0.0196
# 3/9, train_loss: 0.0205
# 4/9, train_loss: 0.0200
# 5/9, train_loss: 0.0196
# 6/9, train_loss: 0.0163
# 7/9, train_loss: 0.0259
# 8/9, train_loss: 0.0188
# 9/9, train_loss: 0.0172
# epoch 217 average loss: 0.0196
# ----------
# epoch 218/500
# 1/9, train_loss: 0.0280
# 2/9, train_loss: 0.0187
# 3/9, train_loss: 0.0186
# 4/9, train_loss: 0.0202
# 5/9, train_loss: 0.0183
# 6/9, train_loss: 0.0171
# 7/9, train_loss: 0.0193
# 8/9, train_loss: 0.0183
# 9/9, train_loss: 0.0172
# epoch 218 average loss: 0.0195
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 218 current mean dice: 0.9602
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 219/500
# 1/9, train_loss: 0.0188
# 2/9, train_loss: 0.0191
# 3/9, train_loss: 0.0175
# 4/9, train_loss: 0.0212
# 5/9, train_loss: 0.0215
# 6/9, train_loss: 0.0250
# 7/9, train_loss: 0.0204
# 8/9, train_loss: 0.0185
# 9/9, train_loss: 0.0148
# epoch 219 average loss: 0.0197
# ----------
# epoch 220/500
# 1/9, train_loss: 0.0169
# 2/9, train_loss: 0.0158
# 3/9, train_loss: 0.0210
# 4/9, train_loss: 0.0159
# 5/9, train_loss: 0.0217
# 6/9, train_loss: 0.0179
# 7/9, train_loss: 0.0178
# 8/9, train_loss: 0.0159
# 9/9, train_loss: 0.0190
# epoch 220 average loss: 0.0180
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 220 current mean dice: 0.9491
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 221/500
# 1/9, train_loss: 0.0165
# 2/9, train_loss: 0.0158
# 3/9, train_loss: 0.0177
# 4/9, train_loss: 0.0187
# 5/9, train_loss: 0.0167
# 6/9, train_loss: 0.0201
# 7/9, train_loss: 0.0170
# 8/9, train_loss: 0.0169
# 9/9, train_loss: 0.0224
# epoch 221 average loss: 0.0180
# ----------
# epoch 222/500
# 1/9, train_loss: 0.0161
# 2/9, train_loss: 0.0162
# 3/9, train_loss: 0.0184
# 4/9, train_loss: 0.0183
# 5/9, train_loss: 0.0225
# 6/9, train_loss: 0.0182
# 7/9, train_loss: 0.0191
# 8/9, train_loss: 0.0164
# 9/9, train_loss: 0.0235
# epoch 222 average loss: 0.0187
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 222 current mean dice: 0.9335
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 223/500
# 1/9, train_loss: 0.0157
# 2/9, train_loss: 0.0171
# 3/9, train_loss: 0.0171
# 4/9, train_loss: 0.0161
# 5/9, train_loss: 0.0194
# 6/9, train_loss: 0.0168
# 7/9, train_loss: 0.0176
# 8/9, train_loss: 0.0165
# 9/9, train_loss: 0.0150
# epoch 223 average loss: 0.0168
# ----------
# epoch 224/500
# 1/9, train_loss: 0.0365
# 2/9, train_loss: 0.0179
# 3/9, train_loss: 0.0172
# 4/9, train_loss: 0.0168
# 5/9, train_loss: 0.0199
# 6/9, train_loss: 0.0176
# 7/9, train_loss: 0.0182
# 8/9, train_loss: 0.0212
# 9/9, train_loss: 0.0166
# epoch 224 average loss: 0.0202
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 224 current mean dice: 0.9425
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 225/500
# 1/9, train_loss: 0.0196
# 2/9, train_loss: 0.0201
# 3/9, train_loss: 0.0163
# 4/9, train_loss: 0.0175
# 5/9, train_loss: 0.0163
# 6/9, train_loss: 0.0149
# 7/9, train_loss: 0.0182
# 8/9, train_loss: 0.0178
# 9/9, train_loss: 0.0196
# epoch 225 average loss: 0.0178
# ----------
# epoch 226/500
# 1/9, train_loss: 0.0158
# 2/9, train_loss: 0.0231
# 3/9, train_loss: 0.0206
# 4/9, train_loss: 0.0183
# 5/9, train_loss: 0.0195
# 6/9, train_loss: 0.0187
# 7/9, train_loss: 0.0182
# 8/9, train_loss: 0.0172
# 9/9, train_loss: 0.0158
# epoch 226 average loss: 0.0186
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 226 current mean dice: 0.9473
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 227/500
# 1/9, train_loss: 0.0179
# 2/9, train_loss: 0.0190
# 3/9, train_loss: 0.0182
# 4/9, train_loss: 0.0169
# 5/9, train_loss: 0.0158
# 6/9, train_loss: 0.0188
# 7/9, train_loss: 0.0189
# 8/9, train_loss: 0.0160
# 9/9, train_loss: 0.0165
# epoch 227 average loss: 0.0176
# ----------
# epoch 228/500
# 1/9, train_loss: 0.0156
# 2/9, train_loss: 0.0169
# 3/9, train_loss: 0.0172
# 4/9, train_loss: 0.0241
# 5/9, train_loss: 0.0197
# 6/9, train_loss: 0.0158
# 7/9, train_loss: 0.0210
# 8/9, train_loss: 0.0183
# 9/9, train_loss: 0.0178
# epoch 228 average loss: 0.0185
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 228 current mean dice: 0.9516
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 229/500
# 1/9, train_loss: 0.0151
# 2/9, train_loss: 0.0212
# 3/9, train_loss: 0.0169
# 4/9, train_loss: 0.0156
# 5/9, train_loss: 0.0189
# 6/9, train_loss: 0.0197
# 7/9, train_loss: 0.0177
# 8/9, train_loss: 0.0177
# 9/9, train_loss: 0.0174
# epoch 229 average loss: 0.0178
# ----------
# epoch 230/500
# 1/9, train_loss: 0.0201
# 2/9, train_loss: 0.0152
# 3/9, train_loss: 0.0166
# 4/9, train_loss: 0.0158
# 5/9, train_loss: 0.0171
# 6/9, train_loss: 0.0191
# 7/9, train_loss: 0.0191
# 8/9, train_loss: 0.0140
# 9/9, train_loss: 0.0173
# epoch 230 average loss: 0.0171
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 230 current mean dice: 0.9617
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 231/500
# 1/9, train_loss: 0.0166
# 2/9, train_loss: 0.0170
# 3/9, train_loss: 0.0141
# 4/9, train_loss: 0.0185
# 5/9, train_loss: 0.0191
# 6/9, train_loss: 0.0159
# 7/9, train_loss: 0.0248
# 8/9, train_loss: 0.0269
# 9/9, train_loss: 0.0188
# epoch 231 average loss: 0.0191
# ----------
# epoch 232/500
# 1/9, train_loss: 0.0185
# 2/9, train_loss: 0.0148
# 3/9, train_loss: 0.0204
# 4/9, train_loss: 0.0231
# 5/9, train_loss: 0.0205
# 6/9, train_loss: 0.0175
# 7/9, train_loss: 0.0188
# 8/9, train_loss: 0.0170
# 9/9, train_loss: 0.0164
# epoch 232 average loss: 0.0186
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 232 current mean dice: 0.9660
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 233/500
# 1/9, train_loss: 0.0166
# 2/9, train_loss: 0.0223
# 3/9, train_loss: 0.0146
# 4/9, train_loss: 0.0194
# 5/9, train_loss: 0.0184
# 6/9, train_loss: 0.0165
# 7/9, train_loss: 0.0175
# 8/9, train_loss: 0.0161
# 9/9, train_loss: 0.0138
# epoch 233 average loss: 0.0173
# ----------
# epoch 234/500
# 1/9, train_loss: 0.0171
# 2/9, train_loss: 0.0184
# 3/9, train_loss: 0.0146
# 4/9, train_loss: 0.0148
# 5/9, train_loss: 0.0159
# 6/9, train_loss: 0.0159
# 7/9, train_loss: 0.0147
# 8/9, train_loss: 0.0196
# 9/9, train_loss: 0.0184
# epoch 234 average loss: 0.0166
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 234 current mean dice: 0.9590
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 235/500
# 1/9, train_loss: 0.0172
# 2/9, train_loss: 0.0137
# 3/9, train_loss: 0.0176
# 4/9, train_loss: 0.0185
# 5/9, train_loss: 0.0179
# 6/9, train_loss: 0.0194
# 7/9, train_loss: 0.0185
# 8/9, train_loss: 0.0172
# 9/9, train_loss: 0.0167
# epoch 235 average loss: 0.0174
# ----------
# epoch 236/500
# 1/9, train_loss: 0.0148
# 2/9, train_loss: 0.0146
# 3/9, train_loss: 0.0156
# 4/9, train_loss: 0.0156
# 5/9, train_loss: 0.0160
# 6/9, train_loss: 0.0175
# 7/9, train_loss: 0.0442
# 8/9, train_loss: 0.0146
# 9/9, train_loss: 0.0177
# epoch 236 average loss: 0.0190
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 236 current mean dice: 0.9593
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 237/500
# 1/9, train_loss: 0.0194
# 2/9, train_loss: 0.0202
# 3/9, train_loss: 0.0184
# 4/9, train_loss: 0.0175
# 5/9, train_loss: 0.0198
# 6/9, train_loss: 0.0164
# 7/9, train_loss: 0.0174
# 8/9, train_loss: 0.0177
# 9/9, train_loss: 0.0183
# epoch 237 average loss: 0.0184
# ----------
# epoch 238/500
# 1/9, train_loss: 0.0164
# 2/9, train_loss: 0.0169
# 3/9, train_loss: 0.0165
# 4/9, train_loss: 0.0243
# 5/9, train_loss: 0.0163
# 6/9, train_loss: 0.0169
# 7/9, train_loss: 0.0165
# 8/9, train_loss: 0.0145
# 9/9, train_loss: 0.0277
# epoch 238 average loss: 0.0185
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 238 current mean dice: 0.9552
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 239/500
# 1/9, train_loss: 0.0168
# 2/9, train_loss: 0.0207
# 3/9, train_loss: 0.0200
# 4/9, train_loss: 0.0211
# 5/9, train_loss: 0.0312
# 6/9, train_loss: 0.0182
# 7/9, train_loss: 0.0168
# 8/9, train_loss: 0.0173
# 9/9, train_loss: 0.0208
# epoch 239 average loss: 0.0203
# ----------
# epoch 240/500
# 1/9, train_loss: 0.0164
# 2/9, train_loss: 0.0167
# 3/9, train_loss: 0.0174
# 4/9, train_loss: 0.0206
# 5/9, train_loss: 0.0165
# 6/9, train_loss: 0.0175
# 7/9, train_loss: 0.0168
# 8/9, train_loss: 0.0250
# 9/9, train_loss: 0.0186
# epoch 240 average loss: 0.0184
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 240 current mean dice: 0.9430
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 241/500
# 1/9, train_loss: 0.0171
# 2/9, train_loss: 0.0151
# 3/9, train_loss: 0.0174
# 4/9, train_loss: 0.0329
# 5/9, train_loss: 0.0164
# 6/9, train_loss: 0.0213
# 7/9, train_loss: 0.0263
# 8/9, train_loss: 0.0240
# 9/9, train_loss: 0.0202
# epoch 241 average loss: 0.0212
# ----------
# epoch 242/500
# 1/9, train_loss: 0.0212
# 2/9, train_loss: 0.0191
# 3/9, train_loss: 0.0171
# 4/9, train_loss: 0.0151
# 5/9, train_loss: 0.0179
# 6/9, train_loss: 0.0208
# 7/9, train_loss: 0.0188
# 8/9, train_loss: 0.0162
# 9/9, train_loss: 0.0199
# epoch 242 average loss: 0.0185
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 242 current mean dice: 0.9727
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 243/500
# 1/9, train_loss: 0.0202
# 2/9, train_loss: 0.0181
# 3/9, train_loss: 0.0227
# 4/9, train_loss: 0.0194
# 5/9, train_loss: 0.0190
# 6/9, train_loss: 0.0160
# 7/9, train_loss: 0.0173
# 8/9, train_loss: 0.0190
# 9/9, train_loss: 0.0192
# epoch 243 average loss: 0.0190
# ----------
# epoch 244/500
# 1/9, train_loss: 0.0170
# 2/9, train_loss: 0.0178
# 3/9, train_loss: 0.0162
# 4/9, train_loss: 0.0172
# 5/9, train_loss: 0.0177
# 6/9, train_loss: 0.0146
# 7/9, train_loss: 0.0161
# 8/9, train_loss: 0.0179
# 9/9, train_loss: 0.0162
# epoch 244 average loss: 0.0168
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 244 current mean dice: 0.9681
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 245/500
# 1/9, train_loss: 0.0191
# 2/9, train_loss: 0.0197
# 3/9, train_loss: 0.0169
# 4/9, train_loss: 0.0147
# 5/9, train_loss: 0.0192
# 6/9, train_loss: 0.0152
# 7/9, train_loss: 0.0165
# 8/9, train_loss: 0.0173
# 9/9, train_loss: 0.0187
# epoch 245 average loss: 0.0175
# ----------
# epoch 246/500
# 1/9, train_loss: 0.0163
# 2/9, train_loss: 0.0154
# 3/9, train_loss: 0.0165
# 4/9, train_loss: 0.0197
# 5/9, train_loss: 0.0150
# 6/9, train_loss: 0.0193
# 7/9, train_loss: 0.0211
# 8/9, train_loss: 0.0149
# 9/9, train_loss: 0.0195
# epoch 246 average loss: 0.0175
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 246 current mean dice: 0.9673
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 247/500
# 1/9, train_loss: 0.0160
# 2/9, train_loss: 0.0153
# 3/9, train_loss: 0.0192
# 4/9, train_loss: 0.0176
# 5/9, train_loss: 0.0165
# 6/9, train_loss: 0.0180
# 7/9, train_loss: 0.0191
# 8/9, train_loss: 0.0181
# 9/9, train_loss: 0.0182
# epoch 247 average loss: 0.0176
# ----------
# epoch 248/500
# 1/9, train_loss: 0.0167
# 2/9, train_loss: 0.0170
# 3/9, train_loss: 0.0188
# 4/9, train_loss: 0.0163
# 5/9, train_loss: 0.0170
# 6/9, train_loss: 0.0205
# 7/9, train_loss: 0.0199
# 8/9, train_loss: 0.0165
# 9/9, train_loss: 0.0182
# epoch 248 average loss: 0.0179
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 248 current mean dice: 0.9720
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 249/500
# 1/9, train_loss: 0.0207
# 2/9, train_loss: 0.0180
# 3/9, train_loss: 0.0190
# 4/9, train_loss: 0.0151
# 5/9, train_loss: 0.0178
# 6/9, train_loss: 0.0154
# 7/9, train_loss: 0.0180
# 8/9, train_loss: 0.0196
# 9/9, train_loss: 0.0149
# epoch 249 average loss: 0.0176
# ----------
# epoch 250/500
# 1/9, train_loss: 0.0170
# 2/9, train_loss: 0.0202
# 3/9, train_loss: 0.0243
# 4/9, train_loss: 0.0206
# 5/9, train_loss: 0.0159
# 6/9, train_loss: 0.0188
# 7/9, train_loss: 0.0153
# 8/9, train_loss: 0.0170
# 9/9, train_loss: 0.0204
# epoch 250 average loss: 0.0188
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 250 current mean dice: 0.9700
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 251/500
# 1/9, train_loss: 0.0171
# 2/9, train_loss: 0.0179
# 3/9, train_loss: 0.0156
# 4/9, train_loss: 0.0196
# 5/9, train_loss: 0.0201
# 6/9, train_loss: 0.0157
# 7/9, train_loss: 0.0152
# 8/9, train_loss: 0.0341
# 9/9, train_loss: 0.0242
# epoch 251 average loss: 0.0199
# ----------
# epoch 252/500
# 1/9, train_loss: 0.0176
# 2/9, train_loss: 0.0191
# 3/9, train_loss: 0.0196
# 4/9, train_loss: 0.0159
# 5/9, train_loss: 0.0174
# 6/9, train_loss: 0.0200
# 7/9, train_loss: 0.0191
# 8/9, train_loss: 0.0195
# 9/9, train_loss: 0.0212
# epoch 252 average loss: 0.0188
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 252 current mean dice: 0.9723
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 253/500
# 1/9, train_loss: 0.0138
# 2/9, train_loss: 0.0213
# 3/9, train_loss: 0.0276
# 4/9, train_loss: 0.0250
# 5/9, train_loss: 0.0164
# 6/9, train_loss: 0.0159
# 7/9, train_loss: 0.0172
# 8/9, train_loss: 0.0150
# 9/9, train_loss: 0.0164
# epoch 253 average loss: 0.0187
# ----------
# epoch 254/500
# 1/9, train_loss: 0.0166
# 2/9, train_loss: 0.0191
# 3/9, train_loss: 0.0177
# 4/9, train_loss: 0.0191
# 5/9, train_loss: 0.0165
# 6/9, train_loss: 0.0245
# 7/9, train_loss: 0.0137
# 8/9, train_loss: 0.0147
# 9/9, train_loss: 0.0213
# epoch 254 average loss: 0.0181
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 254 current mean dice: 0.9708
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 255/500
# 1/9, train_loss: 0.0142
# 2/9, train_loss: 0.0189
# 3/9, train_loss: 0.0208
# 4/9, train_loss: 0.0161
# 5/9, train_loss: 0.0179
# 6/9, train_loss: 0.0160
# 7/9, train_loss: 0.0173
# 8/9, train_loss: 0.0171
# 9/9, train_loss: 0.0188
# epoch 255 average loss: 0.0174
# ----------
# epoch 256/500
# 1/9, train_loss: 0.0176
# 2/9, train_loss: 0.0165
# 3/9, train_loss: 0.0167
# 4/9, train_loss: 0.0309
# 5/9, train_loss: 0.0194
# 6/9, train_loss: 0.0206
# 7/9, train_loss: 0.0152
# 8/9, train_loss: 0.0577
# 9/9, train_loss: 0.0147
# epoch 256 average loss: 0.0233
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 256 current mean dice: 0.9700
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 257/500
# 1/9, train_loss: 0.0202
# 2/9, train_loss: 0.0215
# 3/9, train_loss: 0.0244
# 4/9, train_loss: 0.0182
# 5/9, train_loss: 0.0247
# 6/9, train_loss: 0.0164
# 7/9, train_loss: 0.0375
# 8/9, train_loss: 0.0189
# 9/9, train_loss: 0.0172
# epoch 257 average loss: 0.0221
# ----------
# epoch 258/500
# 1/9, train_loss: 0.0234
# 2/9, train_loss: 0.0237
# 3/9, train_loss: 0.0187
# 4/9, train_loss: 0.0219
# 5/9, train_loss: 0.0254
# 6/9, train_loss: 0.0216
# 7/9, train_loss: 0.0403
# 8/9, train_loss: 0.0229
# 9/9, train_loss: 0.0227
# epoch 258 average loss: 0.0245
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 258 current mean dice: 0.8911
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 259/500
# 1/9, train_loss: 0.0216
# 2/9, train_loss: 0.0302
# 3/9, train_loss: 0.0238
# 4/9, train_loss: 0.0214
# 5/9, train_loss: 0.0208
# 6/9, train_loss: 0.0231
# 7/9, train_loss: 0.0168
# 8/9, train_loss: 0.0335
# 9/9, train_loss: 0.0289
# epoch 259 average loss: 0.0245
# ----------
# epoch 260/500
# 1/9, train_loss: 0.0174
# 2/9, train_loss: 0.0194
# 3/9, train_loss: 0.0176
# 4/9, train_loss: 0.0187
# 5/9, train_loss: 0.0197
# 6/9, train_loss: 0.0204
# 7/9, train_loss: 0.0191
# 8/9, train_loss: 0.0176
# 9/9, train_loss: 0.0168
# epoch 260 average loss: 0.0185
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 260 current mean dice: 0.8923
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 261/500
# 1/9, train_loss: 0.0224
# 2/9, train_loss: 0.0290
# 3/9, train_loss: 0.0172
# 4/9, train_loss: 0.0176
# 5/9, train_loss: 0.0199
# 6/9, train_loss: 0.0141
# 7/9, train_loss: 0.0246
# 8/9, train_loss: 0.0159
# 9/9, train_loss: 0.0133
# epoch 261 average loss: 0.0193
# ----------
# epoch 262/500
# 1/9, train_loss: 0.0200
# 2/9, train_loss: 0.0179
# 3/9, train_loss: 0.0191
# 4/9, train_loss: 0.0159
# 5/9, train_loss: 0.0167
# 6/9, train_loss: 0.0218
# 7/9, train_loss: 0.0187
# 8/9, train_loss: 0.0211
# 9/9, train_loss: 0.0164
# epoch 262 average loss: 0.0186
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 262 current mean dice: 0.9502
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 263/500
# 1/9, train_loss: 0.0178
# 2/9, train_loss: 0.0191
# 3/9, train_loss: 0.0185
# 4/9, train_loss: 0.0128
# 5/9, train_loss: 0.0267
# 6/9, train_loss: 0.0189
# 7/9, train_loss: 0.0235
# 8/9, train_loss: 0.0204
# 9/9, train_loss: 0.0195
# epoch 263 average loss: 0.0197
# ----------
# epoch 264/500
# 1/9, train_loss: 0.0196
# 2/9, train_loss: 0.0192
# 3/9, train_loss: 0.0214
# 4/9, train_loss: 0.0165
# 5/9, train_loss: 0.0190
# 6/9, train_loss: 0.0225
# 7/9, train_loss: 0.0164
# 8/9, train_loss: 0.0170
# 9/9, train_loss: 0.0182
# epoch 264 average loss: 0.0189
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 264 current mean dice: 0.9655
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 265/500
# 1/9, train_loss: 0.0191
# 2/9, train_loss: 0.0238
# 3/9, train_loss: 0.0365
# 4/9, train_loss: 0.0148
# 5/9, train_loss: 0.0265
# 6/9, train_loss: 0.0143
# 7/9, train_loss: 0.0163
# 8/9, train_loss: 0.0199
# 9/9, train_loss: 0.0206
# epoch 265 average loss: 0.0213
# ----------
# epoch 266/500
# 1/9, train_loss: 0.0173
# 2/9, train_loss: 0.0142
# 3/9, train_loss: 0.0170
# 4/9, train_loss: 0.0147
# 5/9, train_loss: 0.0202
# 6/9, train_loss: 0.0214
# 7/9, train_loss: 0.0159
# 8/9, train_loss: 0.0163
# 9/9, train_loss: 0.0167
# epoch 266 average loss: 0.0171
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 266 current mean dice: 0.9709
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 267/500
# 1/9, train_loss: 0.0177
# 2/9, train_loss: 0.0178
# 3/9, train_loss: 0.0194
# 4/9, train_loss: 0.0145
# 5/9, train_loss: 0.0195
# 6/9, train_loss: 0.0157
# 7/9, train_loss: 0.0151
# 8/9, train_loss: 0.0193
# 9/9, train_loss: 0.0158
# epoch 267 average loss: 0.0172
# ----------
# epoch 268/500
# 1/9, train_loss: 0.0123
# 2/9, train_loss: 0.0174
# 3/9, train_loss: 0.0196
# 4/9, train_loss: 0.0185
# 5/9, train_loss: 0.0154
# 6/9, train_loss: 0.0154
# 7/9, train_loss: 0.0159
# 8/9, train_loss: 0.0135
# 9/9, train_loss: 0.0165
# epoch 268 average loss: 0.0161
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 268 current mean dice: 0.9669
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 269/500
# 1/9, train_loss: 0.0147
# 2/9, train_loss: 0.0122
# 3/9, train_loss: 0.0167
# 4/9, train_loss: 0.0178
# 5/9, train_loss: 0.0153
# 6/9, train_loss: 0.0195
# 7/9, train_loss: 0.0168
# 8/9, train_loss: 0.0172
# 9/9, train_loss: 0.0183
# epoch 269 average loss: 0.0165
# ----------
# epoch 270/500
# 1/9, train_loss: 0.0158
# 2/9, train_loss: 0.0153
# 3/9, train_loss: 0.0150
# 4/9, train_loss: 0.0183
# 5/9, train_loss: 0.0148
# 6/9, train_loss: 0.0249
# 7/9, train_loss: 0.0168
# 8/9, train_loss: 0.0165
# 9/9, train_loss: 0.0184
# epoch 270 average loss: 0.0173
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 270 current mean dice: 0.9648
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 271/500
# 1/9, train_loss: 0.0161
# 2/9, train_loss: 0.0154
# 3/9, train_loss: 0.0155
# 4/9, train_loss: 0.0176
# 5/9, train_loss: 0.0143
# 6/9, train_loss: 0.0184
# 7/9, train_loss: 0.0200
# 8/9, train_loss: 0.0149
# 9/9, train_loss: 0.0156
# epoch 271 average loss: 0.0164
# ----------
# epoch 272/500
# 1/9, train_loss: 0.0183
# 2/9, train_loss: 0.0179
# 3/9, train_loss: 0.0227
# 4/9, train_loss: 0.0187
# 5/9, train_loss: 0.0134
# 6/9, train_loss: 0.0177
# 7/9, train_loss: 0.0182
# 8/9, train_loss: 0.0205
# 9/9, train_loss: 0.0178
# epoch 272 average loss: 0.0183
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 272 current mean dice: 0.9586
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 273/500
# 1/9, train_loss: 0.0194
# 2/9, train_loss: 0.0182
# 3/9, train_loss: 0.0174
# 4/9, train_loss: 0.0170
# 5/9, train_loss: 0.0192
# 6/9, train_loss: 0.0196
# 7/9, train_loss: 0.0162
# 8/9, train_loss: 0.0326
# 9/9, train_loss: 0.0177
# epoch 273 average loss: 0.0197
# ----------
# epoch 274/500
# 1/9, train_loss: 0.0260
# 2/9, train_loss: 0.0220
# 3/9, train_loss: 0.0173
# 4/9, train_loss: 0.0142
# 5/9, train_loss: 0.0179
# 6/9, train_loss: 0.0186
# 7/9, train_loss: 0.0158
# 8/9, train_loss: 0.0172
# 9/9, train_loss: 0.0170
# epoch 274 average loss: 0.0184
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 274 current mean dice: 0.9333
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 275/500
# 1/9, train_loss: 0.0175
# 2/9, train_loss: 0.0165
# 3/9, train_loss: 0.0187
# 4/9, train_loss: 0.0166
# 5/9, train_loss: 0.0186
# 6/9, train_loss: 0.0149
# 7/9, train_loss: 0.0168
# 8/9, train_loss: 0.0151
# 9/9, train_loss: 0.0125
# epoch 275 average loss: 0.0164
# ----------
# epoch 276/500
# 1/9, train_loss: 0.0145
# 2/9, train_loss: 0.0172
# 3/9, train_loss: 0.0134
# 4/9, train_loss: 0.0158
# 5/9, train_loss: 0.0188
# 6/9, train_loss: 0.0206
# 7/9, train_loss: 0.0238
# 8/9, train_loss: 0.0183
# 9/9, train_loss: 0.0251
# epoch 276 average loss: 0.0186
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 276 current mean dice: 0.9701
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 277/500
# 1/9, train_loss: 0.0157
# 2/9, train_loss: 0.0139
# 3/9, train_loss: 0.0161
# 4/9, train_loss: 0.0171
# 5/9, train_loss: 0.0159
# 6/9, train_loss: 0.0187
# 7/9, train_loss: 0.0162
# 8/9, train_loss: 0.0170
# 9/9, train_loss: 0.0127
# epoch 277 average loss: 0.0159
# ----------
# epoch 278/500
# 1/9, train_loss: 0.0239
# 2/9, train_loss: 0.0165
# 3/9, train_loss: 0.0190
# 4/9, train_loss: 0.0144
# 5/9, train_loss: 0.0162
# 6/9, train_loss: 0.0147
# 7/9, train_loss: 0.0152
# 8/9, train_loss: 0.0175
# 9/9, train_loss: 0.0149
# epoch 278 average loss: 0.0169
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 278 current mean dice: 0.9651
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 279/500
# 1/9, train_loss: 0.0175
# 2/9, train_loss: 0.0184
# 3/9, train_loss: 0.0159
# 4/9, train_loss: 0.0235
# 5/9, train_loss: 0.0175
# 6/9, train_loss: 0.0155
# 7/9, train_loss: 0.0143
# 8/9, train_loss: 0.0146
# 9/9, train_loss: 0.0167
# epoch 279 average loss: 0.0171
# ----------
# epoch 280/500
# 1/9, train_loss: 0.0184
# 2/9, train_loss: 0.0176
# 3/9, train_loss: 0.0175
# 4/9, train_loss: 0.0147
# 5/9, train_loss: 0.0157
# 6/9, train_loss: 0.0139
# 7/9, train_loss: 0.0167
# 8/9, train_loss: 0.0181
# 9/9, train_loss: 0.0159
# epoch 280 average loss: 0.0165
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 280 current mean dice: 0.9543
# best mean dice: 0.9753 at epoch: 176
# ----------
# epoch 281/500
# 1/9, train_loss: 0.0154
# 2/9, train_loss: 0.0159
# 3/9, train_loss: 0.0136
# 4/9, train_loss: 0.0158
# 5/9, train_loss: 0.0166
# ...
# 3/9, train_loss: 0.0150
# 4/9, train_loss: 0.0141
# 5/9, train_loss: 0.0128
# 6/9, train_loss: 0.0137
# 7/9, train_loss: 0.0133
# 8/9, train_loss: 0.0125
# 9/9, train_loss: 0.0126
# epoch 459 average loss: 0.0131
# ----------
# epoch 460/500
# 1/9, train_loss: 0.0133
# 2/9, train_loss: 0.0140
# 3/9, train_loss: 0.0135
# 4/9, train_loss: 0.0142
# 5/9, train_loss: 0.0141
# 6/9, train_loss: 0.0129
# 7/9, train_loss: 0.0123
# 8/9, train_loss: 0.0152
# 9/9, train_loss: 0.0151
# epoch 460 average loss: 0.0139
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 460 current mean dice: 0.9737
# best mean dice: 0.9805 at epoch: 408
# ----------
# epoch 461/500
# 1/9, train_loss: 0.0122
# 2/9, train_loss: 0.0137
# 3/9, train_loss: 0.0114
# 4/9, train_loss: 0.0265
# 5/9, train_loss: 0.0124
# 6/9, train_loss: 0.0166
# 7/9, train_loss: 0.0139
# 8/9, train_loss: 0.0122
# 9/9, train_loss: 0.0121
# epoch 461 average loss: 0.0145
# ----------
# epoch 462/500
# 1/9, train_loss: 0.0149
# 2/9, train_loss: 0.0159
# 3/9, train_loss: 0.0118
# 4/9, train_loss: 0.0133
# 5/9, train_loss: 0.0149
# 6/9, train_loss: 0.0125
# 7/9, train_loss: 0.0175
# 8/9, train_loss: 0.0143
# 9/9, train_loss: 0.0138
# epoch 462 average loss: 0.0143
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 462 current mean dice: 0.9774
# best mean dice: 0.9805 at epoch: 408
# ----------
# epoch 463/500
# 1/9, train_loss: 0.0137
# 2/9, train_loss: 0.0164
# 3/9, train_loss: 0.0157
# 4/9, train_loss: 0.0118
# 5/9, train_loss: 0.0242
# 6/9, train_loss: 0.0143
# 7/9, train_loss: 0.0154
# 8/9, train_loss: 0.0197
# 9/9, train_loss: 0.0131
# epoch 463 average loss: 0.0160
# ----------
# epoch 464/500
# 1/9, train_loss: 0.0150
# 2/9, train_loss: 0.0305
# 3/9, train_loss: 0.0145
# 4/9, train_loss: 0.0169
# 5/9, train_loss: 0.0138
# 6/9, train_loss: 0.0160
# 7/9, train_loss: 0.0151
# 8/9, train_loss: 0.0148
# 9/9, train_loss: 0.0257
# epoch 464 average loss: 0.0180
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 464 current mean dice: 0.9745
# best mean dice: 0.9805 at epoch: 408
# ----------
# epoch 465/500
# 1/9, train_loss: 0.0124
# 2/9, train_loss: 0.0153
# 3/9, train_loss: 0.0152
# 4/9, train_loss: 0.0121
# 5/9, train_loss: 0.0128
# 6/9, train_loss: 0.0140
# 7/9, train_loss: 0.0157
# 8/9, train_loss: 0.0131
# 9/9, train_loss: 0.0137
# epoch 465 average loss: 0.0138
# ----------
# epoch 466/500
# 1/9, train_loss: 0.0145
# 2/9, train_loss: 0.0127
# 3/9, train_loss: 0.0145
# 4/9, train_loss: 0.0121
# 5/9, train_loss: 0.0155
# 6/9, train_loss: 0.0159
# 7/9, train_loss: 0.0162
# 8/9, train_loss: 0.0149
# 9/9, train_loss: 0.0144
# epoch 466 average loss: 0.0145
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 466 current mean dice: 0.9674
# best mean dice: 0.9805 at epoch: 408
# ----------
# epoch 467/500
# 1/9, train_loss: 0.0180
# 2/9, train_loss: 0.0140
# 3/9, train_loss: 0.0143
# 4/9, train_loss: 0.0148
# 5/9, train_loss: 0.0129
# 6/9, train_loss: 0.0136
# 7/9, train_loss: 0.0120
# 8/9, train_loss: 0.0161
# 9/9, train_loss: 0.0121
# epoch 467 average loss: 0.0142
# ----------
# epoch 468/500
# 1/9, train_loss: 0.0139
# 2/9, train_loss: 0.0136
# 3/9, train_loss: 0.0148
# 4/9, train_loss: 0.0118
# 5/9, train_loss: 0.0133
# 6/9, train_loss: 0.0124
# 7/9, train_loss: 0.0115
# 8/9, train_loss: 0.0170
# 9/9, train_loss: 0.0117
# epoch 468 average loss: 0.0133
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 468 current mean dice: 0.9702
# best mean dice: 0.9805 at epoch: 408
# ----------
# epoch 469/500
# 1/9, train_loss: 0.0160
# 2/9, train_loss: 0.0143
# 3/9, train_loss: 0.0141
# 4/9, train_loss: 0.0123
# 5/9, train_loss: 0.0137
# 6/9, train_loss: 0.0132
# 7/9, train_loss: 0.0202
# 8/9, train_loss: 0.0137
# 9/9, train_loss: 0.0127
# epoch 469 average loss: 0.0145
# ----------
# epoch 470/500
# 1/9, train_loss: 0.0133
# 2/9, train_loss: 0.0128
# 3/9, train_loss: 0.0193
# 4/9, train_loss: 0.0130
# 5/9, train_loss: 0.0138
# 6/9, train_loss: 0.0123
# 7/9, train_loss: 0.0138
# 8/9, train_loss: 0.0132
# 9/9, train_loss: 0.0136
# epoch 470 average loss: 0.0139
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 470 current mean dice: 0.9572
# best mean dice: 0.9805 at epoch: 408
# ----------
# epoch 471/500
# 1/9, train_loss: 0.0112
# 2/9, train_loss: 0.0153
# 3/9, train_loss: 0.0115
# 4/9, train_loss: 0.0145
# 5/9, train_loss: 0.0144
# 6/9, train_loss: 0.0140
# 7/9, train_loss: 0.0147
# 8/9, train_loss: 0.0130
# 9/9, train_loss: 0.0143
# epoch 471 average loss: 0.0137
# ----------
# epoch 472/500
# 1/9, train_loss: 0.0584
# 2/9, train_loss: 0.0156
# 3/9, train_loss: 0.0120
# 4/9, train_loss: 0.0130
# 5/9, train_loss: 0.0180
# 6/9, train_loss: 0.0166
# 7/9, train_loss: 0.0130
# 8/9, train_loss: 0.0146
# 9/9, train_loss: 0.0144
# epoch 472 average loss: 0.0195
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 472 current mean dice: 0.9584
# best mean dice: 0.9805 at epoch: 408
# ----------
# epoch 473/500
# 1/9, train_loss: 0.0195
# 2/9, train_loss: 0.0159
# 3/9, train_loss: 0.0137
# 4/9, train_loss: 0.0136
# 5/9, train_loss: 0.0119
# 6/9, train_loss: 0.0128
# 7/9, train_loss: 0.0177
# 8/9, train_loss: 0.0133
# 9/9, train_loss: 0.0159
# epoch 473 average loss: 0.0149
# ----------
# epoch 474/500
# 1/9, train_loss: 0.0133
# 2/9, train_loss: 0.0122
# 3/9, train_loss: 0.0140
# 4/9, train_loss: 0.0135
# 5/9, train_loss: 0.0308
# 6/9, train_loss: 0.0150
# 7/9, train_loss: 0.0135
# 8/9, train_loss: 0.0119
# 9/9, train_loss: 0.0142
# epoch 474 average loss: 0.0154
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 474 current mean dice: 0.9624
# best mean dice: 0.9805 at epoch: 408
# ----------
# epoch 475/500
# 1/9, train_loss: 0.0145
# 2/9, train_loss: 0.0147
# 3/9, train_loss: 0.0145
# 4/9, train_loss: 0.0177
# 5/9, train_loss: 0.0156
# 6/9, train_loss: 0.0118
# 7/9, train_loss: 0.0107
# 8/9, train_loss: 0.0142
# 9/9, train_loss: 0.0143
# epoch 475 average loss: 0.0142
# ----------
# epoch 476/500
# 1/9, train_loss: 0.0140
# 2/9, train_loss: 0.0183
# 3/9, train_loss: 0.0138
# 4/9, train_loss: 0.0141
# 5/9, train_loss: 0.0120
# 6/9, train_loss: 0.0128
# 7/9, train_loss: 0.0140
# 8/9, train_loss: 0.0154
# 9/9, train_loss: 0.0135
# epoch 476 average loss: 0.0142
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 476 current mean dice: 0.9774
# best mean dice: 0.9805 at epoch: 408
# ----------
# epoch 477/500
# 1/9, train_loss: 0.0115
# 2/9, train_loss: 0.0137
# 3/9, train_loss: 0.0126
# 4/9, train_loss: 0.0149
# 5/9, train_loss: 0.0132
# 6/9, train_loss: 0.0112
# 7/9, train_loss: 0.0135
# 8/9, train_loss: 0.0129
# 9/9, train_loss: 0.0170
# epoch 477 average loss: 0.0134
# ----------
# epoch 478/500
# 1/9, train_loss: 0.0204
# 2/9, train_loss: 0.0182
# 3/9, train_loss: 0.0116
# 4/9, train_loss: 0.0130
# 5/9, train_loss: 0.0146
# 6/9, train_loss: 0.0136
# 7/9, train_loss: 0.0125
# 8/9, train_loss: 0.0120
# 9/9, train_loss: 0.0173
# epoch 478 average loss: 0.0148
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 478 current mean dice: 0.9712
# best mean dice: 0.9805 at epoch: 408
# ----------
# epoch 479/500
# 1/9, train_loss: 0.0146
# 2/9, train_loss: 0.0144
# 3/9, train_loss: 0.0126
# 4/9, train_loss: 0.0115
# 5/9, train_loss: 0.0111
# 6/9, train_loss: 0.0153
# 7/9, train_loss: 0.0207
# 8/9, train_loss: 0.0164
# 9/9, train_loss: 0.0156
# epoch 479 average loss: 0.0147
# ----------
# epoch 480/500
# 1/9, train_loss: 0.0155
# 2/9, train_loss: 0.0148
# 3/9, train_loss: 0.0116
# 4/9, train_loss: 0.0120
# 5/9, train_loss: 0.0129
# 6/9, train_loss: 0.0142
# 7/9, train_loss: 0.0130
# 8/9, train_loss: 0.0119
# 9/9, train_loss: 0.0156
# epoch 480 average loss: 0.0135
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 480 current mean dice: 0.9697
# best mean dice: 0.9805 at epoch: 408
# ----------
# epoch 481/500
# 1/9, train_loss: 0.0130
# 2/9, train_loss: 0.0145
# 3/9, train_loss: 0.0120
# 4/9, train_loss: 0.0146
# 5/9, train_loss: 0.0133
# 6/9, train_loss: 0.0141
# 7/9, train_loss: 0.0147
# 8/9, train_loss: 0.0158
# 9/9, train_loss: 0.0144
# epoch 481 average loss: 0.0141
# ----------
# epoch 482/500
# 1/9, train_loss: 0.0144
# 2/9, train_loss: 0.0112
# 3/9, train_loss: 0.0147
# 4/9, train_loss: 0.0133
# 5/9, train_loss: 0.0166
# 6/9, train_loss: 0.0139
# 7/9, train_loss: 0.0142
# 8/9, train_loss: 0.0136
# 9/9, train_loss: 0.0102
# epoch 482 average loss: 0.0136
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 482 current mean dice: 0.9742
# best mean dice: 0.9805 at epoch: 408
# ----------
# epoch 483/500
# 1/9, train_loss: 0.0162
# 2/9, train_loss: 0.0143
# 3/9, train_loss: 0.0134
# 4/9, train_loss: 0.0128
# 5/9, train_loss: 0.0138
# 6/9, train_loss: 0.0137
# 7/9, train_loss: 0.0140
# 8/9, train_loss: 0.0137
# 9/9, train_loss: 0.0110
# epoch 483 average loss: 0.0137
# ----------
# epoch 484/500
# 1/9, train_loss: 0.0124
# 2/9, train_loss: 0.0153
# 3/9, train_loss: 0.0139
# 4/9, train_loss: 0.0149
# 5/9, train_loss: 0.0145
# 6/9, train_loss: 0.0134
# 7/9, train_loss: 0.0129
# 8/9, train_loss: 0.0120
# 9/9, train_loss: 0.0117
# epoch 484 average loss: 0.0134
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 484 current mean dice: 0.9771
# best mean dice: 0.9805 at epoch: 408
# ----------
# epoch 485/500
# 1/9, train_loss: 0.0133
# 2/9, train_loss: 0.0113
# 3/9, train_loss: 0.0130
# 4/9, train_loss: 0.0134
# 5/9, train_loss: 0.0127
# 6/9, train_loss: 0.0142
# 7/9, train_loss: 0.0451
# 8/9, train_loss: 0.0125
# 9/9, train_loss: 0.0181
# epoch 485 average loss: 0.0171
# ----------
# epoch 486/500
# 1/9, train_loss: 0.0223
# 2/9, train_loss: 0.0181
# 3/9, train_loss: 0.0175
# 4/9, train_loss: 0.0142
# 5/9, train_loss: 0.1525
# 6/9, train_loss: 0.0166
# 7/9, train_loss: 0.0195
# 8/9, train_loss: 0.0228
# 9/9, train_loss: 0.0294
# epoch 486 average loss: 0.0348
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 486 current mean dice: 0.8109
# best mean dice: 0.9805 at epoch: 408
# ----------
# epoch 487/500
# 1/9, train_loss: 0.0250
# 2/9, train_loss: 0.0211
# 3/9, train_loss: 0.0252
# 4/9, train_loss: 0.0209
# 5/9, train_loss: 0.0233
# 6/9, train_loss: 0.0454
# 7/9, train_loss: 0.0286
# 8/9, train_loss: 0.0247
# 9/9, train_loss: 0.0179
# epoch 487 average loss: 0.0258
# ----------
# epoch 488/500
# 1/9, train_loss: 0.0266
# 2/9, train_loss: 0.0342
# 3/9, train_loss: 0.0205
# 4/9, train_loss: 0.0210
# 5/9, train_loss: 0.0198
# 6/9, train_loss: 0.0799
# 7/9, train_loss: 0.0342
# 8/9, train_loss: 0.0270
# 9/9, train_loss: 0.0220
# epoch 488 average loss: 0.0317
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 488 current mean dice: 0.8526
# best mean dice: 0.9805 at epoch: 408
# ----------
# epoch 489/500
# 1/9, train_loss: 0.0237
# 2/9, train_loss: 0.0246
# 3/9, train_loss: 0.0178
# 4/9, train_loss: 0.0253
# 5/9, train_loss: 0.0207
# 6/9, train_loss: 0.0360
# 7/9, train_loss: 0.0228
# 8/9, train_loss: 0.0244
# 9/9, train_loss: 0.0266
# epoch 489 average loss: 0.0247
# ----------
# epoch 490/500
# 1/9, train_loss: 0.0834
# 2/9, train_loss: 0.0214
# 3/9, train_loss: 0.0297
# 4/9, train_loss: 0.0278
# 5/9, train_loss: 0.0211
# 6/9, train_loss: 0.0395
# 7/9, train_loss: 0.0237
# 8/9, train_loss: 0.0169
# 9/9, train_loss: 0.0271
# epoch 490 average loss: 0.0323
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 490 current mean dice: 0.9028
# best mean dice: 0.9805 at epoch: 408
# ----------
# epoch 491/500
# 1/9, train_loss: 0.0176
# 2/9, train_loss: 0.0240
# 3/9, train_loss: 0.0160
# 4/9, train_loss: 0.0213
# 5/9, train_loss: 0.0180
# 6/9, train_loss: 0.0267
# 7/9, train_loss: 0.0322
# 8/9, train_loss: 0.0169
# 9/9, train_loss: 0.0191
# epoch 491 average loss: 0.0213
# ----------
# epoch 492/500
# 1/9, train_loss: 0.0166
# 2/9, train_loss: 0.0223
# 3/9, train_loss: 0.0157
# 4/9, train_loss: 0.0271
# 5/9, train_loss: 0.0206
# 6/9, train_loss: 0.0141
# 7/9, train_loss: 0.0161
# 8/9, train_loss: 0.0145
# 9/9, train_loss: 0.0198
# epoch 492 average loss: 0.0185
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 492 current mean dice: 0.9622
# best mean dice: 0.9805 at epoch: 408
# ----------
# epoch 493/500
# 1/9, train_loss: 0.0128
# 2/9, train_loss: 0.0142
# 3/9, train_loss: 0.0175
# 4/9, train_loss: 0.0250
# 5/9, train_loss: 0.0140
# 6/9, train_loss: 0.0238
# 7/9, train_loss: 0.0155
# 8/9, train_loss: 0.0144
# 9/9, train_loss: 0.0135
# epoch 493 average loss: 0.0167
# ----------
# epoch 494/500
# 1/9, train_loss: 0.0149
# 2/9, train_loss: 0.0265
# 3/9, train_loss: 0.0161
# 4/9, train_loss: 0.0210
# 5/9, train_loss: 0.0131
# 6/9, train_loss: 0.0140
# 7/9, train_loss: 0.0159
# 8/9, train_loss: 0.0135
# 9/9, train_loss: 0.0130
# epoch 494 average loss: 0.0164
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 494 current mean dice: 0.9678
# best mean dice: 0.9805 at epoch: 408
# ----------
# epoch 495/500
# 1/9, train_loss: 0.0190
# 2/9, train_loss: 0.0156
# 3/9, train_loss: 0.0148
# 4/9, train_loss: 0.0146
# 5/9, train_loss: 0.0158
# 6/9, train_loss: 0.0147
# 7/9, train_loss: 0.0157
# 8/9, train_loss: 0.0180
# 9/9, train_loss: 0.0167
# epoch 495 average loss: 0.0161
# ----------
# epoch 496/500
# 1/9, train_loss: 0.0142
# 2/9, train_loss: 0.0269
# 3/9, train_loss: 0.0151
# 4/9, train_loss: 0.0138
# 5/9, train_loss: 0.0134
# 6/9, train_loss: 0.0171
# 7/9, train_loss: 0.0143
# 8/9, train_loss: 0.0146
# 9/9, train_loss: 0.0142
# epoch 496 average loss: 0.0160
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 496 current mean dice: 0.9330
# best mean dice: 0.9805 at epoch: 408
# ----------
# epoch 497/500
# 1/9, train_loss: 0.0126
# 2/9, train_loss: 0.0151
# 3/9, train_loss: 0.0138
# 4/9, train_loss: 0.0153
# 5/9, train_loss: 0.0165
# 6/9, train_loss: 0.0142
# 7/9, train_loss: 0.0180
# 8/9, train_loss: 0.0136
# 9/9, train_loss: 0.0186
# epoch 497 average loss: 0.0153
# ----------
# epoch 498/500
# 1/9, train_loss: 0.0152
# 2/9, train_loss: 0.0224
# 3/9, train_loss: 0.0136
# 4/9, train_loss: 0.0147
# 5/9, train_loss: 0.0152
# 6/9, train_loss: 0.0154
# 7/9, train_loss: 0.0146
# 8/9, train_loss: 0.0205
# 9/9, train_loss: 0.0146
# epoch 498 average loss: 0.0162
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 498 current mean dice: 0.9337
# best mean dice: 0.9805 at epoch: 408
# ----------
# epoch 499/500
# 1/9, train_loss: 0.0150
# 2/9, train_loss: 0.0163
# 3/9, train_loss: 0.0143
# 4/9, train_loss: 0.0144
# 5/9, train_loss: 0.0326
# 6/9, train_loss: 0.0162
# 7/9, train_loss: 0.0121
# 8/9, train_loss: 0.0163
# 9/9, train_loss: 0.0154
# epoch 499 average loss: 0.0169
# ----------
# epoch 500/500
# 1/9, train_loss: 0.0204
# 2/9, train_loss: 0.0160
# 3/9, train_loss: 0.0151
# 4/9, train_loss: 0.0148
# 5/9, train_loss: 0.0150
# 6/9, train_loss: 0.0168
# 7/9, train_loss: 0.0174
# 8/9, train_loss: 0.0150
# 9/9, train_loss: 0.0150
# epoch 500 average loss: 0.0162
# Label shape : torch.Size([1, 1, 157, 217, 136])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 157, 217, 136])
# current epoch: 500 current mean dice: 0.9631
# best mean dice: 0.9805 at epoch: 408

# %%
print(
    f"train completed, best_metric: {best_metric:.4f} "
    f"at epoch: {best_metric_epoch}")
# Out:
# train completed, best_metric: 0.9805 at epoch: 408

# %%
plt.figure("train", (25,7))
plt.subplot(1, 2, 1)
plt.title("Epoch Average Loss")
x = [i + 1 for i in range(len(epoch_loss_values))]
y = epoch_loss_values
plt.ylabel("Loss")
plt.xlabel("epoch")
plt.plot(x, y, color='darkred')
plt.grid(True)
plt.subplot(1, 2, 2)
plt.title("Val Mean Dice")
x = [val_interval * (i + 1) for i in range(len(metric_values))]
y = metric_values
plt.ylabel("DSC")
plt.xlabel("epoch")
plt.grid(True)
plt.plot(x, y, color='black')
plt.show()

# %% [markdown]
# **Make Predictions from Test Data**

# %%
test_ds = Dataset(data=test_files, transform=val_transforms)
test_loader = DataLoader(test_ds, batch_size=1)

post_transforms = Compose([
    Invertd(
        keys="pred",
        transform=val_transforms,
        orig_keys="image",
        meta_keys="pred_meta_dict",
        orig_meta_keys="image_meta_dict",
        meta_key_postfix="meta_dict",
        nearest_interp=False,
        to_tensor=True,
    ),
    AsDiscreted(keys="pred", argmax=True, to_onehot=2),
    SaveImaged(keys="pred", meta_keys="pred_meta_dict", output_dir="./out", output_postfix="seg", resample=False),
])

# %%
import torch
import matplotlib.pyplot as plt
import nibabel as nib
import numpy as np
from monai.transforms import LoadImaged
from monai.inferers import sliding_window_inference
from monai.handlers.utils import from_engine
from monai.data import decollate_batch

# Charger les images avec nibabel
image_path = test_files[0]['image']
label_path = test_files[0]['label']

image_data = nib.load(image_path).get_fdata()
label_data = nib.load(label_path).get_fdata()

# Convertir en tensors PyTorch
original_image = torch.from_numpy(image_data).float()
original_label = torch.from_numpy(label_data).float()

# Vérifier la forme des images
print("Original image shape:", original_image.shape)
print("Original label shape:", original_label.shape)

# Choisir une coupe 2D
slice_idx = 30
image_slice_2d = original_image[slice_idx].detach().cpu().numpy()
label_slice_2d = original_label[slice_idx].detach().cpu().numpy()

# Charger le modèle
model.load_state_dict(torch.load("best_metric_model.pth", map_location="cpu"))
model.eval()

# Exécuter l'inférence
with torch.no_grad():
    for test_data in test_loader:
        test_inputs = test_data["image"].to(device)
        test_data["pred"] = sliding_window_inference(test_inputs, (96, 96, 96), 1, model, overlap=0.75)
        test_data = [post_transforms(i) for i in decollate_batch(test_data)]
        test_output = from_engine(["pred"])(test_data)
        break  # Un seul batch

# Extraire la prédiction pour la classe "poumon" (index 1)
predicted_mask = torch.argmax(test_output[0], dim=0)  # Réduction sur l'axe des classes
predicted_slice = predicted_mask[slice_idx].detach().cpu().numpy()

# Afficher les résultats
plt.figure(figsize=(20, 7))

# Image originale
plt.subplot(1, 3, 1)
plt.imshow(image_slice_2d, cmap="gray", vmin=-1000, vmax=1000)
plt.title(f'Test image, slice {slice_idx}')
plt.axis('off')

# Label de référence
plt.subplot(1, 3, 2)
plt.imshow(label_slice_2d, cmap="gray")
plt.title(f'Reference label, slice {slice_idx}')
plt.axis('off')

# Prédiction
plt.subplot(1, 3, 3)
plt.imshow(predicted_slice, cmap="gray")
plt.title(f'Predicted label, slice {slice_idx}')
plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Original image shape: torch.Size([308, 226, 277])
# Original label shape: torch.Size([308, 226, 277])
# 2025-05-03 21:01:00,945 INFO image_writer.py:197 - writing: out/case_054_1/case_054_1_seg.nii.gz

# %%
import torch
import matplotlib.pyplot as plt
import nibabel as nib
import numpy as np
from monai.transforms import LoadImaged
from monai.inferers import sliding_window_inference
from monai.handlers.utils import from_engine
from monai.data import decollate_batch

# Charger les images avec nibabel
image_path = test_files[0]['image']
label_path = test_files[0]['label']

image_data = nib.load(image_path).get_fdata()
label_data = nib.load(label_path).get_fdata()

# Convertir en tensors PyTorch
original_image = torch.from_numpy(image_data).float()
original_label = torch.from_numpy(label_data).float()

# Vérifier la forme des images
print("Original image shape:", original_image.shape)
print("Original label shape:", original_label.shape)

# Choisir une coupe 2D
slice_idx = 110
image_slice_2d = original_image[slice_idx].detach().cpu().numpy()
label_slice_2d = original_label[slice_idx].detach().cpu().numpy()

# Charger le modèle
model.load_state_dict(torch.load("best_metric_model.pth", map_location="cpu"))
model.eval()

# Exécuter l'inférence
with torch.no_grad():
    for test_data in test_loader:
        test_inputs = test_data["image"].to(device)
        test_data["pred"] = sliding_window_inference(test_inputs, (96, 96, 96), 1, model, overlap=0.75)
        test_data = [post_transforms(i) for i in decollate_batch(test_data)]
        test_output = from_engine(["pred"])(test_data)
        break  # Un seul batch

# Extraire la prédiction pour la classe "poumon" (index 1)
predicted_mask = torch.argmax(test_output[0], dim=0)  # Réduction sur l'axe des classes
predicted_slice = predicted_mask[slice_idx].detach().cpu().numpy()

# Afficher les résultats
plt.figure(figsize=(20, 7))

# Image originale
plt.subplot(1, 3, 1)
plt.imshow(image_slice_2d, cmap="gray", vmin=-1000, vmax=1000)
plt.title(f'Test image, slice {slice_idx}')
plt.axis('off')

# Label de référence
plt.subplot(1, 3, 2)
plt.imshow(label_slice_2d, cmap="gray")
plt.title(f'Reference label, slice {slice_idx}')
plt.axis('off')

# Prédiction
plt.subplot(1, 3, 3)
plt.imshow(predicted_slice, cmap="gray")
plt.title(f'Predicted label, slice {slice_idx}')
plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Original image shape: torch.Size([308, 226, 277])
# Original label shape: torch.Size([308, 226, 277])
# 2025-05-03 21:01:15,053 INFO image_writer.py:197 - writing: out/case_054_1/case_054_1_seg.nii.gz

# %%
import torch
import matplotlib.pyplot as plt
import nibabel as nib
import numpy as np
from monai.transforms import LoadImaged
from monai.inferers import sliding_window_inference
from monai.handlers.utils import from_engine
from monai.data import decollate_batch

# Charger les images avec nibabel
image_path = test_files[0]['image']
label_path = test_files[0]['label']

image_data = nib.load(image_path).get_fdata()
label_data = nib.load(label_path).get_fdata()

# Convertir en tensors PyTorch
original_image = torch.from_numpy(image_data).float()
original_label = torch.from_numpy(label_data).float()

# Vérifier la forme des images
print("Original image shape:", original_image.shape)
print("Original label shape:", original_label.shape)

# Choisir une coupe 2D
slice_idx = 40
image_slice_2d = original_image[slice_idx].detach().cpu().numpy()
label_slice_2d = original_label[slice_idx].detach().cpu().numpy()

# Charger le modèle
model.load_state_dict(torch.load("best_metric_model.pth", map_location="cpu"))
model.eval()

# Exécuter l'inférence
with torch.no_grad():
    for test_data in test_loader:
        test_inputs = test_data["image"].to(device)
        test_data["pred"] = sliding_window_inference(test_inputs, (96, 96, 96), 1, model, overlap=0.75)
        test_data = [post_transforms(i) for i in decollate_batch(test_data)]
        test_output = from_engine(["pred"])(test_data)
        break  # Un seul batch

# Extraire la prédiction pour la classe "poumon" (index 1)
predicted_mask = torch.argmax(test_output[0], dim=0)  # Réduction sur l'axe des classes
predicted_slice = predicted_mask[slice_idx].detach().cpu().numpy()

# Afficher les résultats
plt.figure(figsize=(20, 7))

# Image originale
plt.subplot(1, 3, 1)
plt.imshow(image_slice_2d, cmap="gray", vmin=-1000, vmax=1000)
plt.title(f'Test image, slice {slice_idx}')
plt.axis('off')

# Label de référence
plt.subplot(1, 3, 2)
plt.imshow(label_slice_2d, cmap="gray")
plt.title(f'Reference label, slice {slice_idx}')
plt.axis('off')

# Prédiction
plt.subplot(1, 3, 3)
plt.imshow(predicted_slice, cmap="gray")
plt.title(f'Predicted label, slice {slice_idx}')
plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Original image shape: torch.Size([308, 226, 277])
# Original label shape: torch.Size([308, 226, 277])
# 2025-05-03 21:01:26,462 INFO image_writer.py:197 - writing: out/case_054_1/case_054_1_seg.nii.gz

# %%
import torch
import matplotlib.pyplot as plt
import nibabel as nib
import numpy as np
from monai.transforms import LoadImaged
from monai.inferers import sliding_window_inference
from monai.handlers.utils import from_engine
from monai.data import decollate_batch

# Charger les images avec nibabel
image_path = test_files[0]['image']
label_path = test_files[0]['label']

image_data = nib.load(image_path).get_fdata()
label_data = nib.load(label_path).get_fdata()

# Convertir en tensors PyTorch
original_image = torch.from_numpy(image_data).float()
original_label = torch.from_numpy(label_data).float()

# Vérifier la forme des images
print("Original image shape:", original_image.shape)
print("Original label shape:", original_label.shape)

# Choisir une coupe 2D
slice_idx = 140
image_slice_2d = original_image[slice_idx].detach().cpu().numpy()
label_slice_2d = original_label[slice_idx].detach().cpu().numpy()

# Charger le modèle
model.load_state_dict(torch.load("best_metric_model.pth", map_location="cpu"))
model.eval()

# Exécuter l'inférence
with torch.no_grad():
    for test_data in test_loader:
        test_inputs = test_data["image"].to(device)
        test_data["pred"] = sliding_window_inference(test_inputs, (96, 96, 96), 1, model, overlap=0.75)
        test_data = [post_transforms(i) for i in decollate_batch(test_data)]
        test_output = from_engine(["pred"])(test_data)
        break  # Un seul batch

# Extraire la prédiction pour la classe "poumon" (index 1)
predicted_mask = torch.argmax(test_output[0], dim=0)  # Réduction sur l'axe des classes
predicted_slice = predicted_mask[slice_idx].detach().cpu().numpy()

# Afficher les résultats
plt.figure(figsize=(20, 7))

# Image originale
plt.subplot(1, 3, 1)
plt.imshow(image_slice_2d, cmap="gray", vmin=-1000, vmax=1000)
plt.title(f'Test image, slice {slice_idx}')
plt.axis('off')

# Label de référence
plt.subplot(1, 3, 2)
plt.imshow(label_slice_2d, cmap="gray")
plt.title(f'Reference label, slice {slice_idx}')
plt.axis('off')

# Prédiction
plt.subplot(1, 3, 3)
plt.imshow(predicted_slice, cmap="gray")
plt.title(f'Predicted label, slice {slice_idx}')
plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Original image shape: torch.Size([308, 226, 277])
# Original label shape: torch.Size([308, 226, 277])
# 2025-05-03 21:01:50,002 INFO image_writer.py:197 - writing: out/case_054_1/case_054_1_seg.nii.gz

# %%
import torch
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt
import scipy.ndimage

from monai.transforms import LoadImaged, AsDiscrete
from monai.inferers import sliding_window_inference
from monai.data import decollate_batch

model.load_state_dict(torch.load("best_metric_model.pth", map_location=device))

model.eval()  # Mettre le modèle en mode évaluation

# Transformations pour le post-traitement
post_pred = AsDiscrete(argmax=True, to_onehot=2)

# Listes pour stocker les résultats
reference_voxels = []
predicted_voxels = []
TP_list = []
FP_list = []
FN_list = []
TN_list = []

# Parcourir les données de test
for i, test_data in enumerate(test_loader):
    print(f"Traitement de l'image de test n°{i + 1}")
    test_inputs, test_labels = test_data["image"].to(device), test_data["label"].to(device)

    # Inférence avec sliding window
    with torch.no_grad():
        test_outputs = sliding_window_inference(test_inputs, (96, 96, 96), 1, model, overlap=0.75)

    # Post-traitement des sorties
    test_outputs = [post_pred(i) for i in decollate_batch(test_outputs)]

    # Convertir les masques en numpy arrays et supprimer les dimensions supplémentaires
    predicted_mask = test_outputs[0][1].cpu().numpy()
    predicted_mask = np.squeeze(predicted_mask)  # Supprimer les dimensions supplémentaires
    reference_mask = (test_labels[0] == 1).cpu().numpy().astype(np.uint8)
    reference_mask = np.squeeze(reference_mask)  # Supprimer les dimensions supplémentaires

    # Redimensionner le masque prédit à la taille du masque de référence
    if predicted_mask.shape != reference_mask.shape:
        zoom_factors = np.array(reference_mask.shape) / np.array(predicted_mask.shape)
        predicted_mask = scipy.ndimage.zoom(predicted_mask, zoom_factors, order=0)
        predicted_mask = (predicted_mask > 0.5).astype(np.int32)  # Re-binariser après redimensionnement

    # Calculer le nombre de voxels
    num_voxels_predicted = np.sum(predicted_mask)
    num_voxels_reference = np.sum(reference_mask)

    reference_voxels.append(num_voxels_reference)
    predicted_voxels.append(num_voxels_predicted)

    # Calcul des métriques (après le redimensionnement)
    TP = np.logical_and(predicted_mask == 1, reference_mask == 1).sum()
    FP = np.logical_and(predicted_mask == 1, reference_mask == 0).sum()
    FN = np.logical_and(predicted_mask == 0, reference_mask == 1).sum()
    TN = np.logical_and(predicted_mask == 0, reference_mask == 0).sum()

    TP_list.append(TP)
    FP_list.append(FP)
    FN_list.append(FN)
    TN_list.append(TN)

    print(f"Nombre de voxels dans le masque prédit: {num_voxels_predicted}")
    print(f"Nombre de voxels dans le masque de référence: {num_voxels_reference}")
    print(f"Différence de voxels: {num_voxels_predicted - num_voxels_reference}")
    print(f"TP: {TP}, FP: {FP}, FN: {FN}, TN: {TN}")

# Calcul des métriques globales
total_TP = np.sum(TP_list)
total_FP = np.sum(FP_list)
total_FN = np.sum(FN_list)
total_TN = np.sum(TN_list)

precision = total_TP / (total_TP + total_FP + 1e-8)
recall = total_TP / (total_TP + total_FN + 1e-8)

print("\n--- Résultats globaux ---")
print(f"Précision : {precision:.4f} | Rappel : {recall:.4f}")

# Affichage du graphe comparatif
plt.figure(figsize=(12, 6))
x = np.arange(len(test_files))

plt.plot(x, reference_voxels, label="Masque de référence", marker='o', color='blue')
plt.plot(x, predicted_voxels, label="Masque prédit", marker='s', color='red')

plt.xlabel("Index de l'image de test")
plt.ylabel("Nombre de voxels")
plt.title("Comparaison des voxels dans le masque de référence et le masque prédit")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Traitement de l'image de test n°1
# Nombre de voxels dans le masque prédit: 1336772
# Nombre de voxels dans le masque de référence: 1287201
# Différence de voxels: 49571.0
# TP: 1270397, FP: 66375, FN: 16804, TN: 2970158
# Traitement de l'image de test n°2
# Nombre de voxels dans le masque prédit: 731572
# Nombre de voxels dans le masque de référence: 712978
# Différence de voxels: 18594.0
# TP: 701939, FP: 29633, FN: 11039, TN: 3581123
# Traitement de l'image de test n°3
# Nombre de voxels dans le masque prédit: 1308386.0
# Nombre de voxels dans le masque de référence: 1308514
# Différence de voxels: -128.0
# TP: 1285700, FP: 22686, FN: 22814, TN: 3398414
# Traitement de l'image de test n°4
# Nombre de voxels dans le masque prédit: 590326.0
# Nombre de voxels dans le masque de référence: 589175
# Différence de voxels: 1151.0
# TP: 574015, FP: 16311, FN: 15160, TN: 4124128
# Traitement de l'image de test n°5
# Nombre de voxels dans le masque prédit: 1045539
# Nombre de voxels dans le masque de référence: 1029678
# Différence de voxels: 15861.0
# TP: 1016171, FP: 29368, FN: 13507, TN: 3725954
# Traitement de l'image de test n°6
# Nombre de voxels dans le masque prédit: 594202
# Nombre de voxels dans le masque de référence: 585620
# Différence de voxels: 8582.0
# TP: 574189, FP: 20013, FN: 11431, TN: 4179367
# Traitement de l'image de test n°7
# Nombre de voxels dans le masque prédit: 836330.0
# Nombre de voxels dans le masque de référence: 833676
# Différence de voxels: 2654.0
# TP: 819106, FP: 17224, FN: 14570, TN: 2096660
# Traitement de l'image de test n°8
# Nombre de voxels dans le masque prédit: 529453.0
# Nombre de voxels dans le masque de référence: 537072
# Différence de voxels: -7619.0
# TP: 521594, FP: 7859, FN: 15478, TN: 2440909
# Traitement de l'image de test n°9
# Nombre de voxels dans le masque prédit: 1077703.0
# Nombre de voxels dans le masque de référence: 1081618
# Différence de voxels: -3915.0
# TP: 1064124, FP: 13579, FN: 17494, TN: 2290105
# Traitement de l'image de test n°10
# Nombre de voxels dans le masque prédit: 653028.0
# Nombre de voxels dans le masque de référence: 661767
# Différence de voxels: -8739.0
# TP: 642831, FP: 10197, FN: 18936, TN: 2782899
# Traitement de l'image de test n°11
# Nombre de voxels dans le masque prédit: 1374033.0
# Nombre de voxels dans le masque de référence: 1376388
# Différence de voxels: -2355.0
# TP: 1362181, FP: 11852, FN: 14207, TN: 3673360
# Traitement de l'image de test n°12
# Nombre de voxels dans le masque prédit: 1239023.0
# Nombre de voxels dans le masque de référence: 1242066
# Différence de voxels: -3043.0
# TP: 1228888, FP: 10135, FN: 13178, TN: 3809399
# Traitement de l'image de test n°13
# Nombre de voxels dans le masque prédit: 1395487.0
# Nombre de voxels dans le masque de référence: 1401801
# Différence de voxels: -6314.0
# TP: 1384830, FP: 10657, FN: 16971, TN: 3556592
# Traitement de l'image de test n°14
# Nombre de voxels dans le masque prédit: 1269117.0
# Nombre de voxels dans le masque de référence: 1275567
# Différence de voxels: -6450.0
# TP: 1257213, FP: 11904, FN: 18354, TN: 3649929
# Traitement de l'image de test n°15
# Nombre de voxels dans le masque prédit: 1539307.0
# Nombre de voxels dans le masque de référence: 1528327
# Différence de voxels: 10980.0
# TP: 1517526, FP: 21781, FN: 10801, TN: 2822884
# Traitement de l'image de test n°16
# Nombre de voxels dans le masque prédit: 1406740.0
# Nombre de voxels dans le masque de référence: 1375970
# Différence de voxels: 30770.0
# TP: 1366745, FP: 39995, FN: 9225, TN: 2957027
# Traitement de l'image de test n°17
# Nombre de voxels dans le masque prédit: 948623.0
# Nombre de voxels dans le masque de référence: 952503
# Différence de voxels: -3880.0
# TP: 937747, FP: 10876, FN: 14756, TN: 2797196
# Traitement de l'image de test n°18
# Nombre de voxels dans le masque prédit: 934426.0
# Nombre de voxels dans le masque de référence: 942787
# Différence de voxels: -8361.0
# TP: 927029, FP: 7397, FN: 15758, TN: 2810391
# Traitement de l'image de test n°19
# Nombre de voxels dans le masque prédit: 1381305.0
# Nombre de voxels dans le masque de référence: 1389978
# Différence de voxels: -8673.0
# TP: 1370934, FP: 10371, FN: 19044, TN: 3050899
# Traitement de l'image de test n°20
# Nombre de voxels dans le masque prédit: 1307495.0
# Nombre de voxels dans le masque de référence: 1305592
# Différence de voxels: 1903.0
# TP: 1291217, FP: 16278, FN: 14375, TN: 2946450
# Traitement de l'image de test n°21
# Nombre de voxels dans le masque prédit: 1334334.0
# Nombre de voxels dans le masque de référence: 1336435
# Différence de voxels: -2101.0
# TP: 1321516, FP: 12818, FN: 14919, TN: 2760747
# Traitement de l'image de test n°22
# Nombre de voxels dans le masque prédit: 1104891.0
# Nombre de voxels dans le masque de référence: 1093237
# Différence de voxels: 11654.0
# TP: 1081709, FP: 23182, FN: 11528, TN: 3034681
# Traitement de l'image de test n°23
# Nombre de voxels dans le masque prédit: 1105543.0
# Nombre de voxels dans le masque de référence: 1114660
# Différence de voxels: -9117.0
# TP: 1098037, FP: 7506, FN: 16623, TN: 2479334
# Traitement de l'image de test n°24
# Nombre de voxels dans le masque prédit: 1047189.0
# Nombre de voxels dans le masque de référence: 1043798
# Différence de voxels: 3391.0
# TP: 1029452, FP: 17737, FN: 14346, TN: 2539965
# Traitement de l'image de test n°25
# Nombre de voxels dans le masque prédit: 1073451.0
# Nombre de voxels dans le masque de référence: 1080382
# Différence de voxels: -6931.0
# TP: 1066795, FP: 6656, FN: 13587, TN: 2249160
# Traitement de l'image de test n°26
# Nombre de voxels dans le masque prédit: 898832.0
# Nombre de voxels dans le masque de référence: 902789
# Différence de voxels: -3957.0
# TP: 891885, FP: 6947, FN: 10904, TN: 2451359
# Traitement de l'image de test n°27
# Nombre de voxels dans le masque prédit: 1394353.0
# Nombre de voxels dans le masque de référence: 1403482
# Différence de voxels: -9129.0
# TP: 1382227, FP: 12126, FN: 21255, TN: 3609672
# Traitement de l'image de test n°28
# Nombre de voxels dans le masque prédit: 1286683.0
# Nombre de voxels dans le masque de référence: 1287593
# Différence de voxels: -910.0
# TP: 1270848, FP: 15835, FN: 16745, TN: 3721852
# Traitement de l'image de test n°29
# Nombre de voxels dans le masque prédit: 1332747.0
# Nombre de voxels dans le masque de référence: 1337731
# Différence de voxels: -4984.0
# TP: 1320560, FP: 12187, FN: 17171, TN: 3015586
# Traitement de l'image de test n°30
# Nombre de voxels dans le masque prédit: 1210578.0
# Nombre de voxels dans le masque de référence: 1216306
# Différence de voxels: -5728.0
# TP: 1197297, FP: 13281, FN: 19009, TN: 3135917
#
# --- Résultats globaux ---
# Précision : 0.9846 | Rappel : 0.9862
