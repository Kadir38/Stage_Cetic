# %%
from google.colab import drive

# 1 Monte Google Drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os
import glob
import torch
import numpy as np
import nibabel as nib
import matplotlib.pyplot as plt

# 2 Chemin du dossier extrait sur Google Drive
dossier_path = '/content/drive/MyDrive/Nouveau/Lung250M_4B/Lung250M_4B'

# 3 Lister les fichiers dans le dossier
fichiers = os.listdir(dossier_path)
print("Fichiers dans le dossier :", fichiers)

# %matplotlib inline

# 3. Lister les fichiers images et masques
images_train = sorted(glob.glob(os.path.join(dossier_path, "imagesTr", "*.nii.gz")))
labels_train = sorted(glob.glob(os.path.join(dossier_path, "masksTr", "*.nii.gz")))

# Lister les fichiers de test (imagesTs et masksTs)
images_test = sorted(glob.glob(os.path.join(dossier_path, "imagesTs", "*.nii.gz")))
labels_test = sorted(glob.glob(os.path.join(dossier_path, "masksTs", "*.nii.gz")))

# 4. Afficher le nombre d'images et de masques
print('Nombre d\'images :', len(images_train), 'Nombre de masques :', len(labels_train))
# Out:
# Fichiers dans le dossier : ['imagesTs', 'imagesTr', 'masksTs', 'masksTr']
# Nombre d'images : 174 Nombre de masques : 174

# %%
# 5 Chargement d'une image et du masque
img = nib.load(images_train[0]).get_fdata()
lbl = nib.load(labels_train[0]).get_fdata()
# Affichage des dimensions du volume
print('img shape:', img.shape, ' lbl shape:', lbl.shape)

print('img intensity min.:', np.min(img), ' max.:', np.max(img), ' unique labels:', np.unique(lbl)) # pour vérifier le nombre de classe du masque

# Visualisation de la coupe 100
slice_idx = 100

plt.figure(figsize=(8,5))
plt.subplot(1,2,1)
plt.imshow(img[slice_idx], cmap='gray', vmin=-1000, vmax=1000) # affiche le slice en niveau de gris
plt.contour(lbl[slice_idx], colors='red') # Pour le contour en rouge
plt.axis('off')
# Pour afficher uniquement le masque
plt.subplot(1,2,2)
plt.imshow(lbl[slice_idx], cmap='gray')
plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# img shape: (332, 218, 267)  lbl shape: (332, 218, 267)
# img intensity min.: -1024.0  max.: 1599.203125  unique labels: [0. 1.]

# %%
# !pip install --force-reinstall numpy monai
# Out:
# Collecting numpy
#   Downloading numpy-2.2.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 4.8 MB/s eta 0:00:00
# Collecting monai
#   Downloading monai-1.4.0-py3-none-any.whl.metadata (11 kB)
# Collecting numpy
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 6.7 MB/s eta 0:00:00
# Collecting torch>=1.9 (from monai)
#   Downloading torch-2.7.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Collecting filelock (from torch>=1.9->monai)
#   Downloading filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting typing-extensions>=4.10.0 (from torch>=1.9->monai)
#   Downloading typing_extensions-4.13.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting sympy>=1.13.3 (from torch>=1.9->monai)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch>=1.9->monai)
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch>=1.9->monai)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec (from torch>=1.9->monai)
#   Downloading fsspec-2025.3.2-py3-none-any.whl.metadata (11 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.6.77 (from torch>=1.9->monai)
#   Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.6.77 (from torch>=1.9->monai)
#   Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.6.80 (from torch>=1.9->monai)
#   Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.5.1.17 (from torch>=1.9->monai)
#   Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.6.4.1 (from torch>=1.9->monai)
#   Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.3.0.4 (from torch>=1.9->monai)
#   Downloading nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.7.77 (from torch>=1.9->monai)
#   Downloading nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.7.1.2 (from torch>=1.9->monai)
#   Downloading nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.5.4.2 (from torch>=1.9->monai)
#   Downloading nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.3 (from torch>=1.9->monai)
#   Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.26.2 (from torch>=1.9->monai)
#   Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvtx-cu12==12.6.77 (from torch>=1.9->monai)
#   Downloading nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nvjitlink-cu12==12.6.85 (from torch>=1.9->monai)
#   Downloading nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufile-cu12==1.11.1.6 (from torch>=1.9->monai)
#   Downloading nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.3.0 (from torch>=1.9->monai)
#   Downloading triton-3.3.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Collecting setuptools>=40.8.0 (from triton==3.3.0->torch>=1.9->monai)
#   Downloading setuptools-80.0.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch>=1.9->monai)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch>=1.9->monai)
#   Downloading MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Downloading monai-1.4.0-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 49.5 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 88.8 MB/s eta 0:00:00
# Downloading torch-2.7.0-cp311-cp311-manylinux_2_28_x86_64.whl (865.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 865.2/865.2 MB 1.3 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (393.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 MB 4.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 56.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 79.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.7/897.7 kB 40.8 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl (571.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.0/571.0 MB 2.5 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (200.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.2/200.2 MB 6.6 MB/s eta 0:00:00
# Downloading nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 51.9 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.5 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (158.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/158.2 MB 6.8 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl (156.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 MB 8.9 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 81.5 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.3/89.3 kB 8.8 MB/s eta 0:00:00
# Downloading triton-3.3.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (156.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.5/156.5 MB 6.4 MB/s eta 0:00:00
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 126.4 MB/s eta 0:00:00
# Downloading typing_extensions-4.13.2-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 4.3 MB/s eta 0:00:00
# Downloading filelock-3.18.0-py3-none-any.whl (16 kB)
# Downloading fsspec-2025.3.2-py3-none-any.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.4/194.4 kB 19.8 MB/s eta 0:00:00
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.9/134.9 kB 14.9 MB/s eta 0:00:00
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 90.2 MB/s eta 0:00:00
# Downloading MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23 kB)
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 41.2 MB/s eta 0:00:00
# Downloading setuptools-80.0.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 71.4 MB/s eta 0:00:00
# Installing collected packages: nvidia-cusparselt-cu12, mpmath, typing-extensions, sympy, setuptools, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, MarkupSafe, fsspec, filelock, triton, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, jinja2, nvidia-cusolver-cu12, torch, monai
#   Attempting uninstall: nvidia-cusparselt-cu12
#     Found existing installation: nvidia-cusparselt-cu12 0.6.2
#     Uninstalling nvidia-cusparselt-cu12-0.6.2:
#       Successfully uninstalled nvidia-cusparselt-cu12-0.6.2
#   Attempting uninstall: mpmath
#     Found existing installation: mpmath 1.3.0
#     Uninstalling mpmath-1.3.0:
#       Successfully uninstalled mpmath-1.3.0
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.13.2
#     Uninstalling typing_extensions-4.13.2:
#       Successfully uninstalled typing_extensions-4.13.2
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.1
#     Uninstalling sympy-1.13.1:
#       Successfully uninstalled sympy-1.13.1
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.2.0
#     Uninstalling setuptools-75.2.0:
#       Successfully uninstalled setuptools-75.2.0
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.4.127
#     Uninstalling nvidia-nvtx-cu12-12.4.127:
#       Successfully uninstalled nvidia-nvtx-cu12-12.4.127
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.21.5
#     Uninstalling nvidia-nccl-cu12-2.21.5:
#       Successfully uninstalled nvidia-nccl-cu12-2.21.5
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.4.2
#     Uninstalling networkx-3.4.2:
#       Successfully uninstalled networkx-3.4.2
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
#       Successfully uninstalled MarkupSafe-3.0.2
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.18.0
#     Uninstalling filelock-3.18.0:
#       Successfully uninstalled filelock-3.18.0
#   Attempting uninstall: triton
#     Found existing installation: triton 3.2.0
#     Uninstalling triton-3.2.0:
#       Successfully uninstalled triton-3.2.0
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 3.1.6
#     Uninstalling Jinja2-3.1.6:
#       Successfully uninstalled Jinja2-3.1.6
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
#   Attempting uninstall: torch
#     Found existing installation: torch 2.6.0+cu124
#     Uninstalling torch-2.6.0+cu124:
#       Successfully uninstalled torch-2.6.0+cu124
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# fastai 2.7.19 requires torch<2.7,>=1.10, but you have torch 2.7.0 which is incompatible.
# torchaudio 2.6.0+cu124 requires torch==2.6.0, but you have torch 2.7.0 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# torchvision 0.21.0+cu124 requires torch==2.6.0, but you have torch 2.7.0 which is incompatible.
# Successfully installed MarkupSafe-3.0.2 filelock-3.18.0 fsspec-2025.3.2 jinja2-3.1.6 monai-1.4.0 mpmath-1.3.0 networkx-3.4.2 numpy-1.26.4 nvidia-cublas-cu12-12.6.4.1 nvidia-cuda-cupti-cu12-12.6.80 nvidia-cuda-nvrtc-cu12-12.6.77 nvidia-cuda-runtime-cu12-12.6.77 nvidia-cudnn-cu12-9.5.1.17 nvidia-cufft-cu12-11.3.0.4 nvidia-cufile-cu12-1.11.1.6 nvidia-curand-cu12-10.3.7.77 nvidia-cusolver-cu12-11.7.1.2 nvidia-cusparse-cu12-12.5.4.2 nvidia-cusparselt-cu12-0.6.3 nvidia-nccl-cu12-2.26.2 nvidia-nvjitlink-cu12-12.6.85 nvidia-nvtx-cu12-12.6.77 setuptools-80.0.0 sympy-1.14.0 torch-2.7.0 triton-3.3.0 typing-extensions-4.13.2

# %%
from monai.utils import first, set_determinism

set_determinism(seed=0) # Pour fixer la seed dés le départ

# %%
# 1. Créer une liste de dictionnaires pour les paires image-masque d'entraînement
train_data_dicts = [
    {"image": image_name, "label": label_name}
    for image_name, label_name in zip(images_train, labels_train)
]

# 2. Diviser les données d'entraînement en train/val (par exemple 85%/15%)
train_split = int(0.85 * len(train_data_dicts))
train_files = train_data_dicts[:train_split]
val_files = train_data_dicts[train_split:]

# 3. Créer une liste de dictionnaires pour les données de test
test_files = [
    {"image": image_name, "label": label_name}
    for image_name, label_name in zip(images_test, labels_test)
]

# 4. Afficher le nombre de fichiers dans chaque ensemble
print(f"Entraînement : {len(train_files)} fichiers")
print(f"Validation : {len(val_files)} fichiers")
print(f"Test : {len(test_files)} fichiers")
# Out:
# Entraînement : 147 fichiers
# Validation : 27 fichiers
# Test : 30 fichiers

# %%
from monai.transforms import (
    AsDiscrete,
    AsDiscreted,
    EnsureChannelFirstd,
    Compose,
    CropForegroundd,
    LoadImaged,
    Orientationd,
    RandAffined,
    RandFlipd,
    RandScaleIntensityd,
    RandShiftIntensityd,
    RandSpatialCropd,
    SaveImaged,
    ScaleIntensityRanged,
    Spacingd,
    Invertd,
)
from monai.data import CacheDataset, DataLoader, Dataset, decollate_batch

# Transformations
train_transforms = Compose([
    LoadImaged(keys=["image", "label"]),
    EnsureChannelFirstd(keys=["image", "label"]),
    ScaleIntensityRanged(keys=["image"], a_min=-1000, a_max=1000, b_min=0.0, b_max=1.0, clip=True),
    #ScaleIntensityRanged(keys=["label"], a_min=0, a_max=255, b_min=0.0, b_max=1.0, clip=True),
    CropForegroundd(keys=["image", "label"], source_key="image"),
    Orientationd(keys=["image", "label"], axcodes="PLS"),
    Spacingd(keys=["image", "label"], pixdim=(1.5, 1.5, 2.0), mode=("bilinear", "nearest")),
    RandSpatialCropd(keys=["image", "label"], roi_size=[96, 96, 96], random_size=False),
    RandAffined(keys=["image", "label"], mode=('bilinear', 'nearest'), prob=1.0, spatial_size=(96, 96, 96), rotate_range=(0, 0, np.pi/15), scale_range=(0.1, 0.1, 0.1)),
    RandFlipd(keys=["image", "label"], prob=0.25, spatial_axis=0),
    RandFlipd(keys=["image", "label"], prob=0.25, spatial_axis=1),
    RandFlipd(keys=["image", "label"], prob=0.25, spatial_axis=2),
    RandScaleIntensityd(keys="image", factors=0.1, prob=1.0),
    RandShiftIntensityd(keys="image", offsets=0.1, prob=1.0),
])

val_transforms = Compose([
    LoadImaged(keys=["image", "label"]),
    EnsureChannelFirstd(keys=["image", "label"]),
    ScaleIntensityRanged(keys=["image"], a_min=-1000, a_max=1000, b_min=0.0, b_max=1.0, clip=True),
    #ScaleIntensityRanged(keys=["label"], a_min=0, a_max=255, b_min=0.0, b_max=1.0, clip=True),
    CropForegroundd(keys=["image", "label"], source_key="image"),
    Orientationd(keys=["image", "label"], axcodes="PLS"),
    Spacingd(keys=["image", "label"], pixdim=(1.5, 1.5, 2.0), mode=("bilinear", "nearest")),
])

test_transforms = Compose([
    LoadImaged(keys=["image", "label"]),
    EnsureChannelFirstd(keys=["image", "label"]),
    ScaleIntensityRanged(keys=["image"], a_min=-1000, a_max=1000, b_min=0.0, b_max=1.0, clip=True),
    #ScaleIntensityRanged(keys=["label"], a_min=0, a_max=255, b_min=0.0, b_max=1.0, clip=True),
    CropForegroundd(keys=["image", "label"], source_key="image"),
    Orientationd(keys=["image", "label"], axcodes="PLS"),
    Spacingd(keys=["image", "label"], pixdim=(1.5, 1.5, 2.0), mode=("bilinear", "nearest")),
])
# Out:
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:321: FutureWarning: monai.transforms.croppad.dictionary CropForegroundd.__init__:allow_smaller: Current default value of argument `allow_smaller=True` has been deprecated since version 1.2. It will be changed to `allow_smaller=False` in version 1.5.
#   warn_deprecated(argname, msg, warning_category)

# %%
# Visualisation de l'image après les transformation
sample_ds = Dataset(data=train_files, transform=train_transforms)
sample_dataloader = DataLoader(sample_ds, batch_size=1)
sample_batch = first(sample_dataloader)

img, lbl = sample_batch["image"][0][0], sample_batch["label"][0][0]
print(f"img shape: {img.shape}, lbl shape: {lbl.shape}")

slice_idx = 64
plt.figure(figsize=(8,5))
plt.subplot(1,2,1)
plt.imshow(img[:,:,slice_idx], cmap='gray')
plt.contour(lbl[:,:,slice_idx], colors='red')
plt.axis('off')
plt.subplot(1,2,2)
plt.imshow(lbl[:,:,slice_idx], cmap='gray')
plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# img shape: torch.Size([96, 96, 96]), lbl shape: torch.Size([96, 96, 96])

# %% [markdown]
# Maintenant, nous créons des dataloaders pour les jeux de données d'entraînement et de validation en utilisant la bibliothèque MONAI. La classe `CacheDataset` est utilisée pour créer les jeux de données d'entraînement et de validation en spécifiant les chemins des fichiers, les transformations de prétraitement, le taux de cache et le nombre de travailleurs pour le traitement parallèle. C'est une classe de la bibliothèque MONAI qui permet de créer un jeu de données à partir d'une liste de fichiers de données et d'une fonction de transformation. Elle peut être utilisée pour mettre en cache les données prétraitées en mémoire afin d'y accéder plus rapidement pendant l'entraînement, ce qui peut être particulièrement utile pour de grands jeux de données.

# %%
# Créer les datasets avec CacheDataset
train_ds = CacheDataset(data=train_files, transform=train_transforms, cache_rate=1.0)
val_ds = CacheDataset(data=val_files, transform=val_transforms, cache_rate=1.0)
test_ds = CacheDataset(data=test_files, transform=test_transforms, cache_rate=1.0)

# Créer les DataLoaders
train_loader = DataLoader(train_ds, batch_size=2, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=1)
test_loader = DataLoader(test_ds, batch_size=1)
# Out:
# Loading dataset: 100%|██████████| 147/147 [10:23<00:00,  4.24s/it]
# Loading dataset: 100%|██████████| 27/27 [01:54<00:00,  4.23s/it]
# Loading dataset: 100%|██████████| 30/30 [02:22<00:00,  4.76s/it]

# %%
from monai.losses import DiceLoss
from monai.metrics import DiceMetric
from monai.networks.nets import UNet
from monai.networks.layers import Norm

device = torch.device("cuda:0")
model = UNet(
    spatial_dims=3,
    in_channels=1,
    out_channels=2,
    channels=(16, 32, 64, 128, 256),
    strides=(2, 2, 2, 2),
    num_res_units=2,
    norm=Norm.BATCH,
).to(device)
loss_function = DiceLoss(to_onehot_y=True, softmax=True)
optimizer = torch.optim.Adam(model.parameters(), 1e-4)
dice_metric = DiceMetric(include_background=False, reduction="mean")

# %%
from monai.inferers import sliding_window_inference

# Define hyperparameters
max_epochs = 100
val_interval = 2
best_metric = -1
best_metric_epoch = -1
epoch_loss_values = []
metric_values = []

# Define post-processing transforms
post_pred = Compose([AsDiscrete(argmax=True, to_onehot=2)])
post_label = Compose([AsDiscrete(to_onehot=2)])

# Training loop
for epoch in range(max_epochs):
    print("-" * 10)
    print(f"epoch {epoch + 1}/{max_epochs}")
    model.train()
    epoch_loss = 0
    step = 0
    for batch_data in train_loader:
        step += 1
        inputs, labels = batch_data["image"].to(device), batch_data["label"].to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = loss_function(outputs, labels)
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
        print(f"{step}/{len(train_ds) // train_loader.batch_size}, train_loss: {loss.item():.4f}")
    epoch_loss /= step
    epoch_loss_values.append(epoch_loss)

    print(f"epoch {epoch + 1} average loss: {epoch_loss:.4f}")

    if (epoch + 1) % val_interval == 0:
        model.eval()
        with torch.no_grad():
            val_sample = next(iter(val_loader))
            print("Label shape :", val_sample["label"].shape)
            print("Label unique values :", torch.unique(val_sample["label"]))
            print("Image shape :", val_sample["image"].shape)
            for val_data in val_loader:
                val_inputs, val_labels = val_data["image"].to(device), val_data["label"].to(device),
                val_outputs = sliding_window_inference(val_inputs, (96, 96, 96), 1, model)

                val_outputs = [post_pred(i) for i in decollate_batch(val_outputs)]
                val_labels = [post_label(i) for i in decollate_batch(val_labels)]

                # compute metric for current iteration
                dice_metric(y_pred=val_outputs, y=val_labels)

            # aggregate the final mean dice result
            metric = dice_metric.aggregate().item()

            # reset the status for next validation round
            dice_metric.reset()

            metric_values.append(metric)
            if metric > best_metric:
                best_metric = metric
                best_metric_epoch = epoch + 1
                torch.save(model.state_dict(), "best_metric_model.pth")
                print("saved new best metric model")
            print(
                f"current epoch: {epoch + 1} current mean dice: {metric:.4f}"
                f"\nbest mean dice: {best_metric:.4f} "
                f"at epoch: {best_metric_epoch}"
            )
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# 15/73, train_loss: 0.0169
# 16/73, train_loss: 0.0200
# 17/73, train_loss: 0.0328
# 18/73, train_loss: 0.0177
# 19/73, train_loss: 0.0278
# 20/73, train_loss: 0.0232
# 21/73, train_loss: 0.0207
# 22/73, train_loss: 0.0160
# 23/73, train_loss: 0.0157
# 24/73, train_loss: 0.0167
# 25/73, train_loss: 0.0309
# 26/73, train_loss: 0.0167
# 27/73, train_loss: 0.0217
# 28/73, train_loss: 0.0181
# 29/73, train_loss: 0.0170
# 30/73, train_loss: 0.0176
# 31/73, train_loss: 0.0266
# 32/73, train_loss: 0.0208
# 33/73, train_loss: 0.0227
# 34/73, train_loss: 0.0188
# 35/73, train_loss: 0.0187
# 36/73, train_loss: 0.0153
# 37/73, train_loss: 0.0517
# 38/73, train_loss: 0.0301
# 39/73, train_loss: 0.0187
# 40/73, train_loss: 0.0261
# 41/73, train_loss: 0.0181
# 42/73, train_loss: 0.0151
# 43/73, train_loss: 0.0176
# 44/73, train_loss: 0.0195
# 45/73, train_loss: 0.0187
# 46/73, train_loss: 0.0206
# 47/73, train_loss: 0.0135
# 48/73, train_loss: 0.0249
# 49/73, train_loss: 0.0176
# 50/73, train_loss: 0.0198
# 51/73, train_loss: 0.0217
# 52/73, train_loss: 0.0258
# 53/73, train_loss: 0.0161
# 54/73, train_loss: 0.0190
# 55/73, train_loss: 0.0210
# 56/73, train_loss: 0.0155
# 57/73, train_loss: 0.0173
# 58/73, train_loss: 0.0194
# 59/73, train_loss: 0.0232
# 60/73, train_loss: 0.0184
# 61/73, train_loss: 0.0173
# 62/73, train_loss: 0.0157
# 63/73, train_loss: 0.0180
# 64/73, train_loss: 0.0207
# 65/73, train_loss: 0.0246
# 66/73, train_loss: 0.2421
# 67/73, train_loss: 0.0188
# 68/73, train_loss: 0.0457
# 69/73, train_loss: 0.0181
# 70/73, train_loss: 0.0182
# 71/73, train_loss: 0.0162
# 72/73, train_loss: 0.0182
# 73/73, train_loss: 0.0192
# 74/73, train_loss: 0.0189
# epoch 38 average loss: 0.0241
# Label shape : torch.Size([1, 1, 141, 211, 132])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 141, 211, 132])
# current epoch: 38 current mean dice: 0.9701
# best mean dice: 0.9764 at epoch: 30
# ----------
# epoch 39/100
# 1/73, train_loss: 0.0176
# 2/73, train_loss: 0.0281
# 3/73, train_loss: 0.0174
# 4/73, train_loss: 0.0178
# 5/73, train_loss: 0.0213
# 6/73, train_loss: 0.0261
# 7/73, train_loss: 0.0192
# 8/73, train_loss: 0.0168
# 9/73, train_loss: 0.0193
# 10/73, train_loss: 0.0190
# 11/73, train_loss: 0.0170
# 12/73, train_loss: 0.0215
# 13/73, train_loss: 0.0132
# 14/73, train_loss: 0.0166
# 15/73, train_loss: 0.0210
# 16/73, train_loss: 0.0164
# 17/73, train_loss: 0.0267
# 18/73, train_loss: 0.0188
# 19/73, train_loss: 0.0244
# 20/73, train_loss: 0.0240
# 21/73, train_loss: 0.0138
# 22/73, train_loss: 0.0220
# 23/73, train_loss: 0.0154
# 24/73, train_loss: 0.0151
# 25/73, train_loss: 0.0174
# 26/73, train_loss: 0.0154
# 27/73, train_loss: 0.0148
# 28/73, train_loss: 0.0199
# 29/73, train_loss: 0.0150
# 30/73, train_loss: 0.0171
# 31/73, train_loss: 0.0226
# 32/73, train_loss: 0.0197
# 33/73, train_loss: 0.0265
# 34/73, train_loss: 0.0147
# 35/73, train_loss: 0.0172
# 36/73, train_loss: 0.0158
# 37/73, train_loss: 0.0194
# 38/73, train_loss: 0.0182
# 39/73, train_loss: 0.0154
# 40/73, train_loss: 0.0303
# 41/73, train_loss: 0.0131
# 42/73, train_loss: 0.0190
# 43/73, train_loss: 0.0182
# 44/73, train_loss: 0.0144
# 45/73, train_loss: 0.0223
# 46/73, train_loss: 0.0316
# 47/73, train_loss: 0.0169
# 48/73, train_loss: 0.0192
# 49/73, train_loss: 0.0140
# 50/73, train_loss: 0.0163
# 51/73, train_loss: 0.0234
# 52/73, train_loss: 0.0170
# 53/73, train_loss: 0.0189
# 54/73, train_loss: 0.0176
# 55/73, train_loss: 0.0175
# 56/73, train_loss: 0.0200
# 57/73, train_loss: 0.0167
# 58/73, train_loss: 0.2565
# 59/73, train_loss: 0.0146
# 60/73, train_loss: 0.0199
# 61/73, train_loss: 0.0171
# 62/73, train_loss: 0.0262
# 63/73, train_loss: 0.1949
# 64/73, train_loss: 0.0193
# 65/73, train_loss: 0.0291
# 66/73, train_loss: 0.0199
# 67/73, train_loss: 0.0243
# 68/73, train_loss: 0.0461
# 69/73, train_loss: 0.0291
# 70/73, train_loss: 0.0233
# 71/73, train_loss: 0.0229
# 72/73, train_loss: 0.0303
# 73/73, train_loss: 0.0194
# 74/73, train_loss: 0.0163
# epoch 39 average loss: 0.0256
# ----------
# epoch 40/100
# 1/73, train_loss: 0.0173
# 2/73, train_loss: 0.0247
# 3/73, train_loss: 0.0196
# 4/73, train_loss: 0.0194
# 5/73, train_loss: 0.0191
# 6/73, train_loss: 0.0279
# 7/73, train_loss: 0.0201
# 8/73, train_loss: 0.0220
# 9/73, train_loss: 0.0163
# 10/73, train_loss: 0.0246
# 11/73, train_loss: 0.0157
# 12/73, train_loss: 0.0400
# 13/73, train_loss: 0.0159
# 14/73, train_loss: 0.0173
# 15/73, train_loss: 0.0314
# 16/73, train_loss: 0.0149
# 17/73, train_loss: 0.0161
# 18/73, train_loss: 0.0257
# 19/73, train_loss: 0.0187
# 20/73, train_loss: 0.0136
# 21/73, train_loss: 0.0544
# 22/73, train_loss: 0.0169
# 23/73, train_loss: 0.2223
# 24/73, train_loss: 0.2987
# 25/73, train_loss: 0.0204
# 26/73, train_loss: 0.0179
# 27/73, train_loss: 0.0216
# 28/73, train_loss: 0.0164
# 29/73, train_loss: 0.0286
# 30/73, train_loss: 0.0166
# 31/73, train_loss: 0.0163
# 32/73, train_loss: 0.0352
# 33/73, train_loss: 0.0211
# 34/73, train_loss: 0.0185
# 35/73, train_loss: 0.0184
# 36/73, train_loss: 0.0169
# 37/73, train_loss: 0.0499
# 38/73, train_loss: 0.0200
# 39/73, train_loss: 0.0255
# 40/73, train_loss: 0.0173
# 41/73, train_loss: 0.0215
# 42/73, train_loss: 0.0261
# 43/73, train_loss: 0.0170
# 44/73, train_loss: 0.0193
# 45/73, train_loss: 0.0179
# 46/73, train_loss: 0.0164
# 47/73, train_loss: 0.0150
# 48/73, train_loss: 0.0167
# 49/73, train_loss: 0.0176
# 50/73, train_loss: 0.0236
# 51/73, train_loss: 0.0397
# 52/73, train_loss: 0.0187
# 53/73, train_loss: 0.0179
# 54/73, train_loss: 0.0208
# 55/73, train_loss: 0.0166
# 56/73, train_loss: 0.0167
# 57/73, train_loss: 0.0149
# 58/73, train_loss: 0.0191
# 59/73, train_loss: 0.0186
# 60/73, train_loss: 0.0176
# 61/73, train_loss: 0.0453
# 62/73, train_loss: 0.0146
# 63/73, train_loss: 0.0210
# 64/73, train_loss: 0.0896
# 65/73, train_loss: 0.0185
# 66/73, train_loss: 0.0371
# 67/73, train_loss: 0.0220
# 68/73, train_loss: 0.0377
# 69/73, train_loss: 0.0235
# 70/73, train_loss: 0.0187
# 71/73, train_loss: 0.0249
# 72/73, train_loss: 0.0185
# 73/73, train_loss: 0.0182
# 74/73, train_loss: 0.0160
# epoch 40 average loss: 0.0293
# Label shape : torch.Size([1, 1, 141, 211, 132])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 141, 211, 132])
# current epoch: 40 current mean dice: 0.9756
# best mean dice: 0.9764 at epoch: 30
# ----------
# epoch 41/100
# 1/73, train_loss: 0.0326
# 2/73, train_loss: 0.0359
# 3/73, train_loss: 0.0213
# 4/73, train_loss: 0.0243
# 5/73, train_loss: 0.0174
# 6/73, train_loss: 0.0375
# 7/73, train_loss: 0.0193
# 8/73, train_loss: 0.0188
# 9/73, train_loss: 0.0189
# 10/73, train_loss: 0.0192
# 11/73, train_loss: 0.0172
# 12/73, train_loss: 0.0193
# 13/73, train_loss: 0.0193
# 14/73, train_loss: 0.0156
# 15/73, train_loss: 0.0167
# 16/73, train_loss: 0.0333
# 17/73, train_loss: 0.0157
# 18/73, train_loss: 0.0183
# 19/73, train_loss: 0.0228
# 20/73, train_loss: 0.0164
# 21/73, train_loss: 0.0177
# 22/73, train_loss: 0.0168
# 23/73, train_loss: 0.0195
# 24/73, train_loss: 0.0182
# 25/73, train_loss: 0.0238
# 26/73, train_loss: 0.0430
# 27/73, train_loss: 0.0247
# 28/73, train_loss: 0.0207
# 29/73, train_loss: 0.0174
# 30/73, train_loss: 0.0231
# 31/73, train_loss: 0.0426
# 32/73, train_loss: 0.0243
# 33/73, train_loss: 0.0359
# 34/73, train_loss: 0.0168
# 35/73, train_loss: 0.0250
# 36/73, train_loss: 0.0351
# 37/73, train_loss: 0.0214
# 38/73, train_loss: 0.0188
# 39/73, train_loss: 0.0173
# 40/73, train_loss: 0.0540
# 41/73, train_loss: 0.0240
# 42/73, train_loss: 0.0190
# 43/73, train_loss: 0.0170
# 44/73, train_loss: 0.0163
# 45/73, train_loss: 0.0178
# 46/73, train_loss: 0.0169
# 47/73, train_loss: 0.0191
# 48/73, train_loss: 0.0241
# 49/73, train_loss: 0.0145
# 50/73, train_loss: 0.0251
# 51/73, train_loss: 0.0162
# 52/73, train_loss: 0.0174
# 53/73, train_loss: 0.0222
# 54/73, train_loss: 0.0194
# 55/73, train_loss: 0.0180
# 56/73, train_loss: 0.0150
# 57/73, train_loss: 0.0131
# 58/73, train_loss: 0.0141
# 59/73, train_loss: 0.0209
# 60/73, train_loss: 0.0370
# 61/73, train_loss: 0.0159
# 62/73, train_loss: 0.0194
# 63/73, train_loss: 0.0295
# 64/73, train_loss: 0.0173
# 65/73, train_loss: 0.0173
# 66/73, train_loss: 0.0152
# 67/73, train_loss: 0.0196
# 68/73, train_loss: 0.0196
# 69/73, train_loss: 0.0154
# 70/73, train_loss: 0.0210
# 71/73, train_loss: 0.0275
# 72/73, train_loss: 0.0158
# 73/73, train_loss: 0.0171
# 74/73, train_loss: 0.0177
# epoch 41 average loss: 0.0218
# ----------
# epoch 42/100
# 1/73, train_loss: 0.0179
# 2/73, train_loss: 0.0164
# 3/73, train_loss: 0.0230
# 4/73, train_loss: 0.0338
# 5/73, train_loss: 0.0200
# 6/73, train_loss: 0.0156
# 7/73, train_loss: 0.0215
# 8/73, train_loss: 0.0180
# 9/73, train_loss: 0.0309
# 10/73, train_loss: 0.0166
# 11/73, train_loss: 0.0181
# 12/73, train_loss: 0.0205
# 13/73, train_loss: 0.0151
# 14/73, train_loss: 0.0160
# 15/73, train_loss: 0.0178
# 16/73, train_loss: 0.0165
# 17/73, train_loss: 0.0145
# 18/73, train_loss: 0.0208
# 19/73, train_loss: 0.0149
# 20/73, train_loss: 0.0156
# 21/73, train_loss: 0.0171
# 22/73, train_loss: 0.0213
# 23/73, train_loss: 0.0155
# 24/73, train_loss: 0.0164
# 25/73, train_loss: 0.0133
# 26/73, train_loss: 0.0202
# 27/73, train_loss: 0.0162
# 28/73, train_loss: 0.0151
# 29/73, train_loss: 0.0196
# 30/73, train_loss: 0.0175
# 31/73, train_loss: 0.0152
# 32/73, train_loss: 0.0150
# 33/73, train_loss: 0.0254
# 34/73, train_loss: 0.0198
# 35/73, train_loss: 0.0191
# 36/73, train_loss: 0.0157
# 37/73, train_loss: 0.0227
# 38/73, train_loss: 0.0223
# 39/73, train_loss: 0.0171
# 40/73, train_loss: 0.0175
# 41/73, train_loss: 0.0181
# 42/73, train_loss: 0.0163
# 43/73, train_loss: 0.0200
# 44/73, train_loss: 0.0194
# 45/73, train_loss: 0.0339
# 46/73, train_loss: 0.0207
# 47/73, train_loss: 0.0217
# 48/73, train_loss: 0.2002
# 49/73, train_loss: 0.0206
# 50/73, train_loss: 0.0237
# 51/73, train_loss: 0.0165
# 52/73, train_loss: 0.0203
# 53/73, train_loss: 0.0178
# 54/73, train_loss: 0.0168
# 55/73, train_loss: 0.0135
# 56/73, train_loss: 0.0340
# 57/73, train_loss: 0.0200
# 58/73, train_loss: 0.0172
# 59/73, train_loss: 0.0141
# 60/73, train_loss: 0.0470
# 61/73, train_loss: 0.0165
# 62/73, train_loss: 0.0274
# 63/73, train_loss: 0.0198
# 64/73, train_loss: 0.0168
# 65/73, train_loss: 0.0155
# 66/73, train_loss: 0.0192
# 67/73, train_loss: 0.0210
# 68/73, train_loss: 0.0205
# 69/73, train_loss: 0.0184
# 70/73, train_loss: 0.0153
# 71/73, train_loss: 0.0194
# 72/73, train_loss: 0.0174
# 73/73, train_loss: 0.0263
# 74/73, train_loss: 0.0142
# epoch 42 average loss: 0.0220
# Label shape : torch.Size([1, 1, 141, 211, 132])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 141, 211, 132])
# saved new best metric model
# current epoch: 42 current mean dice: 0.9769
# best mean dice: 0.9769 at epoch: 42
# ----------
# epoch 43/100
# 1/73, train_loss: 0.0285
# 2/73, train_loss: 0.0175
# 3/73, train_loss: 0.0166
# 4/73, train_loss: 0.0179
# 5/73, train_loss: 0.0162
# 6/73, train_loss: 0.0173
# 7/73, train_loss: 0.0146
# 8/73, train_loss: 0.0196
# 9/73, train_loss: 0.0166
# 10/73, train_loss: 0.0192
# 11/73, train_loss: 0.0161
# 12/73, train_loss: 0.0192
# 13/73, train_loss: 0.0172
# 14/73, train_loss: 0.0200
# 15/73, train_loss: 0.0246
# 16/73, train_loss: 0.0182
# 17/73, train_loss: 0.0158
# 18/73, train_loss: 0.0170
# 19/73, train_loss: 0.0169
# 20/73, train_loss: 0.0178
# 21/73, train_loss: 0.0156
# 22/73, train_loss: 0.0131
# 23/73, train_loss: 0.0245
# 24/73, train_loss: 0.0215
# 25/73, train_loss: 0.0163
# 26/73, train_loss: 0.0156
# 27/73, train_loss: 0.0176
# 28/73, train_loss: 0.0202
# 29/73, train_loss: 0.0159
# 30/73, train_loss: 0.0173
# 31/73, train_loss: 0.0151
# 32/73, train_loss: 0.0219
# 33/73, train_loss: 0.0133
# 34/73, train_loss: 0.0311
# 35/73, train_loss: 0.0401
# 36/73, train_loss: 0.0190
# 37/73, train_loss: 0.0204
# 38/73, train_loss: 0.0136
# 39/73, train_loss: 0.0140
# 40/73, train_loss: 0.0182
# 41/73, train_loss: 0.0109
# 42/73, train_loss: 0.0202
# 43/73, train_loss: 0.0245
# 44/73, train_loss: 0.0203
# 45/73, train_loss: 0.0212
# 46/73, train_loss: 0.0164
# 47/73, train_loss: 0.0191
# 48/73, train_loss: 0.0337
# 49/73, train_loss: 0.0208
# 50/73, train_loss: 0.0197
# 51/73, train_loss: 0.0320
# 52/73, train_loss: 0.0203
# 53/73, train_loss: 0.0201
# 54/73, train_loss: 0.0176
# 55/73, train_loss: 0.0169
# 56/73, train_loss: 0.0287
# 57/73, train_loss: 0.0149
# 58/73, train_loss: 0.0235
# 59/73, train_loss: 0.0229
# 60/73, train_loss: 0.0243
# 61/73, train_loss: 0.0165
# 62/73, train_loss: 0.0174
# 63/73, train_loss: 0.0148
# 64/73, train_loss: 0.0151
# 65/73, train_loss: 0.0235
# 66/73, train_loss: 0.0156
# 67/73, train_loss: 0.0455
# 68/73, train_loss: 0.0190
# 69/73, train_loss: 0.0268
# 70/73, train_loss: 0.0265
# 71/73, train_loss: 0.0183
# 72/73, train_loss: 0.0273
# 73/73, train_loss: 0.0267
# 74/73, train_loss: 0.0324
# epoch 43 average loss: 0.0203
# ----------
# epoch 44/100
# 1/73, train_loss: 0.0193
# 2/73, train_loss: 0.0201
# 3/73, train_loss: 0.0225
# 4/73, train_loss: 0.0154
# 5/73, train_loss: 0.0197
# 6/73, train_loss: 0.0163
# 7/73, train_loss: 0.0162
# 8/73, train_loss: 0.0149
# 9/73, train_loss: 0.0197
# 10/73, train_loss: 0.0155
# 11/73, train_loss: 0.0265
# 12/73, train_loss: 0.0307
# 13/73, train_loss: 0.0236
# 14/73, train_loss: 0.0293
# 15/73, train_loss: 0.0151
# 16/73, train_loss: 0.0149
# 17/73, train_loss: 0.1717
# 18/73, train_loss: 0.0183
# 19/73, train_loss: 0.0203
# 20/73, train_loss: 0.0186
# 21/73, train_loss: 0.0169
# 22/73, train_loss: 0.0348
# 23/73, train_loss: 0.0167
# 24/73, train_loss: 0.0147
# 25/73, train_loss: 0.0159
# 26/73, train_loss: 0.0163
# 27/73, train_loss: 0.0144
# 28/73, train_loss: 0.0171
# 29/73, train_loss: 0.0177
# 30/73, train_loss: 0.0201
# 31/73, train_loss: 0.0273
# 32/73, train_loss: 0.0238
# 33/73, train_loss: 0.0163
# 34/73, train_loss: 0.0972
# 35/73, train_loss: 0.0210
# 36/73, train_loss: 0.0241
# 37/73, train_loss: 0.0192
# 38/73, train_loss: 0.0155
# 39/73, train_loss: 0.0825
# 40/73, train_loss: 0.0185
# 41/73, train_loss: 0.0133
# 42/73, train_loss: 0.0395
# 43/73, train_loss: 0.0169
# 44/73, train_loss: 0.0227
# 45/73, train_loss: 0.0210
# 46/73, train_loss: 0.0210
# 47/73, train_loss: 0.0154
# 48/73, train_loss: 0.0219
# 49/73, train_loss: 0.0189
# 50/73, train_loss: 0.0182
# 51/73, train_loss: 0.0374
# 52/73, train_loss: 0.0202
# 53/73, train_loss: 0.0184
# 54/73, train_loss: 0.0193
# 55/73, train_loss: 0.0245
# 56/73, train_loss: 0.0154
# 57/73, train_loss: 0.0149
# 58/73, train_loss: 0.0176
# 59/73, train_loss: 0.0232
# 60/73, train_loss: 0.0162
# 61/73, train_loss: 0.0213
# 62/73, train_loss: 0.0216
# 63/73, train_loss: 0.0224
# 64/73, train_loss: 0.0153
# 65/73, train_loss: 0.0186
# 66/73, train_loss: 0.0188
# 67/73, train_loss: 0.0193
# 68/73, train_loss: 0.0133
# 69/73, train_loss: 0.0185
# 70/73, train_loss: 0.0130
# 71/73, train_loss: 0.0160
# 72/73, train_loss: 0.0181
# 73/73, train_loss: 0.0216
# 74/73, train_loss: 0.0195
# epoch 44 average loss: 0.0237
# Label shape : torch.Size([1, 1, 141, 211, 132])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 141, 211, 132])
# current epoch: 44 current mean dice: 0.9736
# best mean dice: 0.9769 at epoch: 42
# ----------
# epoch 45/100
# 1/73, train_loss: 0.0462
# 2/73, train_loss: 0.0213
# 3/73, train_loss: 0.0418
# 4/73, train_loss: 0.0189
# 5/73, train_loss: 0.0214
# 6/73, train_loss: 0.0205
# 7/73, train_loss: 0.0149
# 8/73, train_loss: 0.0172
# 9/73, train_loss: 0.0205
# 10/73, train_loss: 0.0175
# 11/73, train_loss: 0.0209
# 12/73, train_loss: 0.0176
# 13/73, train_loss: 0.0195
# 14/73, train_loss: 0.0220
# 15/73, train_loss: 0.0151
# 16/73, train_loss: 0.0193
# 17/73, train_loss: 0.0143
# 18/73, train_loss: 0.0194
# 19/73, train_loss: 0.0148
# 20/73, train_loss: 0.0196
# 21/73, train_loss: 0.0169
# 22/73, train_loss: 0.0160
# 23/73, train_loss: 0.0190
# 24/73, train_loss: 0.0170
# 25/73, train_loss: 0.0258
# 26/73, train_loss: 0.0161
# 27/73, train_loss: 0.0186
# 28/73, train_loss: 0.0178
# 29/73, train_loss: 0.0144
# 30/73, train_loss: 0.0154
# 31/73, train_loss: 0.0170
# 32/73, train_loss: 0.0128
# 33/73, train_loss: 0.0219
# 34/73, train_loss: 0.0191
# 35/73, train_loss: 0.0162
# 36/73, train_loss: 0.0177
# 37/73, train_loss: 0.0165
# 38/73, train_loss: 0.0177
# 39/73, train_loss: 0.0346
# 40/73, train_loss: 0.0236
# 41/73, train_loss: 0.0219
# 42/73, train_loss: 0.0193
# 43/73, train_loss: 0.0180
# 44/73, train_loss: 0.0240
# 45/73, train_loss: 0.0142
# 46/73, train_loss: 0.0199
# 47/73, train_loss: 0.0213
# 48/73, train_loss: 0.0145
# 49/73, train_loss: 0.0308
# 50/73, train_loss: 0.0155
# 51/73, train_loss: 0.0182
# 52/73, train_loss: 0.0198
# 53/73, train_loss: 0.0173
# 54/73, train_loss: 0.0186
# 55/73, train_loss: 0.0153
# 56/73, train_loss: 0.0182
# 57/73, train_loss: 0.0289
# 58/73, train_loss: 0.0155
# 59/73, train_loss: 0.0279
# 60/73, train_loss: 0.2469
# 61/73, train_loss: 0.0178
# 62/73, train_loss: 0.0189
# 63/73, train_loss: 0.0166
# 64/73, train_loss: 0.0181
# 65/73, train_loss: 0.0550
# 66/73, train_loss: 0.0158
# 67/73, train_loss: 0.0173
# 68/73, train_loss: 0.0158
# 69/73, train_loss: 0.0231
# 70/73, train_loss: 0.0169
# 71/73, train_loss: 0.0156
# 72/73, train_loss: 0.0202
# 73/73, train_loss: 0.0158
# 74/73, train_loss: 0.0170
# epoch 45 average loss: 0.0231
# ----------
# epoch 46/100
# 1/73, train_loss: 0.0162
# 2/73, train_loss: 0.0140
# 3/73, train_loss: 0.0169
# 4/73, train_loss: 0.0162
# 5/73, train_loss: 0.0215
# 6/73, train_loss: 0.0195
# 7/73, train_loss: 0.0176
# 8/73, train_loss: 0.0170
# 9/73, train_loss: 0.0163
# 10/73, train_loss: 0.0259
# 11/73, train_loss: 0.0143
# 12/73, train_loss: 0.0182
# 13/73, train_loss: 0.0229
# 14/73, train_loss: 0.0265
# 15/73, train_loss: 0.0609
# 16/73, train_loss: 0.0148
# 17/73, train_loss: 0.0179
# 18/73, train_loss: 0.0221
# 19/73, train_loss: 0.0154
# 20/73, train_loss: 0.0231
# 21/73, train_loss: 0.0164
# 22/73, train_loss: 0.0218
# 23/73, train_loss: 0.0452
# 24/73, train_loss: 0.0217
# 25/73, train_loss: 0.0191
# 26/73, train_loss: 0.0172
# 27/73, train_loss: 0.0197
# 28/73, train_loss: 0.0178
# 29/73, train_loss: 0.0357
# 30/73, train_loss: 0.0154
# 31/73, train_loss: 0.0387
# 32/73, train_loss: 0.0169
# 33/73, train_loss: 0.0164
# 34/73, train_loss: 0.0146
# 35/73, train_loss: 0.0204
# 36/73, train_loss: 0.0160
# 37/73, train_loss: 0.0277
# 38/73, train_loss: 0.0167
# 39/73, train_loss: 0.0166
# 40/73, train_loss: 0.0199
# 41/73, train_loss: 0.0201
# 42/73, train_loss: 0.0184
# 43/73, train_loss: 0.0191
# 44/73, train_loss: 0.0176
# 45/73, train_loss: 0.0159
# 46/73, train_loss: 0.0269
# 47/73, train_loss: 0.0200
# 48/73, train_loss: 0.0150
# 49/73, train_loss: 0.0192
# 50/73, train_loss: 0.0149
# 51/73, train_loss: 0.0162
# 52/73, train_loss: 0.0235
# 53/73, train_loss: 0.0162
# 54/73, train_loss: 0.0154
# 55/73, train_loss: 0.0181
# 56/73, train_loss: 0.0191
# 57/73, train_loss: 0.1603
# 58/73, train_loss: 0.0152
# 59/73, train_loss: 0.0212
# 60/73, train_loss: 0.0164
# 61/73, train_loss: 0.0154
# 62/73, train_loss: 0.0233
# 63/73, train_loss: 0.0142
# 64/73, train_loss: 0.0216
# 65/73, train_loss: 0.0224
# 66/73, train_loss: 0.0379
# 67/73, train_loss: 0.0261
# 68/73, train_loss: 0.0179
# 69/73, train_loss: 0.0175
# 70/73, train_loss: 0.0176
# 71/73, train_loss: 0.0137
# 72/73, train_loss: 0.0186
# 73/73, train_loss: 0.0307
# 74/73, train_loss: 0.0168
# epoch 46 average loss: 0.0223
# Label shape : torch.Size([1, 1, 141, 211, 132])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 141, 211, 132])
# current epoch: 46 current mean dice: 0.9754
# best mean dice: 0.9769 at epoch: 42
# ----------
# epoch 47/100
# 1/73, train_loss: 0.0226
# 2/73, train_loss: 0.0138
# 3/73, train_loss: 0.0173
# 4/73, train_loss: 0.0188
# 5/73, train_loss: 0.0188
# 6/73, train_loss: 0.0215
# 7/73, train_loss: 0.0183
# 8/73, train_loss: 0.0147
# 9/73, train_loss: 0.0159
# 10/73, train_loss: 0.0170
# 11/73, train_loss: 0.0297
# 12/73, train_loss: 0.0162
# 13/73, train_loss: 0.0206
# 14/73, train_loss: 0.0324
# 15/73, train_loss: 0.0209
# 16/73, train_loss: 0.0170
# 17/73, train_loss: 0.0169
# 18/73, train_loss: 0.0215
# 19/73, train_loss: 0.0148
# 20/73, train_loss: 0.0172
# 21/73, train_loss: 0.1923
# 22/73, train_loss: 0.0217
# 23/73, train_loss: 0.0219
# 24/73, train_loss: 0.0179
# 25/73, train_loss: 0.0123
# 26/73, train_loss: 0.0203
# 27/73, train_loss: 0.0153
# 28/73, train_loss: 0.0171
# 29/73, train_loss: 0.0185
# 30/73, train_loss: 0.0207
# 31/73, train_loss: 0.0167
# 32/73, train_loss: 0.0151
# 33/73, train_loss: 0.0145
# 34/73, train_loss: 0.0209
# 35/73, train_loss: 0.0336
# 36/73, train_loss: 0.0161
# 37/73, train_loss: 0.0158
# 38/73, train_loss: 0.0186
# 39/73, train_loss: 0.0209
# 40/73, train_loss: 0.0183
# 41/73, train_loss: 0.0191
# 42/73, train_loss: 0.0188
# 43/73, train_loss: 0.0334
# 44/73, train_loss: 0.0305
# 45/73, train_loss: 0.0156
# 46/73, train_loss: 0.0238
# 47/73, train_loss: 0.0147
# 48/73, train_loss: 0.0170
# 49/73, train_loss: 0.0162
# 50/73, train_loss: 0.0164
# 51/73, train_loss: 0.0167
# 52/73, train_loss: 0.0232
# 53/73, train_loss: 0.0197
# 54/73, train_loss: 0.0240
# 55/73, train_loss: 0.0172
# 56/73, train_loss: 0.0232
# 57/73, train_loss: 0.0145
# 58/73, train_loss: 0.0155
# 59/73, train_loss: 0.0180
# 60/73, train_loss: 0.0179
# 61/73, train_loss: 0.0162
# 62/73, train_loss: 0.0185
# 63/73, train_loss: 0.0404
# 64/73, train_loss: 0.0167
# 65/73, train_loss: 0.0204
# 66/73, train_loss: 0.0276
# 67/73, train_loss: 0.0169
# 68/73, train_loss: 0.0267
# 69/73, train_loss: 0.0171
# 70/73, train_loss: 0.0230
# 71/73, train_loss: 0.0153
# 72/73, train_loss: 0.0159
# 73/73, train_loss: 0.0218
# 74/73, train_loss: 0.0127
# epoch 47 average loss: 0.0219
# ----------
# epoch 48/100
# 1/73, train_loss: 0.0197
# 2/73, train_loss: 0.0290
# 3/73, train_loss: 0.0222
# 4/73, train_loss: 0.0167
# 5/73, train_loss: 0.0172
# 6/73, train_loss: 0.0151
# 7/73, train_loss: 0.0176
# 8/73, train_loss: 0.0196
# 9/73, train_loss: 0.0147
# 10/73, train_loss: 0.0159
# 11/73, train_loss: 0.0248
# 12/73, train_loss: 0.0554
# 13/73, train_loss: 0.0137
# 14/73, train_loss: 0.0149
# 15/73, train_loss: 0.0236
# 16/73, train_loss: 0.0186
# 17/73, train_loss: 0.0181
# 18/73, train_loss: 0.0176
# 19/73, train_loss: 0.0293
# 20/73, train_loss: 0.0234
# 21/73, train_loss: 0.0176
# 22/73, train_loss: 0.0176
# 23/73, train_loss: 0.0143
# 24/73, train_loss: 0.0166
# 25/73, train_loss: 0.0186
# 26/73, train_loss: 0.0203
# 27/73, train_loss: 0.0207
# 28/73, train_loss: 0.0292
# 29/73, train_loss: 0.0188
# 30/73, train_loss: 0.0218
# 31/73, train_loss: 0.0286
# 32/73, train_loss: 0.0167
# 33/73, train_loss: 0.0242
# 34/73, train_loss: 0.0190
# 35/73, train_loss: 0.0180
# 36/73, train_loss: 0.0206
# 37/73, train_loss: 0.0144
# 38/73, train_loss: 0.0168
# 39/73, train_loss: 0.0153
# 40/73, train_loss: 0.0176
# 41/73, train_loss: 0.0160
# 42/73, train_loss: 0.0179
# 43/73, train_loss: 0.2573
# 44/73, train_loss: 0.0260
# 45/73, train_loss: 0.0151
# 46/73, train_loss: 0.0152
# 47/73, train_loss: 0.0198
# 48/73, train_loss: 0.0152
# 49/73, train_loss: 0.0196
# 50/73, train_loss: 0.0166
# 51/73, train_loss: 0.0218
# 52/73, train_loss: 0.0209
# 53/73, train_loss: 0.0150
# 54/73, train_loss: 0.0157
# 55/73, train_loss: 0.0197
# 56/73, train_loss: 0.0179
# 57/73, train_loss: 0.0154
# 58/73, train_loss: 0.0154
# 59/73, train_loss: 0.0162
# 60/73, train_loss: 0.0244
# 61/73, train_loss: 0.0156
# 62/73, train_loss: 0.0187
# 63/73, train_loss: 0.0288
# 64/73, train_loss: 0.0342
# 65/73, train_loss: 0.0137
# 66/73, train_loss: 0.0224
# 67/73, train_loss: 0.0177
# 68/73, train_loss: 0.0165
# 69/73, train_loss: 0.0143
# 70/73, train_loss: 0.0208
# 71/73, train_loss: 0.0187
# 72/73, train_loss: 0.0194
# 73/73, train_loss: 0.0144
# 74/73, train_loss: 0.0325
# epoch 48 average loss: 0.0230
# Label shape : torch.Size([1, 1, 141, 211, 132])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 141, 211, 132])
# current epoch: 48 current mean dice: 0.9720
# best mean dice: 0.9769 at epoch: 42
# ----------
# epoch 49/100
# 1/73, train_loss: 0.0173
# 2/73, train_loss: 0.0204
# 3/73, train_loss: 0.0185
# 4/73, train_loss: 0.0223
# 5/73, train_loss: 0.0165
# 6/73, train_loss: 0.1296
# 7/73, train_loss: 0.0147
# 8/73, train_loss: 0.0697
# 9/73, train_loss: 0.0163
# 10/73, train_loss: 0.0228
# 11/73, train_loss: 0.0165
# 12/73, train_loss: 0.0181
# 13/73, train_loss: 0.0188
# 14/73, train_loss: 0.0155
# 15/73, train_loss: 0.0209
# 16/73, train_loss: 0.0873
# 17/73, train_loss: 0.0208
# 18/73, train_loss: 0.0141
# 19/73, train_loss: 0.0659
# 20/73, train_loss: 0.0183
# 21/73, train_loss: 0.0284
# 22/73, train_loss: 0.0186
# 23/73, train_loss: 0.0167
# 24/73, train_loss: 0.0174
# 25/73, train_loss: 0.0197
# 26/73, train_loss: 0.0285
# 27/73, train_loss: 0.0168
# 28/73, train_loss: 0.0227
# 29/73, train_loss: 0.0175
# 30/73, train_loss: 0.0198
# 31/73, train_loss: 0.0366
# 32/73, train_loss: 0.0206
# 33/73, train_loss: 0.0201
# 34/73, train_loss: 0.0249
# 35/73, train_loss: 0.0143
# 36/73, train_loss: 0.0195
# 37/73, train_loss: 0.0209
# 38/73, train_loss: 0.0179
# 39/73, train_loss: 0.0309
# 40/73, train_loss: 0.0224
# 41/73, train_loss: 0.0154
# 42/73, train_loss: 0.0160
# 43/73, train_loss: 0.0214
# 44/73, train_loss: 0.0201
# 45/73, train_loss: 0.0316
# 46/73, train_loss: 0.0182
# 47/73, train_loss: 0.0458
# 48/73, train_loss: 0.0208
# 49/73, train_loss: 0.0182
# 50/73, train_loss: 0.0246
# 51/73, train_loss: 0.0204
# 52/73, train_loss: 0.0222
# 53/73, train_loss: 0.0203
# 54/73, train_loss: 0.0228
# 55/73, train_loss: 0.0160
# 56/73, train_loss: 0.0141
# 57/73, train_loss: 0.0153
# 58/73, train_loss: 0.0158
# 59/73, train_loss: 0.0479
# 60/73, train_loss: 0.0161
# 61/73, train_loss: 0.0161
# 62/73, train_loss: 0.0311
# 63/73, train_loss: 0.0353
# 64/73, train_loss: 0.0273
# 65/73, train_loss: 0.0210
# 66/73, train_loss: 0.0194
# 67/73, train_loss: 0.0218
# 68/73, train_loss: 0.0295
# 69/73, train_loss: 0.0373
# 70/73, train_loss: 0.0153
# 71/73, train_loss: 0.0173
# 72/73, train_loss: 0.0165
# 73/73, train_loss: 0.0174
# 74/73, train_loss: 0.0185
# epoch 49 average loss: 0.0249
# ----------
# epoch 50/100
# 1/73, train_loss: 0.0367
# 2/73, train_loss: 0.0233
# 3/73, train_loss: 0.0153
# 4/73, train_loss: 0.0154
# 5/73, train_loss: 0.0275
# 6/73, train_loss: 0.0145
# 7/73, train_loss: 0.0214
# 8/73, train_loss: 0.0157
# 9/73, train_loss: 0.0173
# 10/73, train_loss: 0.0254
# 11/73, train_loss: 0.0304
# 12/73, train_loss: 0.0166
# 13/73, train_loss: 0.0200
# 14/73, train_loss: 0.0297
# 15/73, train_loss: 0.0173
# 16/73, train_loss: 0.1539
# 17/73, train_loss: 0.0222
# 18/73, train_loss: 0.0147
# 19/73, train_loss: 0.0204
# 20/73, train_loss: 0.0151
# 21/73, train_loss: 0.0167
# 22/73, train_loss: 0.0452
# 23/73, train_loss: 0.0251
# 24/73, train_loss: 0.0176
# 25/73, train_loss: 0.0237
# 26/73, train_loss: 0.0208
# 27/73, train_loss: 0.0204
# 28/73, train_loss: 0.0189
# 29/73, train_loss: 0.0182
# 30/73, train_loss: 0.0146
# 31/73, train_loss: 0.0149
# 32/73, train_loss: 0.0137
# 33/73, train_loss: 0.0189
# 34/73, train_loss: 0.0202
# 35/73, train_loss: 0.0223
# 36/73, train_loss: 0.0179
# 37/73, train_loss: 0.0191
# 38/73, train_loss: 0.0140
# 39/73, train_loss: 0.0217
# 40/73, train_loss: 0.0212
# 41/73, train_loss: 0.0182
# 42/73, train_loss: 0.0182
# 43/73, train_loss: 0.0176
# 44/73, train_loss: 0.0189
# 45/73, train_loss: 0.0166
# 46/73, train_loss: 0.0328
# 47/73, train_loss: 0.0186
# 48/73, train_loss: 0.0268
# 49/73, train_loss: 0.0217
# 50/73, train_loss: 0.0162
# 51/73, train_loss: 0.0147
# 52/73, train_loss: 0.0165
# 53/73, train_loss: 0.0198
# 54/73, train_loss: 0.0217
# 55/73, train_loss: 0.0154
# 56/73, train_loss: 0.0140
# 57/73, train_loss: 0.0162
# 58/73, train_loss: 0.0194
# 59/73, train_loss: 0.0160
# 60/73, train_loss: 0.0209
# 61/73, train_loss: 0.0179
# 62/73, train_loss: 0.0325
# 63/73, train_loss: 0.0142
# 64/73, train_loss: 0.0287
# 65/73, train_loss: 0.0177
# 66/73, train_loss: 0.0154
# 67/73, train_loss: 0.0158
# 68/73, train_loss: 0.0131
# 69/73, train_loss: 0.0206
# 70/73, train_loss: 0.0207
# 71/73, train_loss: 0.0170
# 72/73, train_loss: 0.0211
# 73/73, train_loss: 0.0171
# 74/73, train_loss: 0.0198
# epoch 50 average loss: 0.0218
# Label shape : torch.Size([1, 1, 141, 211, 132])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 141, 211, 132])
# current epoch: 50 current mean dice: 0.9765
# best mean dice: 0.9769 at epoch: 42
# ----------
# epoch 51/100
# 1/73, train_loss: 0.0204
# 2/73, train_loss: 0.0160
# 3/73, train_loss: 0.0182
# 4/73, train_loss: 0.0190
# 5/73, train_loss: 0.0158
# 6/73, train_loss: 0.0188
# 7/73, train_loss: 0.0145
# 8/73, train_loss: 0.0169
# 9/73, train_loss: 0.0194
# 10/73, train_loss: 0.0197
# 11/73, train_loss: 0.0177
# 12/73, train_loss: 0.0148
# 13/73, train_loss: 0.0262
# 14/73, train_loss: 0.0175
# 15/73, train_loss: 0.0188
# 16/73, train_loss: 0.0150
# 17/73, train_loss: 0.0189
# 18/73, train_loss: 0.0152
# 19/73, train_loss: 0.0198
# 20/73, train_loss: 0.0137
# 21/73, train_loss: 0.0239
# 22/73, train_loss: 0.0169
# 23/73, train_loss: 0.0137
# 24/73, train_loss: 0.0174
# 25/73, train_loss: 0.0166
# 26/73, train_loss: 0.0150
# 27/73, train_loss: 0.0207
# 28/73, train_loss: 0.0167
# 29/73, train_loss: 0.0130
# 30/73, train_loss: 0.0168
# 31/73, train_loss: 0.0179
# 32/73, train_loss: 0.0158
# 33/73, train_loss: 0.0157
# 34/73, train_loss: 0.0127
# 35/73, train_loss: 0.0196
# 36/73, train_loss: 0.0170
# 37/73, train_loss: 0.0158
# 38/73, train_loss: 0.0185
# 39/73, train_loss: 0.0203
# 40/73, train_loss: 0.0167
# 41/73, train_loss: 0.0218
# 42/73, train_loss: 0.0222
# 43/73, train_loss: 0.0182
# 44/73, train_loss: 0.0177
# 45/73, train_loss: 0.0202
# 46/73, train_loss: 0.0163
# 47/73, train_loss: 0.0147
# 48/73, train_loss: 0.0198
# 49/73, train_loss: 0.0228
# 50/73, train_loss: 0.0144
# 51/73, train_loss: 0.0925
# 52/73, train_loss: 0.0138
# 53/73, train_loss: 0.0162
# 54/73, train_loss: 0.0186
# 55/73, train_loss: 0.0548
# 56/73, train_loss: 0.0190
# 57/73, train_loss: 0.0174
# 58/73, train_loss: 0.0173
# 59/73, train_loss: 0.0255
# 60/73, train_loss: 0.0128
# 61/73, train_loss: 0.0239
# 62/73, train_loss: 0.0300
# 63/73, train_loss: 0.0154
# 64/73, train_loss: 0.0138
# 65/73, train_loss: 0.0190
# 66/73, train_loss: 0.0148
# 67/73, train_loss: 0.0193
# 68/73, train_loss: 0.0156
# 69/73, train_loss: 0.0159
# 70/73, train_loss: 0.0231
# 71/73, train_loss: 0.0236
# 72/73, train_loss: 0.0220
# 73/73, train_loss: 0.0135
# 74/73, train_loss: 0.0141
# epoch 51 average loss: 0.0194
# ----------
# epoch 52/100
# 1/73, train_loss: 0.0165
# 2/73, train_loss: 0.0144
# 3/73, train_loss: 0.0221
# 4/73, train_loss: 0.0177
# 5/73, train_loss: 0.0176
# 6/73, train_loss: 0.0235
# 7/73, train_loss: 0.0158
# 8/73, train_loss: 0.0207
# 9/73, train_loss: 0.0172
# 10/73, train_loss: 0.0180
# 11/73, train_loss: 0.0175
# 12/73, train_loss: 0.0256
# 13/73, train_loss: 0.3185
# 14/73, train_loss: 0.0186
# 15/73, train_loss: 0.0146
# 16/73, train_loss: 0.0530
# 17/73, train_loss: 0.0165
# 18/73, train_loss: 0.0153
# 19/73, train_loss: 0.0174
# 20/73, train_loss: 0.0141
# 21/73, train_loss: 0.0163
# 22/73, train_loss: 0.0167
# 23/73, train_loss: 0.0137
# 24/73, train_loss: 0.0134
# 25/73, train_loss: 0.0293
# 26/73, train_loss: 0.0789
# 27/73, train_loss: 0.0353
# 28/73, train_loss: 0.0187
# 29/73, train_loss: 0.0225
# 30/73, train_loss: 0.0177
# 31/73, train_loss: 0.0308
# 32/73, train_loss: 0.0309
# 33/73, train_loss: 0.0282
# 34/73, train_loss: 0.0172
# 35/73, train_loss: 0.0167
# 36/73, train_loss: 0.0182
# 37/73, train_loss: 0.0297
# 38/73, train_loss: 0.0165
# 39/73, train_loss: 0.0193
# 40/73, train_loss: 0.0164
# 41/73, train_loss: 0.0183
# 42/73, train_loss: 0.0247
# 43/73, train_loss: 0.0162
# 44/73, train_loss: 0.0236
# 45/73, train_loss: 0.0168
# 46/73, train_loss: 0.0169
# 47/73, train_loss: 0.0140
# 48/73, train_loss: 0.0188
# 49/73, train_loss: 0.0212
# 50/73, train_loss: 0.0198
# 51/73, train_loss: 0.0193
# 52/73, train_loss: 0.0203
# 53/73, train_loss: 0.0189
# 54/73, train_loss: 0.0198
# 55/73, train_loss: 0.0205
# 56/73, train_loss: 0.0168
# 57/73, train_loss: 0.0163
# 58/73, train_loss: 0.0285
# 59/73, train_loss: 0.0152
# 60/73, train_loss: 0.0139
# 61/73, train_loss: 0.0197
# 62/73, train_loss: 0.0201
# 63/73, train_loss: 0.0180
# 64/73, train_loss: 0.0153
# 65/73, train_loss: 0.0165
# 66/73, train_loss: 0.0219
# 67/73, train_loss: 0.0145
# 68/73, train_loss: 0.0162
# 69/73, train_loss: 0.0126
# 70/73, train_loss: 0.0218
# 71/73, train_loss: 0.0212
# 72/73, train_loss: 0.0218
# 73/73, train_loss: 0.0169
# 74/73, train_loss: 0.0349
# epoch 52 average loss: 0.0248
# Label shape : torch.Size([1, 1, 141, 211, 132])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 141, 211, 132])
# current epoch: 52 current mean dice: 0.9664
# best mean dice: 0.9769 at epoch: 42
# ----------
# epoch 53/100
# 1/73, train_loss: 0.0176
# 2/73, train_loss: 0.0157
# 3/73, train_loss: 0.0195
# 4/73, train_loss: 0.0179
# 5/73, train_loss: 0.0191
# 6/73, train_loss: 0.0163
# 7/73, train_loss: 0.0213
# 8/73, train_loss: 0.0162
# 9/73, train_loss: 0.0419
# 10/73, train_loss: 0.0193
# 11/73, train_loss: 0.0159
# 12/73, train_loss: 0.0141
# 13/73, train_loss: 0.0223
# 14/73, train_loss: 0.0150
# 15/73, train_loss: 0.0182
# 16/73, train_loss: 0.0161
# 17/73, train_loss: 0.0154
# 18/73, train_loss: 0.0174
# 19/73, train_loss: 0.0186
# 20/73, train_loss: 0.0153
# 21/73, train_loss: 0.0158
# 22/73, train_loss: 0.0195
# 23/73, train_loss: 0.0206
# 24/73, train_loss: 0.0151
# 25/73, train_loss: 0.0183
# 26/73, train_loss: 0.0160
# 27/73, train_loss: 0.0211
# 28/73, train_loss: 0.0171
# 29/73, train_loss: 0.0187
# 30/73, train_loss: 0.0197
# 31/73, train_loss: 0.0157
# 32/73, train_loss: 0.0304
# 33/73, train_loss: 0.0246
# 34/73, train_loss: 0.0160
# 35/73, train_loss: 0.0230
# 36/73, train_loss: 0.0279
# 37/73, train_loss: 0.0200
# 38/73, train_loss: 0.0196
# 39/73, train_loss: 0.0401
# 40/73, train_loss: 0.0219
# 41/73, train_loss: 0.0202
# 42/73, train_loss: 0.0230
# 43/73, train_loss: 0.0271
# 44/73, train_loss: 0.0166
# 45/73, train_loss: 0.0180
# 46/73, train_loss: 0.0163
# 47/73, train_loss: 0.0170
# 48/73, train_loss: 0.0187
# 49/73, train_loss: 0.0177
# 50/73, train_loss: 0.0167
# 51/73, train_loss: 0.0156
# 52/73, train_loss: 0.0148
# 53/73, train_loss: 0.0189
# 54/73, train_loss: 0.0162
# 55/73, train_loss: 0.0183
# 56/73, train_loss: 0.0194
# 57/73, train_loss: 0.0259
# 58/73, train_loss: 0.0157
# 59/73, train_loss: 0.0154
# 60/73, train_loss: 0.0195
# 61/73, train_loss: 0.0145
# 62/73, train_loss: 0.0234
# 63/73, train_loss: 0.0185
# 64/73, train_loss: 0.0145
# 65/73, train_loss: 0.0134
# 66/73, train_loss: 0.0211
# 67/73, train_loss: 0.0266
# 68/73, train_loss: 0.0348
# 69/73, train_loss: 0.0241
# 70/73, train_loss: 0.0153
# 71/73, train_loss: 0.0226
# 72/73, train_loss: 0.0182
# 73/73, train_loss: 0.0403
# 74/73, train_loss: 0.0169
# epoch 53 average loss: 0.0199
# ----------
# epoch 54/100
# 1/73, train_loss: 0.0218
# 2/73, train_loss: 0.0130
# 3/73, train_loss: 0.0182
# 4/73, train_loss: 0.0371
# 5/73, train_loss: 0.0179
# 6/73, train_loss: 0.0130
# 7/73, train_loss: 0.0209
# 8/73, train_loss: 0.0139
# 9/73, train_loss: 0.0181
# 10/73, train_loss: 0.0157
# 11/73, train_loss: 0.0162
# 12/73, train_loss: 0.0217
# 13/73, train_loss: 0.0300
# 14/73, train_loss: 0.0148
# 15/73, train_loss: 0.0177
# 16/73, train_loss: 0.0179
# 17/73, train_loss: 0.0189
# 18/73, train_loss: 0.0221
# 19/73, train_loss: 0.0273
# 20/73, train_loss: 0.0193
# 21/73, train_loss: 0.0174
# 22/73, train_loss: 0.0163
# 23/73, train_loss: 0.0160
# 24/73, train_loss: 0.0169
# 25/73, train_loss: 0.0147
# 26/73, train_loss: 0.0160
# 27/73, train_loss: 0.0148
# 28/73, train_loss: 0.0172
# 29/73, train_loss: 0.0163
# 30/73, train_loss: 0.0417
# 31/73, train_loss: 0.0204
# 32/73, train_loss: 0.0205
# 33/73, train_loss: 0.0226
# 34/73, train_loss: 0.0181
# 35/73, train_loss: 0.0132
# 36/73, train_loss: 0.0202
# 37/73, train_loss: 0.0193
# 38/73, train_loss: 0.0183
# 39/73, train_loss: 0.0209
# 40/73, train_loss: 0.0286
# 41/73, train_loss: 0.0190
# 42/73, train_loss: 0.0466
# 43/73, train_loss: 0.0180
# 44/73, train_loss: 0.0166
# 45/73, train_loss: 0.0145
# 46/73, train_loss: 0.0201
# 47/73, train_loss: 0.0204
# 48/73, train_loss: 0.0197
# 49/73, train_loss: 0.0204
# 50/73, train_loss: 0.0169
# 51/73, train_loss: 0.0158
# 52/73, train_loss: 0.0171
# 53/73, train_loss: 0.0168
# 54/73, train_loss: 0.0176
# 55/73, train_loss: 0.0139
# 56/73, train_loss: 0.0170
# 57/73, train_loss: 0.0215
# 58/73, train_loss: 0.0155
# 59/73, train_loss: 0.0464
# 60/73, train_loss: 0.0181
# 61/73, train_loss: 0.0152
# 62/73, train_loss: 0.0199
# 63/73, train_loss: 0.0226
# 64/73, train_loss: 0.0184
# 65/73, train_loss: 0.0172
# 66/73, train_loss: 0.0201
# 67/73, train_loss: 0.0164
# 68/73, train_loss: 0.0178
# 69/73, train_loss: 0.0157
# 70/73, train_loss: 0.0242
# 71/73, train_loss: 0.0232
# 72/73, train_loss: 0.0143
# 73/73, train_loss: 0.0154
# 74/73, train_loss: 0.0192
# epoch 54 average loss: 0.0197
# Label shape : torch.Size([1, 1, 141, 211, 132])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 141, 211, 132])
# current epoch: 54 current mean dice: 0.9756
# best mean dice: 0.9769 at epoch: 42
# ----------
# epoch 55/100
# 1/73, train_loss: 0.0157
# 2/73, train_loss: 0.0229
# 3/73, train_loss: 0.0187
# 4/73, train_loss: 0.0171
# 5/73, train_loss: 0.0197
# 6/73, train_loss: 0.0169
# 7/73, train_loss: 0.0190
# 8/73, train_loss: 0.0153
# 9/73, train_loss: 0.0278
# 10/73, train_loss: 0.0212
# 11/73, train_loss: 0.0268
# 12/73, train_loss: 0.0188
# 13/73, train_loss: 0.0143
# 14/73, train_loss: 0.0176
# 15/73, train_loss: 0.0157
# 16/73, train_loss: 0.0157
# 17/73, train_loss: 0.0152
# 18/73, train_loss: 0.0123
# 19/73, train_loss: 0.0160
# 20/73, train_loss: 0.0226
# 21/73, train_loss: 0.0153
# 22/73, train_loss: 0.0182
# 23/73, train_loss: 0.0141
# 24/73, train_loss: 0.0192
# 25/73, train_loss: 0.0160
# 26/73, train_loss: 0.0148
# 27/73, train_loss: 0.0188
# 28/73, train_loss: 0.0144
# 29/73, train_loss: 0.0255
# 30/73, train_loss: 0.0139
# 31/73, train_loss: 0.0219
# 32/73, train_loss: 0.0147
# 33/73, train_loss: 0.0201
# 34/73, train_loss: 0.0181
# 35/73, train_loss: 0.0182
# 36/73, train_loss: 0.1261
# 37/73, train_loss: 0.0454
# 38/73, train_loss: 0.0189
# 39/73, train_loss: 0.0172
# 40/73, train_loss: 0.0234
# 41/73, train_loss: 0.0198
# 42/73, train_loss: 0.0236
# 43/73, train_loss: 0.0319
# 44/73, train_loss: 0.1291
# 45/73, train_loss: 0.0352
# 46/73, train_loss: 0.0186
# 47/73, train_loss: 0.0176
# 48/73, train_loss: 0.0203
# 49/73, train_loss: 0.0192
# 50/73, train_loss: 0.0218
# 51/73, train_loss: 0.0245
# 52/73, train_loss: 0.0534
# 53/73, train_loss: 0.0188
# 54/73, train_loss: 0.0193
# 55/73, train_loss: 0.0151
# 56/73, train_loss: 0.0151
# 57/73, train_loss: 0.0219
# 58/73, train_loss: 0.0265
# 59/73, train_loss: 0.0400
# 60/73, train_loss: 0.0190
# 61/73, train_loss: 0.0193
# 62/73, train_loss: 0.0180
# 63/73, train_loss: 0.0142
# 64/73, train_loss: 0.0125
# 65/73, train_loss: 0.0312
# 66/73, train_loss: 0.0178
# 67/73, train_loss: 0.0190
# 68/73, train_loss: 0.0278
# 69/73, train_loss: 0.0263
# 70/73, train_loss: 0.0163
# 71/73, train_loss: 0.0180
# 72/73, train_loss: 0.0247
# 73/73, train_loss: 0.0168
# 74/73, train_loss: 0.0240
# epoch 55 average loss: 0.0235
# ----------
# epoch 56/100
# 1/73, train_loss: 0.0160
# 2/73, train_loss: 0.0187
# 3/73, train_loss: 0.0227
# 4/73, train_loss: 0.0176
# 5/73, train_loss: 0.0204
# 6/73, train_loss: 0.0183
# 7/73, train_loss: 0.0178
# 8/73, train_loss: 0.0224
# 9/73, train_loss: 0.0288
# 10/73, train_loss: 0.0151
# 11/73, train_loss: 0.0184
# 12/73, train_loss: 0.0152
# 13/73, train_loss: 0.0218
# 14/73, train_loss: 0.0156
# 15/73, train_loss: 0.0183
# 16/73, train_loss: 0.0174
# 17/73, train_loss: 0.0167
# 18/73, train_loss: 0.0159
# 19/73, train_loss: 0.0142
# 20/73, train_loss: 0.0170
# 21/73, train_loss: 0.0148
# 22/73, train_loss: 0.0163
# 23/73, train_loss: 0.0163
# 24/73, train_loss: 0.0174
# 25/73, train_loss: 0.0189
# 26/73, train_loss: 0.0213
# 27/73, train_loss: 0.0279
# 28/73, train_loss: 0.0249
# 29/73, train_loss: 0.0160
# 30/73, train_loss: 0.0293
# 31/73, train_loss: 0.0137
# 32/73, train_loss: 0.0214
# 33/73, train_loss: 0.0198
# 34/73, train_loss: 0.0400
# 35/73, train_loss: 0.0165
# 36/73, train_loss: 0.0146
# 37/73, train_loss: 0.0156
# 38/73, train_loss: 0.0143
# 39/73, train_loss: 0.0196
# 40/73, train_loss: 0.0219
# 41/73, train_loss: 0.0185
# 42/73, train_loss: 0.0190
# 43/73, train_loss: 0.0292
# 44/73, train_loss: 0.0207
# 45/73, train_loss: 0.0137
# 46/73, train_loss: 0.0169
# 47/73, train_loss: 0.0174
# 48/73, train_loss: 0.0158
# 49/73, train_loss: 0.0551
# 50/73, train_loss: 0.0208
# 51/73, train_loss: 0.0231
# 52/73, train_loss: 0.0325
# 53/73, train_loss: 0.0177
# 54/73, train_loss: 0.0154
# 55/73, train_loss: 0.0140
# 56/73, train_loss: 0.0168
# 57/73, train_loss: 0.0199
# 58/73, train_loss: 0.0161
# 59/73, train_loss: 0.0209
# 60/73, train_loss: 0.0180
# 61/73, train_loss: 0.0159
# 62/73, train_loss: 0.0177
# 63/73, train_loss: 0.0145
# 64/73, train_loss: 0.0150
# 65/73, train_loss: 0.0223
# 66/73, train_loss: 0.0185
# 67/73, train_loss: 0.0128
# 68/73, train_loss: 0.0167
# 69/73, train_loss: 0.0165
# 70/73, train_loss: 0.0293
# 71/73, train_loss: 0.0180
# 72/73, train_loss: 0.0154
# 73/73, train_loss: 0.0171
# 74/73, train_loss: 0.5762
# epoch 56 average loss: 0.0270
# Label shape : torch.Size([1, 1, 141, 211, 132])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 141, 211, 132])
# current epoch: 56 current mean dice: 0.9758
# best mean dice: 0.9769 at epoch: 42
# ----------
# epoch 57/100
# 1/73, train_loss: 0.0217
# 2/73, train_loss: 0.0175
# 3/73, train_loss: 0.0159
# 4/73, train_loss: 0.0206
# 5/73, train_loss: 0.0164
# 6/73, train_loss: 0.0178
# 7/73, train_loss: 0.0159
# 8/73, train_loss: 0.0159
# 9/73, train_loss: 0.0217
# 10/73, train_loss: 0.0181
# 11/73, train_loss: 0.0140
# 12/73, train_loss: 0.0178
# 13/73, train_loss: 0.0432
# 14/73, train_loss: 0.0501
# 15/73, train_loss: 0.0351
# 16/73, train_loss: 0.0152
# 17/73, train_loss: 0.0159
# 18/73, train_loss: 0.0158
# 19/73, train_loss: 0.0231
# 20/73, train_loss: 0.0189
# 21/73, train_loss: 0.0136
# 22/73, train_loss: 0.0247
# 23/73, train_loss: 0.0158
# 24/73, train_loss: 0.0170
# 25/73, train_loss: 0.0137
# 26/73, train_loss: 0.0165
# 27/73, train_loss: 0.0193
# 28/73, train_loss: 0.0317
# 29/73, train_loss: 0.0217
# 30/73, train_loss: 0.0150
# 31/73, train_loss: 0.0158
# 32/73, train_loss: 0.0158
# 33/73, train_loss: 0.0172
# 34/73, train_loss: 0.0153
# 35/73, train_loss: 0.0145
# 36/73, train_loss: 0.0210
# 37/73, train_loss: 0.0196
# 38/73, train_loss: 0.0377
# 39/73, train_loss: 0.0198
# 40/73, train_loss: 0.0126
# 41/73, train_loss: 0.0169
# 42/73, train_loss: 0.0182
# 43/73, train_loss: 0.0266
# 44/73, train_loss: 0.0132
# 45/73, train_loss: 0.0143
# 46/73, train_loss: 0.0345
# 47/73, train_loss: 0.0127
# 48/73, train_loss: 0.0134
# 49/73, train_loss: 0.0210
# 50/73, train_loss: 0.0138
# 51/73, train_loss: 0.0201
# 52/73, train_loss: 0.0141
# 53/73, train_loss: 0.0143
# 54/73, train_loss: 0.0169
# 55/73, train_loss: 0.0190
# 56/73, train_loss: 0.0139
# 57/73, train_loss: 0.0155
# 58/73, train_loss: 0.0195
# 59/73, train_loss: 0.0150
# 60/73, train_loss: 0.0171
# 61/73, train_loss: 0.0170
# 62/73, train_loss: 0.0215
# 63/73, train_loss: 0.0146
# 64/73, train_loss: 0.0159
# 65/73, train_loss: 0.0143
# 66/73, train_loss: 0.0141
# 67/73, train_loss: 0.0162
# 68/73, train_loss: 0.0183
# 69/73, train_loss: 0.0234
# 70/73, train_loss: 0.0163
# 71/73, train_loss: 0.0165
# 72/73, train_loss: 0.0241
# 73/73, train_loss: 0.0342
# 74/73, train_loss: 0.0150
# epoch 57 average loss: 0.0192
# ----------
# epoch 58/100
# 1/73, train_loss: 0.0184
# 2/73, train_loss: 0.0186
# 3/73, train_loss: 0.0159
# 4/73, train_loss: 0.0152
# 5/73, train_loss: 0.0128
# 6/73, train_loss: 0.0159
# 7/73, train_loss: 0.0147
# 8/73, train_loss: 0.0169
# 9/73, train_loss: 0.0190
# 10/73, train_loss: 0.0160
# 11/73, train_loss: 0.0215
# 12/73, train_loss: 0.0132
# 13/73, train_loss: 0.0222
# 14/73, train_loss: 0.0323
# 15/73, train_loss: 0.0178
# 16/73, train_loss: 0.0148
# 17/73, train_loss: 0.0141
# 18/73, train_loss: 0.0155
# 19/73, train_loss: 0.0125
# 20/73, train_loss: 0.0151
# 21/73, train_loss: 0.0141
# 22/73, train_loss: 0.0176
# 23/73, train_loss: 0.0183
# 24/73, train_loss: 0.0197
# 25/73, train_loss: 0.0175
# 26/73, train_loss: 0.0161
# 27/73, train_loss: 0.0178
# 28/73, train_loss: 0.0156
# 29/73, train_loss: 0.0174
# 30/73, train_loss: 0.0136
# 31/73, train_loss: 0.0152
# 32/73, train_loss: 0.0169
# 33/73, train_loss: 0.0184
# 34/73, train_loss: 0.0181
# 35/73, train_loss: 0.0140
# 36/73, train_loss: 0.0159
# 37/73, train_loss: 0.0149
# 38/73, train_loss: 0.0183
# 39/73, train_loss: 0.0144
# 40/73, train_loss: 0.0204
# 41/73, train_loss: 0.0149
# 42/73, train_loss: 0.0114
# 43/73, train_loss: 0.0157
# 44/73, train_loss: 0.0137
# 45/73, train_loss: 0.0174
# 46/73, train_loss: 0.0172
# 47/73, train_loss: 0.0181
# 48/73, train_loss: 0.0154
# 49/73, train_loss: 0.0160
# 50/73, train_loss: 0.0161
# 51/73, train_loss: 0.0215
# 52/73, train_loss: 0.0147
# 53/73, train_loss: 0.0161
# 54/73, train_loss: 0.0176
# 55/73, train_loss: 0.1041
# 56/73, train_loss: 0.0151
# 57/73, train_loss: 0.0197
# 58/73, train_loss: 0.0160
# 59/73, train_loss: 0.0198
# 60/73, train_loss: 0.0166
# 61/73, train_loss: 0.0179
# 62/73, train_loss: 0.0161
# 63/73, train_loss: 0.1457
# 64/73, train_loss: 0.0149
# 65/73, train_loss: 0.0155
# 66/73, train_loss: 0.0154
# 67/73, train_loss: 0.0138
# 68/73, train_loss: 0.0212
# 69/73, train_loss: 0.0235
# 70/73, train_loss: 0.0189
# 71/73, train_loss: 0.0160
# 72/73, train_loss: 0.0195
# 73/73, train_loss: 0.0154
# 74/73, train_loss: 0.0125
# epoch 58 average loss: 0.0197
# Label shape : torch.Size([1, 1, 141, 211, 132])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 141, 211, 132])
# saved new best metric model
# current epoch: 58 current mean dice: 0.9788
# best mean dice: 0.9788 at epoch: 58
# ----------
# epoch 59/100
# 1/73, train_loss: 0.0155
# 2/73, train_loss: 0.0173
# 3/73, train_loss: 0.0178
# 4/73, train_loss: 0.0176
# 5/73, train_loss: 0.0203
# 6/73, train_loss: 0.0180
# 7/73, train_loss: 0.0144
# 8/73, train_loss: 0.0178
# 9/73, train_loss: 0.0142
# 10/73, train_loss: 0.0135
# 11/73, train_loss: 0.0223
# 12/73, train_loss: 0.0140
# 13/73, train_loss: 0.0154
# 14/73, train_loss: 0.0210
# 15/73, train_loss: 0.0225
# 16/73, train_loss: 0.0151
# 17/73, train_loss: 0.0208
# 18/73, train_loss: 0.0180
# 19/73, train_loss: 0.0173
# 20/73, train_loss: 0.0176
# 21/73, train_loss: 0.0183
# 22/73, train_loss: 0.0166
# 23/73, train_loss: 0.0163
# 24/73, train_loss: 0.0174
# 25/73, train_loss: 0.0190
# 26/73, train_loss: 0.0220
# 27/73, train_loss: 0.0211
# 28/73, train_loss: 0.0210
# 29/73, train_loss: 0.0176
# 30/73, train_loss: 0.0164
# 31/73, train_loss: 0.0147
# 32/73, train_loss: 0.0150
# 33/73, train_loss: 0.0151
# 34/73, train_loss: 0.0139
# 35/73, train_loss: 0.0268
# 36/73, train_loss: 0.0435
# 37/73, train_loss: 0.0145
# 38/73, train_loss: 0.0233
# 39/73, train_loss: 0.0166
# 40/73, train_loss: 0.0394
# 41/73, train_loss: 0.0124
# 42/73, train_loss: 0.0148
# 43/73, train_loss: 0.0182
# 44/73, train_loss: 0.0157
# 45/73, train_loss: 0.0224
# 46/73, train_loss: 0.0183
# 47/73, train_loss: 0.0123
# 48/73, train_loss: 0.0364
# 49/73, train_loss: 0.0144
# 50/73, train_loss: 0.0185
# 51/73, train_loss: 0.0151
# 52/73, train_loss: 0.0209
# 53/73, train_loss: 0.0341
# 54/73, train_loss: 0.0402
# 55/73, train_loss: 0.0167
# 56/73, train_loss: 0.0193
# 57/73, train_loss: 0.0138
# 58/73, train_loss: 0.0173
# 59/73, train_loss: 0.0169
# 60/73, train_loss: 0.0212
# 61/73, train_loss: 0.0157
# 62/73, train_loss: 0.0141
# 63/73, train_loss: 0.0274
# 64/73, train_loss: 0.0148
# 65/73, train_loss: 0.0187
# 66/73, train_loss: 0.0135
# 67/73, train_loss: 0.0245
# 68/73, train_loss: 0.0159
# 69/73, train_loss: 0.0139
# 70/73, train_loss: 0.0307
# 71/73, train_loss: 0.0173
# 72/73, train_loss: 0.0174
# 73/73, train_loss: 0.0170
# 74/73, train_loss: 0.0127
# epoch 59 average loss: 0.0191
# ----------
# epoch 60/100
# 1/73, train_loss: 0.0298
# 2/73, train_loss: 0.0123
# 3/73, train_loss: 0.0159
# 4/73, train_loss: 0.0289
# 5/73, train_loss: 0.0200
# 6/73, train_loss: 0.0143
# 7/73, train_loss: 0.0138
# 8/73, train_loss: 0.0172
# 9/73, train_loss: 0.0195
# 10/73, train_loss: 0.0253
# 11/73, train_loss: 0.0245
# 12/73, train_loss: 0.0158
# 13/73, train_loss: 0.0166
# 14/73, train_loss: 0.0151
# 15/73, train_loss: 0.0183
# 16/73, train_loss: 0.0171
# 17/73, train_loss: 0.0123
# 18/73, train_loss: 0.0141
# 19/73, train_loss: 0.0184
# 20/73, train_loss: 0.0180
# 21/73, train_loss: 0.0218
# 22/73, train_loss: 0.0191
# 23/73, train_loss: 0.0172
# 24/73, train_loss: 0.0329
# 25/73, train_loss: 0.0130
# 26/73, train_loss: 0.0165
# 27/73, train_loss: 0.0167
# 28/73, train_loss: 0.0196
# 29/73, train_loss: 0.0185
# 30/73, train_loss: 0.0280
# 31/73, train_loss: 0.0237
# 32/73, train_loss: 0.0154
# 33/73, train_loss: 0.0250
# 34/73, train_loss: 0.0155
# 35/73, train_loss: 0.0162
# 36/73, train_loss: 0.0179
# 37/73, train_loss: 0.0317
# 38/73, train_loss: 0.0152
# 39/73, train_loss: 0.0219
# 40/73, train_loss: 0.0165
# 41/73, train_loss: 0.0205
# 42/73, train_loss: 0.0149
# 43/73, train_loss: 0.0542
# 44/73, train_loss: 0.0197
# 45/73, train_loss: 0.0149
# 46/73, train_loss: 0.0166
# 47/73, train_loss: 0.0146
# 48/73, train_loss: 0.0132
# 49/73, train_loss: 0.0128
# 50/73, train_loss: 0.0195
# 51/73, train_loss: 0.0165
# 52/73, train_loss: 0.0173
# 53/73, train_loss: 0.0157
# 54/73, train_loss: 0.0160
# 55/73, train_loss: 0.0162
# 56/73, train_loss: 0.0203
# 57/73, train_loss: 0.0218
# 58/73, train_loss: 0.0222
# 59/73, train_loss: 0.0164
# 60/73, train_loss: 0.0184
# 61/73, train_loss: 0.0183
# 62/73, train_loss: 0.0191
# 63/73, train_loss: 0.0180
# 64/73, train_loss: 0.0174
# 65/73, train_loss: 0.0151
# 66/73, train_loss: 0.0157
# 67/73, train_loss: 0.0206
# 68/73, train_loss: 0.0205
# 69/73, train_loss: 0.0166
# 70/73, train_loss: 0.0134
# 71/73, train_loss: 0.0172
# 72/73, train_loss: 0.0139
# 73/73, train_loss: 0.0136
# 74/73, train_loss: 0.0152
# epoch 60 average loss: 0.0187
# Label shape : torch.Size([1, 1, 141, 211, 132])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 141, 211, 132])
# current epoch: 60 current mean dice: 0.9757
# best mean dice: 0.9788 at epoch: 58
# ----------
# epoch 61/100
# 1/73, train_loss: 0.0242
# 2/73, train_loss: 0.0265
# 3/73, train_loss: 0.0306
# 4/73, train_loss: 0.0690
# 5/73, train_loss: 0.0157
# 6/73, train_loss: 0.0269
# 7/73, train_loss: 0.0145
# 8/73, train_loss: 0.0160
# 9/73, train_loss: 0.0167
# 10/73, train_loss: 0.0134
# 11/73, train_loss: 0.0166
# 12/73, train_loss: 0.0193
# ...
# 25/73, train_loss: 0.0174
# 26/73, train_loss: 0.0128
# 27/73, train_loss: 0.0412
# 28/73, train_loss: 0.0128
# 29/73, train_loss: 0.0120
# 30/73, train_loss: 0.0154
# 31/73, train_loss: 0.0152
# 32/73, train_loss: 0.0184
# 33/73, train_loss: 0.0134
# 34/73, train_loss: 0.0188
# 35/73, train_loss: 0.0176
# 36/73, train_loss: 0.0169
# 37/73, train_loss: 0.0135
# 38/73, train_loss: 0.0148
# 39/73, train_loss: 0.0147
# 40/73, train_loss: 0.0138
# 41/73, train_loss: 0.0117
# 42/73, train_loss: 0.0160
# 43/73, train_loss: 0.0133
# 44/73, train_loss: 0.0132
# 45/73, train_loss: 0.0177
# 46/73, train_loss: 0.0322
# 47/73, train_loss: 0.0180
# 48/73, train_loss: 0.0130
# 49/73, train_loss: 0.0152
# 50/73, train_loss: 0.0179
# 51/73, train_loss: 0.0204
# 52/73, train_loss: 0.0115
# 53/73, train_loss: 0.0170
# 54/73, train_loss: 0.0136
# 55/73, train_loss: 0.0183
# 56/73, train_loss: 0.0148
# 57/73, train_loss: 0.0143
# 58/73, train_loss: 0.0141
# 59/73, train_loss: 0.0136
# 60/73, train_loss: 0.0130
# 61/73, train_loss: 0.0138
# 62/73, train_loss: 0.0198
# 63/73, train_loss: 0.0222
# 64/73, train_loss: 0.0168
# 65/73, train_loss: 0.0136
# 66/73, train_loss: 0.0127
# 67/73, train_loss: 0.0163
# 68/73, train_loss: 0.0134
# 69/73, train_loss: 0.0174
# 70/73, train_loss: 0.0151
# 71/73, train_loss: 0.0186
# 72/73, train_loss: 0.0141
# 73/73, train_loss: 0.0233
# 74/73, train_loss: 0.0111
# epoch 93 average loss: 0.0172
# ----------
# epoch 94/100
# 1/73, train_loss: 0.0134
# 2/73, train_loss: 0.0182
# 3/73, train_loss: 0.0148
# 4/73, train_loss: 0.0124
# 5/73, train_loss: 0.0145
# 6/73, train_loss: 0.0496
# 7/73, train_loss: 0.0195
# 8/73, train_loss: 0.0144
# 9/73, train_loss: 0.0150
# 10/73, train_loss: 0.0143
# 11/73, train_loss: 0.0159
# 12/73, train_loss: 0.0171
# 13/73, train_loss: 0.0144
# 14/73, train_loss: 0.0288
# 15/73, train_loss: 0.0335
# 16/73, train_loss: 0.0173
# 17/73, train_loss: 0.0137
# 18/73, train_loss: 0.0170
# 19/73, train_loss: 0.0175
# 20/73, train_loss: 0.0150
# 21/73, train_loss: 0.0152
# 22/73, train_loss: 0.0174
# 23/73, train_loss: 0.0218
# 24/73, train_loss: 0.0184
# 25/73, train_loss: 0.0142
# 26/73, train_loss: 0.0172
# 27/73, train_loss: 0.0175
# 28/73, train_loss: 0.0135
# 29/73, train_loss: 0.0183
# 30/73, train_loss: 0.0149
# 31/73, train_loss: 0.0197
# 32/73, train_loss: 0.0142
# 33/73, train_loss: 0.0138
# 34/73, train_loss: 0.0106
# 35/73, train_loss: 0.0148
# 36/73, train_loss: 0.0137
# 37/73, train_loss: 0.0125
# 38/73, train_loss: 0.0132
# 39/73, train_loss: 0.0182
# 40/73, train_loss: 0.0160
# 41/73, train_loss: 0.0209
# 42/73, train_loss: 0.0149
# 43/73, train_loss: 0.0159
# 44/73, train_loss: 0.0156
# 45/73, train_loss: 0.0158
# 46/73, train_loss: 0.0134
# 47/73, train_loss: 0.0206
# 48/73, train_loss: 0.0170
# 49/73, train_loss: 0.0133
# 50/73, train_loss: 0.0150
# 51/73, train_loss: 0.0143
# 52/73, train_loss: 0.0152
# 53/73, train_loss: 0.0167
# 54/73, train_loss: 0.0132
# 55/73, train_loss: 0.0124
# 56/73, train_loss: 0.0151
# 57/73, train_loss: 0.0171
# 58/73, train_loss: 0.0211
# 59/73, train_loss: 0.0132
# 60/73, train_loss: 0.0153
# 61/73, train_loss: 0.0153
# 62/73, train_loss: 0.0150
# 63/73, train_loss: 0.1133
# 64/73, train_loss: 0.0150
# 65/73, train_loss: 0.0162
# 66/73, train_loss: 0.0146
# 67/73, train_loss: 0.0121
# 68/73, train_loss: 0.0184
# 69/73, train_loss: 0.0208
# 70/73, train_loss: 0.0186
# 71/73, train_loss: 0.0215
# 72/73, train_loss: 0.0331
# 73/73, train_loss: 0.0242
# 74/73, train_loss: 0.0167
# epoch 94 average loss: 0.0184
# Label shape : torch.Size([1, 1, 141, 211, 132])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 141, 211, 132])
# current epoch: 94 current mean dice: 0.9691
# best mean dice: 0.9799 at epoch: 88
# ----------
# epoch 95/100
# 1/73, train_loss: 0.0139
# 2/73, train_loss: 0.0341
# 3/73, train_loss: 0.0145
# 4/73, train_loss: 0.0173
# 5/73, train_loss: 0.0183
# 6/73, train_loss: 0.0212
# 7/73, train_loss: 0.0185
# 8/73, train_loss: 0.0128
# 9/73, train_loss: 0.0314
# 10/73, train_loss: 0.0154
# 11/73, train_loss: 0.0137
# 12/73, train_loss: 0.0371
# 13/73, train_loss: 0.0168
# 14/73, train_loss: 0.0165
# 15/73, train_loss: 0.0287
# 16/73, train_loss: 0.2565
# 17/73, train_loss: 0.0145
# 18/73, train_loss: 0.0156
# 19/73, train_loss: 0.0183
# 20/73, train_loss: 0.0154
# 21/73, train_loss: 0.0118
# 22/73, train_loss: 0.0163
# 23/73, train_loss: 0.0194
# 24/73, train_loss: 0.0204
# 25/73, train_loss: 0.0124
# 26/73, train_loss: 0.0150
# 27/73, train_loss: 0.0187
# 28/73, train_loss: 0.0161
# 29/73, train_loss: 0.0170
# 30/73, train_loss: 0.0175
# 31/73, train_loss: 0.0179
# 32/73, train_loss: 0.0193
# 33/73, train_loss: 0.0164
# 34/73, train_loss: 0.2207
# 35/73, train_loss: 0.0195
# 36/73, train_loss: 0.0158
# 37/73, train_loss: 0.0161
# 38/73, train_loss: 0.0169
# 39/73, train_loss: 0.0154
# 40/73, train_loss: 0.0191
# 41/73, train_loss: 0.0156
# 42/73, train_loss: 0.0172
# 43/73, train_loss: 0.0141
# 44/73, train_loss: 0.0146
# 45/73, train_loss: 0.0171
# 46/73, train_loss: 0.0174
# 47/73, train_loss: 0.0129
# 48/73, train_loss: 0.0135
# 49/73, train_loss: 0.0140
# 50/73, train_loss: 0.0152
# 51/73, train_loss: 0.0195
# 52/73, train_loss: 0.0288
# 53/73, train_loss: 0.0136
# 54/73, train_loss: 0.0140
# 55/73, train_loss: 0.0284
# 56/73, train_loss: 0.0142
# 57/73, train_loss: 0.0178
# 58/73, train_loss: 0.0203
# 59/73, train_loss: 0.0153
# 60/73, train_loss: 0.0135
# 61/73, train_loss: 0.0155
# 62/73, train_loss: 0.0162
# 63/73, train_loss: 0.0180
# 64/73, train_loss: 0.0204
# 65/73, train_loss: 0.0118
# 66/73, train_loss: 0.0168
# 67/73, train_loss: 0.0119
# 68/73, train_loss: 0.0140
# 69/73, train_loss: 0.0257
# 70/73, train_loss: 0.0163
# 71/73, train_loss: 0.0140
# 72/73, train_loss: 0.0165
# 73/73, train_loss: 0.0144
# 74/73, train_loss: 0.0126
# epoch 95 average loss: 0.0234
# ----------
# epoch 96/100
# 1/73, train_loss: 0.0166
# 2/73, train_loss: 0.0570
# 3/73, train_loss: 0.0215
# 4/73, train_loss: 0.0156
# 5/73, train_loss: 0.0137
# 6/73, train_loss: 0.0135
# 7/73, train_loss: 0.0121
# 8/73, train_loss: 0.0213
# 9/73, train_loss: 0.0146
# 10/73, train_loss: 0.0153
# 11/73, train_loss: 0.0144
# 12/73, train_loss: 0.0144
# 13/73, train_loss: 0.0154
# 14/73, train_loss: 0.0137
# 15/73, train_loss: 0.0177
# 16/73, train_loss: 0.0140
# 17/73, train_loss: 0.0161
# 18/73, train_loss: 0.0133
# 19/73, train_loss: 0.0131
# 20/73, train_loss: 0.0223
# 21/73, train_loss: 0.0139
# 22/73, train_loss: 0.0154
# 23/73, train_loss: 0.0138
# 24/73, train_loss: 0.0192
# 25/73, train_loss: 0.0290
# 26/73, train_loss: 0.0146
# 27/73, train_loss: 0.0140
# 28/73, train_loss: 0.1210
# 29/73, train_loss: 0.0263
# 30/73, train_loss: 0.0194
# 31/73, train_loss: 0.0236
# 32/73, train_loss: 0.0121
# 33/73, train_loss: 0.0152
# 34/73, train_loss: 0.0452
# 35/73, train_loss: 0.0136
# 36/73, train_loss: 0.0126
# 37/73, train_loss: 0.0358
# 38/73, train_loss: 0.0240
# 39/73, train_loss: 0.0152
# 40/73, train_loss: 0.0167
# 41/73, train_loss: 0.0129
# 42/73, train_loss: 0.0132
# 43/73, train_loss: 0.0164
# 44/73, train_loss: 0.0157
# 45/73, train_loss: 0.0151
# 46/73, train_loss: 0.0148
# 47/73, train_loss: 0.0150
# 48/73, train_loss: 0.0197
# 49/73, train_loss: 0.0163
# 50/73, train_loss: 0.0341
# 51/73, train_loss: 0.0145
# 52/73, train_loss: 0.0221
# 53/73, train_loss: 0.0162
# 54/73, train_loss: 0.0157
# 55/73, train_loss: 0.0251
# 56/73, train_loss: 0.0128
# 57/73, train_loss: 0.0141
# 58/73, train_loss: 0.0162
# 59/73, train_loss: 0.0129
# 60/73, train_loss: 0.0145
# 61/73, train_loss: 0.0152
# 62/73, train_loss: 0.0134
# 63/73, train_loss: 0.0164
# 64/73, train_loss: 0.0116
# 65/73, train_loss: 0.0151
# 66/73, train_loss: 0.0176
# 67/73, train_loss: 0.0136
# 68/73, train_loss: 0.0166
# 69/73, train_loss: 0.0242
# 70/73, train_loss: 0.0125
# 71/73, train_loss: 0.0170
# 72/73, train_loss: 0.0137
# 73/73, train_loss: 0.0129
# 74/73, train_loss: 0.0134
# epoch 96 average loss: 0.0190
# Label shape : torch.Size([1, 1, 141, 211, 132])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 141, 211, 132])
# current epoch: 96 current mean dice: 0.9755
# best mean dice: 0.9799 at epoch: 88
# ----------
# epoch 97/100
# 1/73, train_loss: 0.0132
# 2/73, train_loss: 0.0119
# 3/73, train_loss: 0.0174
# 4/73, train_loss: 0.0137
# 5/73, train_loss: 0.0174
# 6/73, train_loss: 0.0134
# 7/73, train_loss: 0.0191
# 8/73, train_loss: 0.0147
# 9/73, train_loss: 0.0119
# 10/73, train_loss: 0.0240
# 11/73, train_loss: 0.0147
# 12/73, train_loss: 0.0150
# 13/73, train_loss: 0.0150
# 14/73, train_loss: 0.0215
# 15/73, train_loss: 0.0149
# 16/73, train_loss: 0.0135
# 17/73, train_loss: 0.0235
# 18/73, train_loss: 0.0134
# 19/73, train_loss: 0.0197
# 20/73, train_loss: 0.0170
# 21/73, train_loss: 0.0154
# 22/73, train_loss: 0.0141
# 23/73, train_loss: 0.0135
# 24/73, train_loss: 0.0178
# 25/73, train_loss: 0.0180
# 26/73, train_loss: 0.0141
# 27/73, train_loss: 0.0161
# 28/73, train_loss: 0.0155
# 29/73, train_loss: 0.0154
# 30/73, train_loss: 0.0185
# 31/73, train_loss: 0.0149
# 32/73, train_loss: 0.0164
# 33/73, train_loss: 0.0151
# 34/73, train_loss: 0.0177
# 35/73, train_loss: 0.0165
# 36/73, train_loss: 0.0133
# 37/73, train_loss: 0.0264
# 38/73, train_loss: 0.0149
# 39/73, train_loss: 0.0297
# 40/73, train_loss: 0.0163
# 41/73, train_loss: 0.0147
# 42/73, train_loss: 0.0247
# 43/73, train_loss: 0.0181
# 44/73, train_loss: 0.0208
# 45/73, train_loss: 0.0240
# 46/73, train_loss: 0.0171
# 47/73, train_loss: 0.0208
# 48/73, train_loss: 0.0187
# 49/73, train_loss: 0.0118
# 50/73, train_loss: 0.0194
# 51/73, train_loss: 0.0146
# 52/73, train_loss: 0.0188
# 53/73, train_loss: 0.0163
# 54/73, train_loss: 0.0303
# 55/73, train_loss: 0.0123
# 56/73, train_loss: 0.0134
# 57/73, train_loss: 0.0162
# 58/73, train_loss: 0.0138
# 59/73, train_loss: 0.0145
# 60/73, train_loss: 0.0364
# 61/73, train_loss: 0.0165
# 62/73, train_loss: 0.0192
# 63/73, train_loss: 0.0136
# 64/73, train_loss: 0.0130
# 65/73, train_loss: 0.0152
# 66/73, train_loss: 0.0147
# 67/73, train_loss: 0.0137
# 68/73, train_loss: 0.0168
# 69/73, train_loss: 0.0153
# 70/73, train_loss: 0.0170
# 71/73, train_loss: 0.0160
# 72/73, train_loss: 0.0135
# 73/73, train_loss: 0.0323
# 74/73, train_loss: 0.0169
# epoch 97 average loss: 0.0172
# ----------
# epoch 98/100
# 1/73, train_loss: 0.0134
# 2/73, train_loss: 0.0132
# 3/73, train_loss: 0.0220
# 4/73, train_loss: 0.0135
# 5/73, train_loss: 0.0166
# 6/73, train_loss: 0.0242
# 7/73, train_loss: 0.0130
# 8/73, train_loss: 0.0165
# 9/73, train_loss: 0.0143
# 10/73, train_loss: 0.0149
# 11/73, train_loss: 0.0140
# 12/73, train_loss: 0.0164
# 13/73, train_loss: 0.0140
# 14/73, train_loss: 0.0155
# 15/73, train_loss: 0.0159
# 16/73, train_loss: 0.0146
# 17/73, train_loss: 0.0143
# 18/73, train_loss: 0.0156
# 19/73, train_loss: 0.0139
# 20/73, train_loss: 0.0142
# 21/73, train_loss: 0.0124
# 22/73, train_loss: 0.0152
# 23/73, train_loss: 0.0145
# 24/73, train_loss: 0.0272
# 25/73, train_loss: 0.0199
# 26/73, train_loss: 0.0120
# 27/73, train_loss: 0.0169
# 28/73, train_loss: 0.0176
# 29/73, train_loss: 0.0200
# 30/73, train_loss: 0.0191
# 31/73, train_loss: 0.0145
# 32/73, train_loss: 0.0142
# 33/73, train_loss: 0.2137
# 34/73, train_loss: 0.0145
# 35/73, train_loss: 0.0349
# 36/73, train_loss: 0.0130
# 37/73, train_loss: 0.0274
# 38/73, train_loss: 0.0173
# 39/73, train_loss: 0.0207
# 40/73, train_loss: 0.0201
# 41/73, train_loss: 0.0288
# 42/73, train_loss: 0.0173
# 43/73, train_loss: 0.0149
# 44/73, train_loss: 0.0188
# 45/73, train_loss: 0.0169
# 46/73, train_loss: 0.0218
# 47/73, train_loss: 0.0146
# 48/73, train_loss: 0.0123
# 49/73, train_loss: 0.0264
# 50/73, train_loss: 0.0202
# 51/73, train_loss: 0.0228
# 52/73, train_loss: 0.0236
# 53/73, train_loss: 0.0248
# 54/73, train_loss: 0.0265
# 55/73, train_loss: 0.0138
# 56/73, train_loss: 0.0167
# 57/73, train_loss: 0.0182
# 58/73, train_loss: 0.0135
# 59/73, train_loss: 0.0133
# 60/73, train_loss: 0.0168
# 61/73, train_loss: 0.0124
# 62/73, train_loss: 0.0141
# 63/73, train_loss: 0.0133
# 64/73, train_loss: 0.0171
# 65/73, train_loss: 0.0146
# 66/73, train_loss: 0.0136
# 67/73, train_loss: 0.0198
# 68/73, train_loss: 0.0155
# 69/73, train_loss: 0.0157
# 70/73, train_loss: 0.0131
# 71/73, train_loss: 0.0178
# 72/73, train_loss: 0.0135
# 73/73, train_loss: 0.0147
# 74/73, train_loss: 0.1951
# epoch 98 average loss: 0.0223
# Label shape : torch.Size([1, 1, 141, 211, 132])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 141, 211, 132])
# current epoch: 98 current mean dice: 0.9711
# best mean dice: 0.9799 at epoch: 88
# ----------
# epoch 99/100
# 1/73, train_loss: 0.0144
# 2/73, train_loss: 0.0201
# 3/73, train_loss: 0.0178
# 4/73, train_loss: 0.0159
# 5/73, train_loss: 0.0187
# 6/73, train_loss: 0.0156
# 7/73, train_loss: 0.0140
# 8/73, train_loss: 0.0511
# 9/73, train_loss: 0.0172
# 10/73, train_loss: 0.0183
# 11/73, train_loss: 0.0136
# 12/73, train_loss: 0.0204
# 13/73, train_loss: 0.0155
# 14/73, train_loss: 0.0121
# 15/73, train_loss: 0.0159
# 16/73, train_loss: 0.0157
# 17/73, train_loss: 0.0167
# 18/73, train_loss: 0.0136
# 19/73, train_loss: 0.0168
# 20/73, train_loss: 0.0158
# 21/73, train_loss: 0.0278
# 22/73, train_loss: 0.0152
# 23/73, train_loss: 0.0225
# 24/73, train_loss: 0.0220
# 25/73, train_loss: 0.0119
# 26/73, train_loss: 0.0116
# 27/73, train_loss: 0.0166
# 28/73, train_loss: 0.0154
# 29/73, train_loss: 0.0177
# 30/73, train_loss: 0.0146
# 31/73, train_loss: 0.0153
# 32/73, train_loss: 0.0142
# 33/73, train_loss: 0.0177
# 34/73, train_loss: 0.0178
# 35/73, train_loss: 0.0165
# 36/73, train_loss: 0.0142
# 37/73, train_loss: 0.0202
# 38/73, train_loss: 0.0306
# 39/73, train_loss: 0.0171
# 40/73, train_loss: 0.0174
# 41/73, train_loss: 0.0231
# 42/73, train_loss: 0.0254
# 43/73, train_loss: 0.0142
# 44/73, train_loss: 0.0149
# 45/73, train_loss: 0.0149
# 46/73, train_loss: 0.0146
# 47/73, train_loss: 0.0158
# 48/73, train_loss: 0.0161
# 49/73, train_loss: 0.0160
# 50/73, train_loss: 0.0180
# 51/73, train_loss: 0.0178
# 52/73, train_loss: 0.0161
# 53/73, train_loss: 0.0143
# 54/73, train_loss: 0.0120
# 55/73, train_loss: 0.0139
# 56/73, train_loss: 0.0157
# 57/73, train_loss: 0.0147
# 58/73, train_loss: 0.0144
# 59/73, train_loss: 0.0133
# 60/73, train_loss: 0.0156
# 61/73, train_loss: 0.0160
# 62/73, train_loss: 0.0111
# 63/73, train_loss: 0.0154
# 64/73, train_loss: 0.0136
# 65/73, train_loss: 0.0227
# 66/73, train_loss: 0.0142
# 67/73, train_loss: 0.0136
# 68/73, train_loss: 0.0233
# 69/73, train_loss: 0.0129
# 70/73, train_loss: 0.0135
# 71/73, train_loss: 0.0173
# 72/73, train_loss: 0.0192
# 73/73, train_loss: 0.0151
# 74/73, train_loss: 0.0128
# epoch 99 average loss: 0.0170
# ----------
# epoch 100/100
# 1/73, train_loss: 0.0171
# 2/73, train_loss: 0.0146
# 3/73, train_loss: 0.0179
# 4/73, train_loss: 0.0140
# 5/73, train_loss: 0.0188
# 6/73, train_loss: 0.0163
# 7/73, train_loss: 0.0167
# 8/73, train_loss: 0.0134
# 9/73, train_loss: 0.0195
# 10/73, train_loss: 0.0178
# 11/73, train_loss: 0.0416
# 12/73, train_loss: 0.0187
# 13/73, train_loss: 0.0893
# 14/73, train_loss: 0.0115
# 15/73, train_loss: 0.0176
# 16/73, train_loss: 0.0146
# 17/73, train_loss: 0.0130
# 18/73, train_loss: 0.0147
# 19/73, train_loss: 0.0160
# 20/73, train_loss: 0.0172
# 21/73, train_loss: 0.0139
# 22/73, train_loss: 0.0123
# 23/73, train_loss: 0.0163
# 24/73, train_loss: 0.0157
# 25/73, train_loss: 0.0127
# 26/73, train_loss: 0.0169
# 27/73, train_loss: 0.0222
# 28/73, train_loss: 0.0203
# 29/73, train_loss: 0.0143
# 30/73, train_loss: 0.0137
# 31/73, train_loss: 0.0123
# 32/73, train_loss: 0.0249
# 33/73, train_loss: 0.0171
# 34/73, train_loss: 0.0190
# 35/73, train_loss: 0.0144
# 36/73, train_loss: 0.0149
# 37/73, train_loss: 0.0126
# 38/73, train_loss: 0.0182
# 39/73, train_loss: 0.0145
# 40/73, train_loss: 0.0139
# 41/73, train_loss: 0.0161
# 42/73, train_loss: 0.0138
# 43/73, train_loss: 0.0161
# 44/73, train_loss: 0.0125
# 45/73, train_loss: 0.0141
# 46/73, train_loss: 0.0150
# 47/73, train_loss: 0.0144
# 48/73, train_loss: 0.0161
# 49/73, train_loss: 0.0116
# 50/73, train_loss: 0.0107
# 51/73, train_loss: 0.0119
# 52/73, train_loss: 0.0216
# 53/73, train_loss: 0.0146
# 54/73, train_loss: 0.0252
# 55/73, train_loss: 0.0142
# 56/73, train_loss: 0.0179
# 57/73, train_loss: 0.0146
# 58/73, train_loss: 0.0173
# 59/73, train_loss: 0.0184
# 60/73, train_loss: 0.0129
# 61/73, train_loss: 0.0126
# 62/73, train_loss: 0.0146
# 63/73, train_loss: 0.0176
# 64/73, train_loss: 0.0131
# 65/73, train_loss: 0.0162
# 66/73, train_loss: 0.0190
# 67/73, train_loss: 0.0138
# 68/73, train_loss: 0.0149
# 69/73, train_loss: 0.0360
# 70/73, train_loss: 0.0198
# 71/73, train_loss: 0.0157
# 72/73, train_loss: 0.0291
# 73/73, train_loss: 0.0157
# 74/73, train_loss: 0.0122
# epoch 100 average loss: 0.0176
# Label shape : torch.Size([1, 1, 141, 211, 132])
# Label unique values : metatensor([0., 1.])
# Image shape : torch.Size([1, 1, 141, 211, 132])
# current epoch: 100 current mean dice: 0.9787
# best mean dice: 0.9799 at epoch: 88

# %%
print(
    f"train completed, best_metric: {best_metric:.4f} "
    f"at epoch: {best_metric_epoch}")
# Out:
# train completed, best_metric: 0.0000 at epoch: 2

# %%
plt.figure("train", (25,7))
plt.subplot(1, 2, 1)
plt.title("Epoch Average Loss")
x = [i + 1 for i in range(len(epoch_loss_values))]
y = epoch_loss_values
plt.ylabel("Loss")
plt.xlabel("epoch")
plt.plot(x, y, color='darkred')
plt.grid(True)
plt.subplot(1, 2, 2)
plt.title("Val Mean Dice")
x = [val_interval * (i + 1) for i in range(len(metric_values))]
y = metric_values
plt.ylabel("DSC")
plt.xlabel("epoch")
plt.grid(True)
plt.plot(x, y, color='black')
plt.show()

# %% [markdown]
# **Make Predictions from Test Data**

# %%
test_ds = Dataset(data=test_files, transform=val_transforms)
test_loader = DataLoader(test_ds, batch_size=1)

post_transforms = Compose([
    Invertd(
        keys="pred",
        transform=val_transforms,
        orig_keys="image",
        meta_keys="pred_meta_dict",
        orig_meta_keys="image_meta_dict",
        meta_key_postfix="meta_dict",
        nearest_interp=False,
        to_tensor=True,
    ),
    AsDiscreted(keys="pred", argmax=True, to_onehot=2),
    SaveImaged(keys="pred", meta_keys="pred_meta_dict", output_dir="./out", output_postfix="seg", resample=False),
])

# %%
import torch
import matplotlib.pyplot as plt
import nibabel as nib
import numpy as np
from monai.transforms import LoadImaged
from monai.inferers import sliding_window_inference
from monai.handlers.utils import from_engine
from monai.data import decollate_batch

# Charger les images avec nibabel
image_path = test_files[0]['image']
label_path = test_files[0]['label']

image_data = nib.load(image_path).get_fdata()
label_data = nib.load(label_path).get_fdata()

# Convertir en tensors PyTorch
original_image = torch.from_numpy(image_data).float()
original_label = torch.from_numpy(label_data).float()

# Vérifier la forme des images
print("Original image shape:", original_image.shape)
print("Original label shape:", original_label.shape)

# Choisir une coupe 2D
slice_idx = 30
image_slice_2d = original_image[slice_idx].detach().cpu().numpy()
label_slice_2d = original_label[slice_idx].detach().cpu().numpy()

# Charger le modèle
model.load_state_dict(torch.load("best_metric_model.pth", map_location="cpu"))
model.eval()

# Exécuter l'inférence
with torch.no_grad():
    for test_data in test_loader:
        test_inputs = test_data["image"].to(device)
        test_data["pred"] = sliding_window_inference(test_inputs, (96, 96, 96), 1, model, overlap=0.75)
        test_data = [post_transforms(i) for i in decollate_batch(test_data)]
        test_output = from_engine(["pred"])(test_data)
        break  # Un seul batch

# Extraire la prédiction pour la classe "poumon" (index 1)
predicted_mask = torch.argmax(test_output[0], dim=0)  # Réduction sur l'axe des classes
predicted_slice = predicted_mask[slice_idx].detach().cpu().numpy()

# Afficher les résultats
plt.figure(figsize=(20, 7))

# Image originale
plt.subplot(1, 3, 1)
plt.imshow(image_slice_2d, cmap="gray", vmin=-1000, vmax=1000)
plt.title(f'Test image, slice {slice_idx}')
plt.axis('off')

# Label de référence
plt.subplot(1, 3, 2)
plt.imshow(label_slice_2d, cmap="gray")
plt.title(f'Reference label, slice {slice_idx}')
plt.axis('off')

# Prédiction
plt.subplot(1, 3, 3)
plt.imshow(predicted_slice, cmap="gray")
plt.title(f'Predicted label, slice {slice_idx}')
plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Original image shape: torch.Size([308, 226, 277])
# Original label shape: torch.Size([308, 226, 277])
# 2025-04-29 23:42:49,128 INFO image_writer.py:197 - writing: out/case_054_1/case_054_1_seg.nii.gz

# %%
import torch
import matplotlib.pyplot as plt
import nibabel as nib
import numpy as np
from monai.transforms import LoadImaged
from monai.inferers import sliding_window_inference
from monai.handlers.utils import from_engine
from monai.data import decollate_batch

# Charger les images avec nibabel
image_path = test_files[0]['image']
label_path = test_files[0]['label']

image_data = nib.load(image_path).get_fdata()
label_data = nib.load(label_path).get_fdata()

# Convertir en tensors PyTorch
original_image = torch.from_numpy(image_data).float()
original_label = torch.from_numpy(label_data).float()

# Vérifier la forme des images
print("Original image shape:", original_image.shape)
print("Original label shape:", original_label.shape)

# Choisir une coupe 2D
slice_idx = 110
image_slice_2d = original_image[slice_idx].detach().cpu().numpy()
label_slice_2d = original_label[slice_idx].detach().cpu().numpy()

# Charger le modèle
model.load_state_dict(torch.load("best_metric_model.pth", map_location="cpu"))
model.eval()

# Exécuter l'inférence
with torch.no_grad():
    for test_data in test_loader:
        test_inputs = test_data["image"].to(device)
        test_data["pred"] = sliding_window_inference(test_inputs, (96, 96, 96), 1, model, overlap=0.75)
        test_data = [post_transforms(i) for i in decollate_batch(test_data)]
        test_output = from_engine(["pred"])(test_data)
        break  # Un seul batch

# Extraire la prédiction pour la classe "poumon" (index 1)
predicted_mask = torch.argmax(test_output[0], dim=0)  # Réduction sur l'axe des classes
predicted_slice = predicted_mask[slice_idx].detach().cpu().numpy()

# Afficher les résultats
plt.figure(figsize=(20, 7))

# Image originale
plt.subplot(1, 3, 1)
plt.imshow(image_slice_2d, cmap="gray", vmin=-1000, vmax=1000)
plt.title(f'Test image, slice {slice_idx}')
plt.axis('off')

# Label de référence
plt.subplot(1, 3, 2)
plt.imshow(label_slice_2d, cmap="gray")
plt.title(f'Reference label, slice {slice_idx}')
plt.axis('off')

# Prédiction
plt.subplot(1, 3, 3)
plt.imshow(predicted_slice, cmap="gray")
plt.title(f'Predicted label, slice {slice_idx}')
plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Original image shape: torch.Size([308, 226, 277])
# Original label shape: torch.Size([308, 226, 277])
# 2025-04-29 23:43:35,710 INFO image_writer.py:197 - writing: out/case_054_1/case_054_1_seg.nii.gz

# %%
import torch
import matplotlib.pyplot as plt
import nibabel as nib
import numpy as np
from monai.transforms import LoadImaged
from monai.inferers import sliding_window_inference
from monai.handlers.utils import from_engine
from monai.data import decollate_batch

# Charger les images avec nibabel
image_path = test_files[0]['image']
label_path = test_files[0]['label']

image_data = nib.load(image_path).get_fdata()
label_data = nib.load(label_path).get_fdata()

# Convertir en tensors PyTorch
original_image = torch.from_numpy(image_data).float()
original_label = torch.from_numpy(label_data).float()

# Vérifier la forme des images
print("Original image shape:", original_image.shape)
print("Original label shape:", original_label.shape)

# Choisir une coupe 2D
slice_idx = 40
image_slice_2d = original_image[slice_idx].detach().cpu().numpy()
label_slice_2d = original_label[slice_idx].detach().cpu().numpy()

# Charger le modèle
model.load_state_dict(torch.load("best_metric_model.pth", map_location="cpu"))
model.eval()

# Exécuter l'inférence
with torch.no_grad():
    for test_data in test_loader:
        test_inputs = test_data["image"].to(device)
        test_data["pred"] = sliding_window_inference(test_inputs, (96, 96, 96), 1, model, overlap=0.75)
        test_data = [post_transforms(i) for i in decollate_batch(test_data)]
        test_output = from_engine(["pred"])(test_data)
        break  # Un seul batch

# Extraire la prédiction pour la classe "poumon" (index 1)
predicted_mask = torch.argmax(test_output[0], dim=0)  # Réduction sur l'axe des classes
predicted_slice = predicted_mask[slice_idx].detach().cpu().numpy()

# Afficher les résultats
plt.figure(figsize=(20, 7))

# Image originale
plt.subplot(1, 3, 1)
plt.imshow(image_slice_2d, cmap="gray", vmin=-1000, vmax=1000)
plt.title(f'Test image, slice {slice_idx}')
plt.axis('off')

# Label de référence
plt.subplot(1, 3, 2)
plt.imshow(label_slice_2d, cmap="gray")
plt.title(f'Reference label, slice {slice_idx}')
plt.axis('off')

# Prédiction
plt.subplot(1, 3, 3)
plt.imshow(predicted_slice, cmap="gray")
plt.title(f'Predicted label, slice {slice_idx}')
plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Original image shape: torch.Size([308, 226, 277])
# Original label shape: torch.Size([308, 226, 277])
# 2025-04-17 17:38:52,145 INFO image_writer.py:197 - writing: out/case_054_1/case_054_1_seg.nii.gz

# %%
import torch
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt
import scipy.ndimage

from monai.transforms import LoadImaged, AsDiscrete
from monai.inferers import sliding_window_inference
from monai.data import decollate_batch

model.load_state_dict(torch.load("best_metric_model.pth", map_location=device))

model.eval()  

# Transformations pour le post-traitement
post_pred = AsDiscrete(argmax=True, to_onehot=2)

# Listes pour stocker les résultats
reference_voxels = []
predicted_voxels = []
TP_list = []
FP_list = []
FN_list = []
TN_list = []

# Parcourir les données de test
for i, test_data in enumerate(test_loader):
    print(f"Traitement de l'image de test n°{i + 1}")
    test_inputs, test_labels = test_data["image"].to(device), test_data["label"].to(device)

    # Inférence avec sliding window
    with torch.no_grad():
        test_outputs = sliding_window_inference(test_inputs, (96, 96, 96), 1, model, overlap=0.75)

    # Post-traitement des sorties
    test_outputs = [post_pred(i) for i in decollate_batch(test_outputs)]

    # Convertir les masques en numpy arrays et supprimer les dimensions supplémentaires
    predicted_mask = test_outputs[0][1].cpu().numpy()
    predicted_mask = np.squeeze(predicted_mask)  # Supprimer les dimensions supplémentaires
    reference_mask = (test_labels[0] == 1).cpu().numpy().astype(np.uint8)
    reference_mask = np.squeeze(reference_mask)  # Supprimer les dimensions supplémentaires

    # Redimensionner le masque prédit à la taille du masque de référence
    if predicted_mask.shape != reference_mask.shape:
        zoom_factors = np.array(reference_mask.shape) / np.array(predicted_mask.shape)
        predicted_mask = scipy.ndimage.zoom(predicted_mask, zoom_factors, order=0)
        predicted_mask = (predicted_mask > 0.5).astype(np.int32)  # Re-binariser après redimensionnement

    # Calculer le nombre de voxels
    num_voxels_predicted = np.sum(predicted_mask)
    num_voxels_reference = np.sum(reference_mask)

    reference_voxels.append(num_voxels_reference)
    predicted_voxels.append(num_voxels_predicted)

    # Calcul des métriques (après le redimensionnement)
    TP = np.logical_and(predicted_mask == 1, reference_mask == 1).sum()
    FP = np.logical_and(predicted_mask == 1, reference_mask == 0).sum()
    FN = np.logical_and(predicted_mask == 0, reference_mask == 1).sum()
    TN = np.logical_and(predicted_mask == 0, reference_mask == 0).sum()

    TP_list.append(TP)
    FP_list.append(FP)
    FN_list.append(FN)
    TN_list.append(TN)

    print(f"Nombre de voxels dans le masque prédit: {num_voxels_predicted}")
    print(f"Nombre de voxels dans le masque de référence: {num_voxels_reference}")
    print(f"Différence de voxels: {num_voxels_predicted - num_voxels_reference}")
    print(f"TP: {TP}, FP: {FP}, FN: {FN}, TN: {TN}")

# Calcul des métriques globales
total_TP = np.sum(TP_list)
total_FP = np.sum(FP_list)
total_FN = np.sum(FN_list)
total_TN = np.sum(TN_list)

precision = total_TP / (total_TP + total_FP + 1e-8)
recall = total_TP / (total_TP + total_FN + 1e-8)

print("\n--- Résultats globaux ---")
print(f"Précision : {precision:.4f} | Rappel : {recall:.4f}")

# Affichage du graphe comparatif
plt.figure(figsize=(12, 6))
x = np.arange(len(test_files))

plt.plot(x, reference_voxels, label="Masque de référence", marker='o', color='blue')
plt.plot(x, predicted_voxels, label="Masque prédit", marker='s', color='red')

plt.xlabel("Index de l'image de test")
plt.ylabel("Nombre de voxels")
plt.title("Comparaison des voxels dans le masque de référence et le masque prédit")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Traitement de l'image de test n°1
# Nombre de voxels dans le masque prédit: 1040175
# Nombre de voxels dans le masque de référence: 1287201
# Différence de voxels: -247026.0
# TP: 942257, FP: 97918, FN: 344944, TN: 2938615
# Traitement de l'image de test n°2
# Nombre de voxels dans le masque prédit: 797486
# Nombre de voxels dans le masque de référence: 712978
# Différence de voxels: 84508.0
# TP: 672469, FP: 125017, FN: 40509, TN: 3485739
# Traitement de l'image de test n°3
# Nombre de voxels dans le masque prédit: 1098533.0
# Nombre de voxels dans le masque de référence: 1308514
# Différence de voxels: -209981.0
# TP: 1016212, FP: 82321, FN: 292302, TN: 3338779
# Traitement de l'image de test n°4
# Nombre de voxels dans le masque prédit: 619335.0
# Nombre de voxels dans le masque de référence: 589175
# Différence de voxels: 30160.0
# TP: 556429, FP: 62906, FN: 32746, TN: 4077533
# Traitement de l'image de test n°5
# Nombre de voxels dans le masque prédit: 920203
# Nombre de voxels dans le masque de référence: 1029678
# Différence de voxels: -109475.0
# TP: 824895, FP: 95308, FN: 204783, TN: 3660014
# Traitement de l'image de test n°6
# Nombre de voxels dans le masque prédit: 589146
# Nombre de voxels dans le masque de référence: 585620
# Différence de voxels: 3526.0
# TP: 549222, FP: 39924, FN: 36398, TN: 4159456
# Traitement de l'image de test n°7
# Nombre de voxels dans le masque prédit: 666465.0
# Nombre de voxels dans le masque de référence: 833676
# Différence de voxels: -167211.0
# TP: 645459, FP: 21006, FN: 188217, TN: 2092878
# Traitement de l'image de test n°8
# Nombre de voxels dans le masque prédit: 504654.0
# Nombre de voxels dans le masque de référence: 537072
# Différence de voxels: -32418.0
# TP: 485821, FP: 18833, FN: 51251, TN: 2429935
# Traitement de l'image de test n°9
# Nombre de voxels dans le masque prédit: 871573.0
# Nombre de voxels dans le masque de référence: 1081618
# Différence de voxels: -210045.0
# TP: 854253, FP: 17320, FN: 227365, TN: 2286364
# Traitement de l'image de test n°10
# Nombre de voxels dans le masque prédit: 619274.0
# Nombre de voxels dans le masque de référence: 661767
# Différence de voxels: -42493.0
# TP: 599602, FP: 19672, FN: 62165, TN: 2773424
# Traitement de l'image de test n°11
# Nombre de voxels dans le masque prédit: 1058617.0
# Nombre de voxels dans le masque de référence: 1376388
# Différence de voxels: -317771.0
# TP: 1040422, FP: 18195, FN: 335966, TN: 3667017
# Traitement de l'image de test n°12
# Nombre de voxels dans le masque prédit: 1098537.0
# Nombre de voxels dans le masque de référence: 1242066
# Différence de voxels: -143529.0
# TP: 1073461, FP: 25076, FN: 168605, TN: 3794458
# Traitement de l'image de test n°13
# Nombre de voxels dans le masque prédit: 947226.0
# Nombre de voxels dans le masque de référence: 1401801
# Différence de voxels: -454575.0
# TP: 931860, FP: 15366, FN: 469941, TN: 3551883
# Traitement de l'image de test n°14
# Nombre de voxels dans le masque prédit: 969724.0
# Nombre de voxels dans le masque de référence: 1275567
# Différence de voxels: -305843.0
# TP: 950028, FP: 19696, FN: 325539, TN: 3642137
# Traitement de l'image de test n°15
# Nombre de voxels dans le masque prédit: 1095475.0
# Nombre de voxels dans le masque de référence: 1528327
# Différence de voxels: -432852.0
# TP: 1073287, FP: 22188, FN: 455040, TN: 2822477
# Traitement de l'image de test n°16
# Nombre de voxels dans le masque prédit: 1253285.0
# Nombre de voxels dans le masque de référence: 1375970
# Différence de voxels: -122685.0
# TP: 1220048, FP: 33237, FN: 155922, TN: 2963785
# Traitement de l'image de test n°17
# Nombre de voxels dans le masque prédit: 925478.0
# Nombre de voxels dans le masque de référence: 952503
# Différence de voxels: -27025.0
# TP: 888588, FP: 36890, FN: 63915, TN: 2771182
# Traitement de l'image de test n°18
# Nombre de voxels dans le masque prédit: 892305.0
# Nombre de voxels dans le masque de référence: 942787
# Différence de voxels: -50482.0
# TP: 866098, FP: 26207, FN: 76689, TN: 2791581
# Traitement de l'image de test n°19
# Nombre de voxels dans le masque prédit: 1033711.0
# Nombre de voxels dans le masque de référence: 1389978
# Différence de voxels: -356267.0
# TP: 1019074, FP: 14637, FN: 370904, TN: 3046633
# Traitement de l'image de test n°20
# Nombre de voxels dans le masque prédit: 1078753.0
# Nombre de voxels dans le masque de référence: 1305592
# Différence de voxels: -226839.0
# TP: 1050703, FP: 28050, FN: 254889, TN: 2934678
# Traitement de l'image de test n°21
# Nombre de voxels dans le masque prédit: 1053576.0
# Nombre de voxels dans le masque de référence: 1336435
# Différence de voxels: -282859.0
# TP: 1033648, FP: 19928, FN: 302787, TN: 2753637
# Traitement de l'image de test n°22
# Nombre de voxels dans le masque prédit: 1041475.0
# Nombre de voxels dans le masque de référence: 1093237
# Différence de voxels: -51762.0
# TP: 1015905, FP: 25570, FN: 77332, TN: 3032293
# Traitement de l'image de test n°23
# Nombre de voxels dans le masque prédit: 900610.0
# Nombre de voxels dans le masque de référence: 1114660
# Différence de voxels: -214050.0
# TP: 876098, FP: 24512, FN: 238562, TN: 2462328
# Traitement de l'image de test n°24
# Nombre de voxels dans le masque prédit: 939854.0
# Nombre de voxels dans le masque de référence: 1043798
# Différence de voxels: -103944.0
# TP: 891567, FP: 48287, FN: 152231, TN: 2509415
# Traitement de l'image de test n°25
# Nombre de voxels dans le masque prédit: 855483.0
# Nombre de voxels dans le masque de référence: 1080382
# Différence de voxels: -224899.0
# TP: 843252, FP: 12231, FN: 237130, TN: 2243585
# Traitement de l'image de test n°26
# Nombre de voxels dans le masque prédit: 863731.0
# Nombre de voxels dans le masque de référence: 902789
# Différence de voxels: -39058.0
# TP: 848518, FP: 15213, FN: 54271, TN: 2443093
# Traitement de l'image de test n°27
# Nombre de voxels dans le masque prédit: 1037870.0
# Nombre de voxels dans le masque de référence: 1403482
# Différence de voxels: -365612.0
# TP: 1015959, FP: 21911, FN: 387523, TN: 3599887
# Traitement de l'image de test n°28
# Nombre de voxels dans le masque prédit: 1123773.0
# Nombre de voxels dans le masque de référence: 1287593
# Différence de voxels: -163820.0
# TP: 1093852, FP: 29921, FN: 193741, TN: 3707766
# Traitement de l'image de test n°29
# Nombre de voxels dans le masque prédit: 1034497.0
# Nombre de voxels dans le masque de référence: 1337731
# Différence de voxels: -303234.0
# TP: 1017458, FP: 17039, FN: 320273, TN: 3010734
# Traitement de l'image de test n°30
# Nombre de voxels dans le masque prédit: 1042211.0
# Nombre de voxels dans le masque de référence: 1216306
# Différence de voxels: -174095.0
# TP: 1016672, FP: 25539, FN: 199634, TN: 3123659
#
# --- Résultats globaux ---
# Précision : 0.9621 | Rappel : 0.8098
